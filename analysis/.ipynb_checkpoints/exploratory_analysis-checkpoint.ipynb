# %% [markdown]
# # Exploring Steven Universe
#
# This notebook explores the data I scraped from the [Steven Universe Fandom Wiki](https://steven-universe.fandom.com/wiki/Episode_Guide). I want to see how large the datasets are so that I can decide whether or not to create a database to store the data or just use pandas DataFrames.
#
# ## To-do list:
# - Create additional columns e.g., calculating length of a season
# - Find most salient tokens using TF-IDF
#     - Create a dictionary that counts the number of times tokens are in the summary column
#     - Write a function that lists the top K tokens, in descending order
#     - Write a function that lists the tokens that occur at least some specified minimum number of times
#     - Write a function that maps each token to its TF-IDF

# %%
import csv
import pandas as pd
import numpy as np

# %%
data_pathname = '../data/'

seasons_df = pd.read_csv(data_pathname + 'seasons.csv')

# %%
seasons_df
# Out:
#      name  num_episodes           start_date             end_date
# 0       1            52  2013-11-04 00:00:00  2015-03-12 00:00:00
# 1       2            26  2015-03-13 00:00:00  2016-01-08 00:00:00
# 2       3            25  2016-05-12 00:00:00  2016-08-10 00:00:00
# 3       4            25  2016-08-11 00:00:00  2017-05-11 00:00:00
# 4       5            32  2017-05-29 00:00:00  2019-01-21 00:00:00
# 5   Movie             1  2019-09-02 00:00:00  2019-09-02 00:00:00
# 6  Future            20  2019-12-07 00:00:00  2020-03-27 00:00:00

# %%
seasons_df.dtypes
# Out:
# name            object
# num_episodes     int64
# start_date      object
# end_date        object
# dtype: object

# %%
# Need to convert date columns to datetime objects
for col in ['start_date', 'end_date']:
    seasons_df[col] = pd.to_datetime(seasons_df[col])
    
seasons_df.dtypes
# Out:
# name                    object
# num_episodes             int64
# start_date      datetime64[ns]
# end_date        datetime64[ns]
# dtype: object

# %%
seasons_df['length'] = seasons_df['end_date'] - seasons_df['start_date']
seasons_df[seasons_df['name'] != "Movie"]['length'].describe()
# Out:
# count                           6
# mean            311 days 16:00:00
# std      204 days 01:15:45.296281
# min              90 days 00:00:00
# 25%             151 days 12:00:00
# 50%             287 days 00:00:00
# 75%             445 days 00:00:00
# max             602 days 00:00:00
# Name: length, dtype: object

# %%
# Visualize the length of each season
import matplotlib.pyplot as plt
import seaborn as sns

# LATER

# %%
episodes_df = pd.read_csv(data_pathname + 'episodes.csv')

# %%
episodes_df.head()
# Out:
#                    title season num_series num_season  airdate  \
# 0               Gem Glow      1          1          1      NaN
# 1     Laser Light Cannon      1          2          2      NaN
# 2  Cheeseburger Backpack      1          3          3      NaN
# 3     Together Breakfast      1          4          4      NaN
# 4                  Frybo      1          5          5      NaN
#
#                                              summary
# 0  Steven thinks his favorite ice cream sandwiche...
# 1  A magical comet hurtles toward Beach City, and...
# 2  A mission to the Lunar Sea Spire takes a treac...
# 3  Steven tries to get the Crystal Gems to take p...
# 4  Steven helps a Boardie kid with his grueling j...

# %%
episodes_df.shape
# Out:
# (175, 6)

# %%
import re

def create_list_tokens(input_string):
    '''
    Takes input (should be a string) and returns a list of tokens 
    '''
    if not isinstance(input_string, str):
        string = str(input_string)
    else:
        string = input_string
        
    list_of_tokens = string.split()
    cleaned_list = []
    
    for token in list_of_tokens:
        stripped_token = re.sub(r'[^\w\s]', '', token).lower() 
        cleaned_token = re.sub(r'[0-9]', '', stripped_token)
        
        if cleaned_token != '':
            cleaned_list.append(cleaned_token)
        
    return cleaned_list

# %%
# Create a helper function that counts the distinct number of tokens
def count_distinct_tokens(list_of_tokens, token_counts):
    '''
    Takes as input a list of tokens and updates a dictionary with each 
    distinct string and the number of times it appears in the list.
    
    Inputs:
        - list_of_tokens (list): List of tokens
        - token_counts (dict): Dictionary mapping token to counts
        
    Returns None, updates dictionary in place
    '''
    for token in list_of_tokens:
        if token not in token_counts:
            token_counts[token] = 1
        else:
            token_counts[token] += 1
    
    return None

# %%
episodes_df['list_of_tokens'] = episodes_df.apply(lambda row: create_list_tokens(row['summary']), axis = 1)
episodes_df['list_of_tokens'].head()
# Out:
# 0    [steven, thinks, his, favorite, ice, cream, sa...
# 1    [a, magical, comet, hurtles, toward, beach, ci...
# 2    [a, mission, to, the, lunar, sea, spire, takes...
# 3    [steven, tries, to, get, the, crystal, gems, t...
# 4    [steven, helps, a, boardie, kid, with, his, gr...
# Name: list_of_tokens, dtype: object

# %%
episodes_df.head()
# Out:
#                    title season num_series num_season  airdate  \
# 0               Gem Glow      1          1          1      NaN
# 1     Laser Light Cannon      1          2          2      NaN
# 2  Cheeseburger Backpack      1          3          3      NaN
# 3     Together Breakfast      1          4          4      NaN
# 4                  Frybo      1          5          5      NaN
#
#                                              summary  \
# 0  Steven thinks his favorite ice cream sandwiche...
# 1  A magical comet hurtles toward Beach City, and...
# 2  A mission to the Lunar Sea Spire takes a treac...
# 3  Steven tries to get the Crystal Gems to take p...
# 4  Steven helps a Boardie kid with his grueling j...
#
#                                       list_of_tokens
# 0  [steven, thinks, his, favorite, ice, cream, sa...
# 1  [a, magical, comet, hurtles, toward, beach, ci...
# 2  [a, mission, to, the, lunar, sea, spire, takes...
# 3  [steven, tries, to, get, the, crystal, gems, t...
# 4  [steven, helps, a, boardie, kid, with, his, gr...

# %%
episodes_df.loc[episodes_df.title == 'Gem Glow']['season'].values[0]
# Out:
# '1'

# %%
# Need to create a dictionary of tokens for the summaries
summary_token_map = {}

episodes_df.apply(lambda row: count_distinct_tokens(row['list_of_tokens'], summary_token_map), axis=1)
# Out:
# 0      None
# 1      None
# 2      None
# 3      None
# 4      None
#        ...
# 170    None
# 171    None
# 172    None
# 173    None
# 174    None
# Length: 175, dtype: object

# %%
summary_token_map
# Out:
# {'steven': 153,
#  'thinks': 3,
#  'his': 34,
#  'favorite': 3,
#  'ice': 1,
#  'cream': 2,
#  'sandwiches': 1,
#  'are': 6,
#  'the': 119,
#  'trick': 1,
#  'to': 115,
#  'summoning': 1,
#  'magic': 2,
#  'shield': 1,
#  'but': 15,
#  'learns': 5,
#  'otherwise': 1,
#  'when': 11,
#  'facing': 1,
#  'off': 6,
#  'with': 26,
#  'an': 11,
#  'acidspewing': 1,
#  'insect': 1,
#  'monster': 6,
#  'a': 106,
#  'magical': 9,
#  'comet': 1,
#  'hurtles': 1,
#  'toward': 1,
#  'beach': 14,
#  'city': 15,
#  'and': 81,
#  'must': 2,
#  'dig': 1,
#  'through': 3,
#  'fathers': 1,
#  'collection': 1,
#  'of': 33,
#  'old': 4,
#  'junk': 1,
#  'past': 2,
#  'find': 9,
#  'weapon': 1,
#  'that': 14,
#  'can': 8,
#  'save': 1,
#  'town': 3,
#  'mission': 6,
#  'lunar': 2,
#  'sea': 3,
#  'spire': 3,
#  'takes': 7,
#  'treacherous': 1,
#  'turn': 2,
#  'has': 11,
#  'packed': 1,
#  'totally': 1,
#  'amazing': 1,
#  'cheeseburger': 1,
#  'backpack': 1,
#  'anything': 1,
#  'they': 5,
#  'could': 1,
#  'ever': 1,
#  'need': 1,
#  'tries': 8,
#  'get': 11,
#  'crystal': 16,
#  'gems': 35,
#  'take': 8,
#  'part': 2,
#  'in': 29,
#  'special': 5,
#  'breakfast': 1,
#  'tradition': 1,
#  'instead': 1,
#  'finds': 6,
#  'himself': 6,
#  'tumbling': 1,
#  'rooms': 1,
#  'temple': 5,
#  'helps': 10,
#  'boardie': 1,
#  'kid': 1,
#  'grueling': 1,
#  'job': 1,
#  'by': 3,
#  'using': 2,
#  'gem': 13,
#  'shard': 1,
#  'bring': 2,
#  'clothing': 1,
#  'life': 7,
#  'attempts': 3,
#  'master': 1,
#  'power': 4,
#  'shape': 2,
#  'shifting': 1,
#  'only': 1,
#  'shift': 2,
#  'fingers': 1,
#  'into': 13,
#  'tiny': 1,
#  'cat': 1,
#  'heads': 3,
#  'looks': 1,
#  'like': 1,
#  'hero': 1,
#  'he': 13,
#  'forms': 1,
#  'bubble': 4,
#  'around': 4,
#  'protect': 1,
#  'girl': 1,
#  'likes': 2,
#  'from': 8,
#  'danger': 1,
#  'then': 1,
#  'panics': 1,
#  'cant': 3,
#  'figure': 1,
#  'out': 16,
#  'how': 10,
#  'prove': 1,
#  'be': 8,
#  'worthy': 1,
#  'garnet': 10,
#  'while': 6,
#  'navigate': 1,
#  'their': 10,
#  'way': 2,
#  'ancient': 2,
#  'maze': 1,
#  'joins': 2,
#  'amethyst': 20,
#  'underground': 2,
#  'wrestling': 2,
#  'league': 1,
#  'makes': 2,
#  'friends': 7,
#  'lion': 5,
#  'quite': 1,
#  'tell': 2,
#  'why': 1,
#  'it': 5,
#  'him': 6,
#  'funland': 3,
#  'arcade': 1,
#  'where': 2,
#  'allure': 1,
#  'video': 1,
#  'games': 1,
#  'during': 1,
#  'sky': 1,
#  'convince': 1,
#  'pearl': 13,
#  'fuse': 3,
#  'together': 11,
#  'become': 2,
#  'giant': 2,
#  'woman': 1,
#  'thousands': 2,
#  'years': 1,
#  'decides': 2,
#  'make': 4,
#  'up': 8,
#  'for': 14,
#  'all': 6,
#  'birthdays': 1,
#  'have': 3,
#  'missed': 1,
#  'lars': 9,
#  'hang': 2,
#  'cool': 4,
#  'kids': 4,
#  'teenage': 1,
#  'shenanigans': 1,
#  'them': 4,
#  'trouble': 3,
#  'toy': 1,
#  'trade': 1,
#  'between': 3,
#  'onion': 2,
#  'escalates': 1,
#  'epic': 1,
#  'proportions': 1,
#  'teach': 2,
#  'art': 1,
#  'swordfighting': 1,
#  'holographic': 1,
#  'version': 1,
#  'herself': 2,
#  'connie': 16,
#  'try': 8,
#  'ride': 2,
#  'movie': 1,
#  'theater': 1,
#  'other': 1,
#  'ideas': 1,
#  'after': 6,
#  'battle': 1,
#  'damages': 1,
#  'fish': 1,
#  'stew': 1,
#  'pizza': 3,
#  'throws': 2,
#  'cookout': 1,
#  'at': 8,
#  'mend': 2,
#  'relationship': 1,
#  'family': 5,
#  'stevens': 9,
#  'desire': 1,
#  'some': 13,
#  'alonetime': 1,
#  'unlocks': 2,
#  'new': 14,
#  'room': 3,
#  'answers': 3,
#  'every': 1,
#  'wish': 1,
#  'seeing': 1,
#  'powerful': 2,
#  'sugilite': 1,
#  'gets': 6,
#  'determined': 2,
#  'super': 1,
#  'strong': 1,
#  'pawns': 1,
#  'work': 2,
#  'on': 27,
#  'sadie': 5,
#  'working': 1,
#  'big': 3,
#  'donut': 1,
#  'needs': 1,
#  'musical': 1,
#  'partner': 1,
#  'upcoming': 1,
#  'show': 4,
#  'uses': 2,
#  'time': 4,
#  'travel': 1,
#  'device': 1,
#  'recruit': 1,
#  'perfect': 1,
#  'bandmate': 1,
#  'accidentally': 3,
#  'releases': 1,
#  'tame': 1,
#  'its': 1,
#  'wild': 1,
#  'violent': 1,
#  'instincts': 1,
#  'cracks': 1,
#  'her': 11,
#  'gemstone': 1,
#  'go': 2,
#  'heal': 2,
#  'befriends': 1,
#  'mirror': 1,
#  'mysteriously': 1,
#  'communicate': 1,
#  'ocean': 1,
#  'disappears': 1,
#  'first': 5,
#  'day': 4,
#  'summer': 1,
#  'is': 12,
#  'panic': 1,
#  'injuring': 1,
#  'leg': 1,
#  'greg': 11,
#  'comes': 3,
#  'live': 3,
#  'unintentionally': 1,
#  'interferes': 1,
#  'powers': 4,
#  'build': 2,
#  'spaceship': 2,
#  'let': 1,
#  'revisit': 3,
#  'wonders': 1,
#  'cosmos': 1,
#  'pop': 1,
#  'bubbled': 1,
#  'form': 1,
#  'secret': 3,
#  'team': 1,
#  'secretly': 1,
#  'retrieve': 2,
#  'missing': 2,
#  'shards': 1,
#  'vacation': 2,
#  'friendship': 1,
#  'caught': 1,
#  'ronaldos': 1,
#  'paranormal': 1,
#  'theories': 1,
#  'about': 10,
#  'strange': 3,
#  'occurrences': 1,
#  'effort': 1,
#  'win': 1,
#  'over': 3,
#  'connies': 2,
#  'parents': 1,
#  'convinces': 2,
#  'pretend': 1,
#  'mother': 1,
#  'imagines': 1,
#  'what': 5,
#  'does': 2,
#  'discovers': 2,
#  'grows': 1,
#  'patch': 1,
#  'stevenshaped': 1,
#  'watermelons': 2,
#  'wont': 1,
#  'stop': 2,
#  'laying': 1,
#  'face': 2,
#  'sleeps': 1,
#  'sees': 2,
#  'something': 3,
#  'creepy': 1,
#  'traversing': 1,
#  'warp': 1,
#  'streams': 1,
#  'ease': 1,
#  'paranoia': 1,
#  'use': 1,
#  'fusion': 4,
#  'was': 2,
#  'simply': 1,
#  'test': 1,
#  'demands': 1,
#  'one': 2,
#  'see': 2,
#  'future': 2,
#  'becomes': 1,
#  'curious': 1,
#  'possible': 1,
#  'dangers': 1,
#  'lurk': 1,
#  'road': 3,
#  'goes': 6,
#  'lighthouse': 1,
#  'watch': 1,
#  'scary': 1,
#  'movies': 1,
#  'ronaldo': 4,
#  'home': 3,
#  'before': 1,
#  'snows': 1,
#  'cleaning': 1,
#  'gregs': 1,
#  'storage': 1,
#  'unit': 1,
#  'reunited': 1,
#  'sitcom': 1,
#  'lil': 1,
#  'butler': 1,
#  'encounter': 1,
#  'another': 1,
#  'droid': 1,
#  'space': 1,
#  'place': 3,
#  'belonged': 1,
#  'rose': 2,
#  'quartz': 3,
#  'want': 1,
#  'ending': 1,
#  'beloved': 1,
#  'book': 2,
#  'series': 1,
#  'so': 5,
#  'roses': 2,
#  'reenact': 1,
#  'buck': 1,
#  'dewey': 3,
#  'tshirts': 1,
#  'tells': 6,
#  'full': 1,
#  'story': 4,
#  'met': 1,
#  'message': 1,
#  'wailing': 1,
#  'stone': 1,
#  'cause': 1,
#  'outage': 1,
#  'mayor': 2,
#  'do': 2,
#  'damage': 1,
#  'control': 2,
#  'threat': 2,
#  'arrives': 1,
#  'teams': 1,
#  'ally': 1,
#  'rescue': 1,
#  'avoid': 1,
#  'doesnt': 2,
#  'most': 2,
#  'harrowing': 1,
#  'adventure': 2,
#  'help': 7,
#  'put': 4,
#  'fun': 1,
#  'back': 3,
#  'longlost': 1,
#  'relative': 1,
#  'aid': 1,
#  'unlocking': 1,
#  'mothers': 1,
#  'jamie': 2,
#  'mailman': 1,
#  'love': 1,
#  'chase': 1,
#  'thats': 1,
#  'been': 2,
#  'loose': 1,
#  'trains': 1,
#  'sword': 2,
#  'fighter': 1,
#  'investigative': 1,
#  'reporting': 1,
#  'whether': 1,
#  'safe': 1,
#  'kindergarten': 3,
#  'dark': 1,
#  'learned': 1,
#  'relax': 2,
#  'slumber': 1,
#  'party': 5,
#  'tv': 2,
#  'interrupted': 1,
#  'disturbance': 1,
#  'trip': 5,
#  'visit': 5,
#  'world': 3,
#  'onions': 2,
#  'house': 2,
#  'play': 1,
#  'founding': 1,
#  'explore': 2,
#  'sneak': 1,
#  'hospital': 1,
#  'recover': 1,
#  'act': 1,
#  'beachapalooza': 1,
#  'we': 1,
#  'finally': 4,
#  'inside': 2,
#  'bathroom': 1,
#  'friend': 3,
#  'whos': 1,
#  'afraid': 1,
#  'thunderstorms': 1,
#  'head': 1,
#  'barn': 4,
#  'robots': 1,
#  'gossip': 1,
#  'she': 2,
#  'came': 2,
#  'birthday': 1,
#  'growing': 1,
#  'moon': 3,
#  'doubts': 1,
#  'believing': 1,
#  'everyone': 2,
#  'sneaks': 1,
#  'listen': 1,
#  'audio': 1,
#  'diary': 1,
#  'happened': 1,
#  'those': 1,
#  'sentient': 1,
#  'created': 1,
#  'journey': 1,
#  'deep': 2,
#  'flies': 1,
#  'two': 3,
#  'along': 1,
#  'engage': 1,
#  'oldfashioned': 1,
#  'game': 1,
#  'baseball': 1,
#  'excited': 1,
#  'jumps': 2,
#  'joy': 1,
#  'too': 2,
#  'high': 1,
#  'sour': 2,
#  'even': 2,
#  'though': 1,
#  'creams': 1,
#  'stepdad': 1,
#  'approve': 1,
#  'djs': 1,
#  'empire': 1,
#  'good': 1,
#  'run': 2,
#  'short': 1,
#  'rollercoasters': 1,
#  'look': 3,
#  'highspeed': 1,
#  'car': 2,
#  'race': 1,
#  'biggest': 3,
#  'foe': 1,
#  'frymans': 1,
#  'pizzas': 1,
#  'settle': 1,
#  'reignited': 1,
#  'rivalry': 1,
#  'restaurants': 1,
#  'projects': 1,
#  'kikis': 1,
#  'dreams': 2,
#  'saves': 1,
#  'asks': 1,
#  'turns': 1,
#  'nightly': 1,
#  'stress': 1,
#  'dream': 2,
#  'reunites': 1,
#  'centipeetle': 1,
#  'boat': 1,
#  'themselves': 1,
#  'dangerous': 1,
#  'water': 1,
#  'tale': 1,
#  'wash': 1,
#  'track': 1,
#  'wilderness': 1,
#  'tracks': 1,
#  'lead': 1,
#  'mystery': 2,
#  'left': 1,
#  'charge': 1,
#  'there': 1,
#  'will': 1,
#  'no': 1,
#  'training': 2,
#  'shes': 1,
#  'competitive': 1,
#  'thought': 1,
#  'lost': 2,
#  'lions': 1,
#  'mane': 1,
#  'country': 1,
#  'isnt': 2,
#  'being': 1,
#  'exact': 1,
#  'revenge': 1,
#  'showdown': 1,
#  'base': 1,
#  'marooned': 1,
#  'deal': 1,
#  'problem': 1,
#  'delve': 1,
#  'visits': 2,
#  'library': 1,
#  'uncovers': 1,
#  'long': 1,
#  'learn': 2,
#  'focus': 1,
#  'better': 1,
#  'peoples': 1,
#  'fortunes': 1,
#  'attend': 2,
#  'rock': 2,
#  'autumn': 1,
#  'brings': 2,
#  'stranger': 1,
#  'winter': 1,
#  'prompts': 1,
#  'search': 2,
#  'recovery': 1,
#  'pull': 1,
#  'heist': 1,
#  'zoo': 1,
#  'daring': 1,
#  'escape': 1,
#  'busy': 1,
#  'sets': 1,
#  'people': 2,
#  'living': 1,
#  'returns': 1,
#  'ring': 1,
#  'continue': 1,
#  'pro': 1,
#  'odyssey': 1,
#  'continues': 1,
#  'grow': 1,
#  'coughs': 1,
#  'key': 1,
#  'quest': 1,
#  'discover': 1,
#  'join': 1,
#  'father': 1,
#  'stake': 1,
#  'invited': 2,
#  'disappearing': 1,
#  'solve': 1,
#  'struggles': 1,
#  'fix': 1,
#  'mistakes': 1,
#  'spend': 1,
#  'trial': 1,
#  'unusual': 1,
#  'allies': 1,
#  'lets': 1,
#  'difficult': 1,
#  'campaign': 1,
#  'pumpkin': 1,
#  'peridot': 1,
#  'spruce': 1,
#  'start': 2,
#  'band': 2,
#  'finding': 1,
#  'sound': 1,
#  'kevin': 1,
#  'throwing': 1,
#  'rises': 1,
#  'occasion': 1,
#  'stevonnie': 1,
#  'themself': 1,
#  'alone': 1,
#  'meet': 1,
#  'shoots': 1,
#  'documentary': 1,
#  'follows': 1,
#  'local': 1,
#  'as': 1,
#  'break': 1,
#  'unlikely': 1,
#  'timelines': 1,
#  'writes': 1,
#  'latest': 1,
#  'news': 1,
#  'spots': 1,
#  'mysterious': 2,
#  'investigate': 1,
#  'phone': 1,
#  'shows': 2,
#  'slicker': 1,
#  'cowboys': 1,
#  'lived': 1,
#  'surprise': 2,
#  'reunion': 1,
#  'travels': 1,
#  'many': 1,
#  'changes': 1,
#  'going': 1,
#  'psychic': 1,
#  'faces': 2,
#  'challenge': 2,
#  'yet': 2,
#  'defending': 1,
#  'earth': 2,
#  'welcome': 1,
#  'little': 4,
#  'homeschool': 3,
#  'universe': 2,
#  'come': 1,
#  'peacefully': 1,
#  'theres': 1,
#  'who': 1,
#  'refuses': 1,
#  'helping': 1,
#  'jobs': 1,
#  'boardwalk': 1,
#  'sure': 2,
#  'approach': 1,
#  'more': 1,
#  'surprising': 1,
#  'introduction': 1,
#  'ones': 1,
#  'pink': 1,
#  'diamonds': 2,
#  'original': 1,
#  'scar': 1,
#  'questions': 1,
#  'motives': 1,
#  'suddenly': 1,
#  'rainbow': 1,
#  'promised': 1,
#  'same': 1,
#  'sunstone': 1,
#  'scheduled': 1,
#  'safety': 1,
#  'geminar': 1,
#  'places': 1,
#  'fusions': 1,
#  'once': 1,
#  'chance': 1,
#  'catch': 1,
#  'theyre': 1,
#  'snowed': 1,
#  'heard': 1,
#  'rumors': 1,
#  'pair': 1,
#  'still': 1,
#  'destroying': 1,
#  'worlds': 1,
#  'if': 1,
#  'maybe': 1,
#  'lapis': 1,
#  'celebrate': 1,
#  'homeschools': 1,
#  'graduating': 1,
#  'class': 1,
#  'leaving': 1,
#  'found': 1,
#  'hobby': 1,
#  'plants': 1,
#  'broadcasting': 1,
#  'onto': 1,
#  'bedroom': 1,
#  'invites': 1,
#  'bismuth': 1,
#  'roller': 1,
#  'rink': 1,
#  'lesson': 1,
#  'forge': 1,
#  'human': 1,
#  'relationships': 1,
#  'very': 1,
#  'clear': 1,
#  'vision': 1,
#  'wants': 1,
#  'hes': 1,
#  'doctor': 1,
#  'origins': 1,
#  'name': 1,
#  'woods': 1,
#  'train': 1,
#  'mentor': 1,
#  'advice': 1,
#  'insists': 1,
#  'everything': 2,
#  'fine': 2,
#  'not': 1,
#  'ready': 1,
#  'move': 1}

# %% [markdown]
# ## Calculating TF-IDF
# According to Wikipedia, term frequency–inverse document frequency (aka tf–idf) is a statistic designed to reflect how important a word is to a document in a collection or corpus and is often used as a weighting factor in information retrieval and text mining. A word or term is considered salient to a particular document if it occurs frequently in that document, but not in the document corpus over all.
#
# Term frequency–inverse document frequency is defined as:
#
# $$\text{tf-idf}(t,d,D)= \text{tf}(t,d) ⋅ \text {idf}(t,D)$$
#
# where _t_ is a term, _d_ is a document (collection of terms), _D_ is the collection of documents, and _tf_ and _idf_ are defined below.
#
# There are several variants of both term frequency (tf) and inverse document frequency (idf) that can be used to compute tf-idf. We will be using augumented frequency as our measure of term frequency, and we will use vanilla inverse document frequency.
#
# The augmented frequency of a term _t_ in a document _d_ is defined as
#
# $$\text {tf}(t,d)=0.5+0.5⋅\frac {f_{t,d}}{\text {max}({f_{t′,d}}:t′∈d)}$$
#
# where $f_{t,d}$ is the number of times the term _t_ appears in the document _d_.
#
# The vanilla inverse document frequency of a term _t_ in a document collection _D_ is defined as
#
# $$\text {idf} (t,D)=\text {log} \frac{N}{| d∈D:t∈d |}$$
# where _N_ is the number of documents in the document collection D.
#
# Use the natural log (math.log) in the _idf_ computation.

# %%
def sort_by_count(token_count):
    '''
    Takes a dictionary of token and counts, and returns a list
    of tuples, sorted as expected
    '''
    return sorted(token_count.items(), key=lambda x: x[1], reverse=True)


def calculate_tf(term, token_count):
    '''
    Calculates the term frequency in a specific document
    
    Inputs:
        - term (str): Term of interest
        - token_count (dict): Dictionary mapping terms to 
                              their frequencies in the doc
    '''
    f_td = token_count[term]
    max_ftd = sort_by_count(token_count)[0][1] 
    
    return 0.5 + (0.5 * (f_td / max_ftd))

# %%
test_d = {"a": 1, "b": 2, "c": 3}
test_sorted = sort_by_count(test_d)
test_sorted
# Out:
# [('c', 3), ('b', 2), ('a', 1)]

# %%
calculate_tf("a", test_d)
# Out:
# 0.6666666666666666

# %%
calculate_tf("b", test_d)
# Out:
# 0.8333333333333333

# %%
calculate_tf("c", test_d)
# Out:
# 1.0

# %%
import math

def count_documents_with_term(term, corpus):
    '''
    Counts the number of documents that contain the term
    
    Inputs:
        - term (str): The term of interest
        - corpus (dict): The collection of documents where the 
            key is some identifier, and the value is a list of
            tokens
    '''
    num_documents=0
    
    for document, tokens in corpus.items():
        if term in tokens:
             num_documents += 1
    
    return num_documents


def calculate_idf(term, corpus):
    '''
    Calculates the vanilla inverse document frequency of a term
    
    Inputs:
        - term (str): The term of interest
        - corpus (dict): The collection of documents where the 
            key is some identifier, and the value is a list of
            tokens
    '''
    docs_with_term = count_documents_with_term(term, corpus)
    
    return math.log(len(corpus) / docs_with_term)


def calculate_tfidf(term, document_tokens, corpus):
    '''
    Calculate the tf-idf of a term in a document, given a corpus
    
    Inputs:
    - term (str): The term of interest
    - document_tokens (list): List of tokens in a document
    - corpus (dict): The collection of documents where the 
            key is some identifier, and the value is a list of
            tokens
    '''
    token_frequency_map = {}
    count_distinct_tokens(document_tokens, token_frequency_map)
    
    tf = calculate_tf(term, token_frequency_map)
    idf = calculate_idf(term, corpus)
    tfidf = tf * idf
        
    return tfidf

# %%
# Test on episode summaries
# Every episode summary is a document
# All episode summaries can be the corpus

corpus = {}

for i in range(len(episodes_df)):
    corpus[episodes_df.loc[i, 'title']] = episodes_df.loc[i, 'list_of_tokens']

# %%
corpus
# Out:
# {'Gem Glow': ['steven',
#   'thinks',
#   'his',
#   'favorite',
#   'ice',
#   'cream',
#   'sandwiches',
#   'are',
#   'the',
#   'trick',
#   'to',
#   'summoning',
#   'his',
#   'magic',
#   'shield',
#   'but',
#   'learns',
#   'otherwise',
#   'when',
#   'facing',
#   'off',
#   'with',
#   'an',
#   'acidspewing',
#   'insect',
#   'monster'],
#  'Laser Light Cannon': ['a',
#   'magical',
#   'comet',
#   'hurtles',
#   'toward',
#   'beach',
#   'city',
#   'and',
#   'steven',
#   'must',
#   'dig',
#   'through',
#   'his',
#   'fathers',
#   'collection',
#   'of',
#   'old',
#   'junk',
#   'and',
#   'the',
#   'past',
#   'to',
#   'find',
#   'the',
#   'weapon',
#   'that',
#   'can',
#   'save',
#   'the',
#   'town'],
#  'Cheeseburger Backpack': ['a',
#   'mission',
#   'to',
#   'the',
#   'lunar',
#   'sea',
#   'spire',
#   'takes',
#   'a',
#   'treacherous',
#   'turn',
#   'but',
#   'steven',
#   'has',
#   'packed',
#   'his',
#   'totally',
#   'amazing',
#   'cheeseburger',
#   'backpack',
#   'with',
#   'anything',
#   'they',
#   'could',
#   'ever',
#   'need'],
#  'Together Breakfast': ['steven',
#   'tries',
#   'to',
#   'get',
#   'the',
#   'crystal',
#   'gems',
#   'to',
#   'take',
#   'part',
#   'in',
#   'his',
#   'special',
#   'breakfast',
#   'tradition',
#   'but',
#   'instead',
#   'finds',
#   'himself',
#   'tumbling',
#   'through',
#   'the',
#   'magical',
#   'rooms',
#   'of',
#   'the',
#   'crystal',
#   'gems',
#   'temple'],
#  'Frybo': ['steven',
#   'helps',
#   'a',
#   'boardie',
#   'kid',
#   'with',
#   'his',
#   'grueling',
#   'job',
#   'by',
#   'using',
#   'a',
#   'magical',
#   'gem',
#   'shard',
#   'that',
#   'can',
#   'bring',
#   'clothing',
#   'to',
#   'life'],
#  'Cat Fingers': ['steven',
#   'attempts',
#   'to',
#   'master',
#   'the',
#   'power',
#   'of',
#   'shape',
#   'shifting',
#   'but',
#   'can',
#   'only',
#   'shape',
#   'shift',
#   'his',
#   'fingers',
#   'into',
#   'tiny',
#   'cat',
#   'heads'],
#  'Bubble Buddies': ['steven',
#   'looks',
#   'like',
#   'a',
#   'hero',
#   'when',
#   'he',
#   'forms',
#   'a',
#   'magic',
#   'crystal',
#   'bubble',
#   'around',
#   'himself',
#   'to',
#   'protect',
#   'a',
#   'girl',
#   'he',
#   'likes',
#   'from',
#   'danger',
#   'but',
#   'then',
#   'panics',
#   'when',
#   'he',
#   'cant',
#   'figure',
#   'out',
#   'how',
#   'to',
#   'turn',
#   'the',
#   'bubble',
#   'off'],
#  'Serious Steven': ['steven',
#   'tries',
#   'to',
#   'prove',
#   'himself',
#   'to',
#   'be',
#   'a',
#   'worthy',
#   'crystal',
#   'gem',
#   'to',
#   'garnet',
#   'while',
#   'they',
#   'navigate',
#   'their',
#   'way',
#   'out',
#   'of',
#   'an',
#   'ancient',
#   'gem',
#   'maze'],
#  'Tiger Millionaire': ['steven',
#   'joins',
#   'amethyst',
#   'in',
#   'an',
#   'underground',
#   'wrestling',
#   'league'],
#  "Steven's Lion": ['steven',
#   'makes',
#   'friends',
#   'with',
#   'a',
#   'magical',
#   'lion',
#   'but',
#   'cant',
#   'quite',
#   'tell',
#   'why',
#   'it',
#   'likes',
#   'him'],
#  'Arcade Mania': ['steven',
#   'takes',
#   'the',
#   'crystal',
#   'gems',
#   'to',
#   'funland',
#   'arcade',
#   'where',
#   'garnet',
#   'learns',
#   'the',
#   'allure',
#   'of',
#   'video',
#   'games'],
#  'Giant Woman': ['during',
#   'a',
#   'mission',
#   'to',
#   'the',
#   'sky',
#   'spire',
#   'steven',
#   'tries',
#   'to',
#   'convince',
#   'amethyst',
#   'and',
#   'pearl',
#   'to',
#   'fuse',
#   'together',
#   'and',
#   'become',
#   'a',
#   'giant',
#   'woman'],
#  'So Many Birthdays': ['steven',
#   'learns',
#   'that',
#   'the',
#   'crystal',
#   'gems',
#   'are',
#   'thousands',
#   'of',
#   'years',
#   'old',
#   'and',
#   'decides',
#   'to',
#   'make',
#   'up',
#   'for',
#   'all',
#   'the',
#   'thousands',
#   'of',
#   'birthdays',
#   'they',
#   'have',
#   'missed'],
#  'Lars and the Cool Kids': ['steven',
#   'and',
#   'lars',
#   'get',
#   'to',
#   'hang',
#   'out',
#   'with',
#   'the',
#   'cool',
#   'kids',
#   'in',
#   'town',
#   'but',
#   'their',
#   'teenage',
#   'shenanigans',
#   'get',
#   'them',
#   'into',
#   'magical',
#   'trouble'],
#  'Onion Trade': ['a',
#   'toy',
#   'trade',
#   'between',
#   'steven',
#   'and',
#   'onion',
#   'escalates',
#   'to',
#   'epic',
#   'proportions'],
#  'Steven the Sword Fighter': ['pearl',
#   'tries',
#   'to',
#   'teach',
#   'steven',
#   'the',
#   'art',
#   'of',
#   'swordfighting',
#   'using',
#   'a',
#   'holographic',
#   'version',
#   'of',
#   'herself'],
#  'Lion 2: The Movie': ['steven',
#   'and',
#   'connie',
#   'try',
#   'to',
#   'ride',
#   'lion',
#   'to',
#   'the',
#   'movie',
#   'theater',
#   'but',
#   'lion',
#   'has',
#   'other',
#   'ideas'],
#  'Beach Party': ['after',
#   'a',
#   'battle',
#   'damages',
#   'fish',
#   'stew',
#   'pizza',
#   'steven',
#   'throws',
#   'a',
#   'cookout',
#   'at',
#   'the',
#   'temple',
#   'to',
#   'mend',
#   'the',
#   'relationship',
#   'between',
#   'the',
#   'pizza',
#   'family',
#   'and',
#   'the',
#   'crystal',
#   'gems'],
#  "Rose's Room": ['stevens',
#   'desire',
#   'for',
#   'some',
#   'alonetime',
#   'unlocks',
#   'a',
#   'new',
#   'room',
#   'in',
#   'the',
#   'temple',
#   'that',
#   'answers',
#   'his',
#   'every',
#   'wish'],
#  'Coach Steven': ['after',
#   'seeing',
#   'garnet',
#   'and',
#   'amethyst',
#   'fuse',
#   'together',
#   'into',
#   'the',
#   'powerful',
#   'sugilite',
#   'steven',
#   'gets',
#   'determined',
#   'to',
#   'become',
#   'super',
#   'strong'],
#  'Joking Victim': ['when',
#   'lars',
#   'pawns',
#   'off',
#   'all',
#   'his',
#   'work',
#   'on',
#   'sadie',
#   'steven',
#   'helps',
#   'out',
#   'by',
#   'working',
#   'a',
#   'shift',
#   'at',
#   'the',
#   'big',
#   'donut'],
#  'Steven and the Stevens': ['steven',
#   'needs',
#   'a',
#   'musical',
#   'partner',
#   'for',
#   'an',
#   'upcoming',
#   'show',
#   'and',
#   'uses',
#   'a',
#   'time',
#   'travel',
#   'device',
#   'to',
#   'recruit',
#   'the',
#   'perfect',
#   'bandmate',
#   'himself'],
#  'Monster Buddies': ['steven',
#   'accidentally',
#   'releases',
#   'a',
#   'monster',
#   'from',
#   'a',
#   'gem',
#   'bubble',
#   'and',
#   'attempts',
#   'to',
#   'tame',
#   'its',
#   'wild',
#   'violent',
#   'instincts'],
#  'An Indirect Kiss': ['when',
#   'amethyst',
#   'cracks',
#   'her',
#   'gemstone',
#   'steven',
#   'and',
#   'the',
#   'crystal',
#   'gems',
#   'go',
#   'on',
#   'a',
#   'mission',
#   'to',
#   'heal',
#   'her'],
#  'Mirror Gem': ['steven',
#   'befriends',
#   'a',
#   'magical',
#   'mirror',
#   'that',
#   'can',
#   'mysteriously',
#   'communicate',
#   'with',
#   'him'],
#  'Ocean Gem': ['the',
#   'ocean',
#   'disappears',
#   'on',
#   'the',
#   'first',
#   'day',
#   'of',
#   'summer',
#   'and',
#   'beach',
#   'city',
#   'is',
#   'in',
#   'a',
#   'panic'],
#  'House Guest': ['after',
#   'injuring',
#   'his',
#   'leg',
#   'greg',
#   'comes',
#   'to',
#   'live',
#   'with',
#   'steven',
#   'and',
#   'unintentionally',
#   'interferes',
#   'with',
#   'stevens',
#   'powers'],
#  'Space Race': ['steven',
#   'attempts',
#   'to',
#   'build',
#   'a',
#   'spaceship',
#   'to',
#   'let',
#   'pearl',
#   'revisit',
#   'the',
#   'wonders',
#   'of',
#   'the',
#   'cosmos'],
#  'Secret Team': ['steven',
#   'amethyst',
#   'and',
#   'pearl',
#   'accidentally',
#   'pop',
#   'a',
#   'bubbled',
#   'gem',
#   'and',
#   'form',
#   'a',
#   'secret',
#   'team',
#   'to',
#   'secretly',
#   'retrieve',
#   'the',
#   'missing',
#   'shards'],
#  'Island Adventure': ['steven',
#   'takes',
#   'lars',
#   'and',
#   'sadie',
#   'on',
#   'a',
#   'vacation',
#   'to',
#   'a',
#   'magical',
#   'beach',
#   'to',
#   'mend',
#   'their',
#   'friendship'],
#  'Keep Beach City Weird': ['steven',
#   'gets',
#   'caught',
#   'up',
#   'in',
#   'ronaldos',
#   'paranormal',
#   'theories',
#   'about',
#   'the',
#   'strange',
#   'occurrences',
#   'in',
#   'beach',
#   'city'],
#  'Fusion Cuisine': ['in',
#   'an',
#   'effort',
#   'to',
#   'win',
#   'over',
#   'connies',
#   'parents',
#   'steven',
#   'convinces',
#   'the',
#   'gems',
#   'to',
#   'fuse',
#   'together',
#   'and',
#   'pretend',
#   'to',
#   'be',
#   'his',
#   'mother'],
#  "Garnet's Universe": ['steven',
#   'imagines',
#   'what',
#   'garnet',
#   'does',
#   'with',
#   'her',
#   'day'],
#  'Watermelon Steven': ['steven',
#   'discovers',
#   'a',
#   'new',
#   'power',
#   'when',
#   'he',
#   'grows',
#   'a',
#   'patch',
#   'of',
#   'stevenshaped',
#   'watermelons'],
#  'Lion 3: Straight to Video': ['lion',
#   'wont',
#   'stop',
#   'laying',
#   'on',
#   'stevens',
#   'face',
#   'while',
#   'he',
#   'sleeps'],
#  'Warp Tour': ['steven',
#   'thinks',
#   'he',
#   'sees',
#   'something',
#   'creepy',
#   'traversing',
#   'the',
#   'warp',
#   'streams',
#   'and',
#   'the',
#   'gems',
#   'try',
#   'to',
#   'ease',
#   'his',
#   'paranoia'],
#  'Alone Together': ['the',
#   'gems',
#   'try',
#   'to',
#   'teach',
#   'steven',
#   'to',
#   'use',
#   'his',
#   'fusion',
#   'powers'],
#  'The Test': ['steven',
#   'finds',
#   'out',
#   'that',
#   'his',
#   'mission',
#   'to',
#   'the',
#   'lunar',
#   'sea',
#   'spire',
#   'was',
#   'simply',
#   'a',
#   'test',
#   'and',
#   'demands',
#   'a',
#   'new',
#   'one'],
#  'Future Vision': ['steven',
#   'learns',
#   'that',
#   'garnet',
#   'can',
#   'see',
#   'into',
#   'the',
#   'future',
#   'and',
#   'becomes',
#   'curious',
#   'about',
#   'the',
#   'possible',
#   'dangers',
#   'that',
#   'lurk',
#   'around',
#   'him'],
#  'On the Run': ['steven',
#   'and',
#   'amethyst',
#   'try',
#   'out',
#   'life',
#   'on',
#   'the',
#   'road'],
#  'Horror Club': ['steven',
#   'goes',
#   'to',
#   'the',
#   'lighthouse',
#   'to',
#   'watch',
#   'scary',
#   'movies',
#   'with',
#   'ronaldo',
#   'lars',
#   'and',
#   'sadie'],
#  'Winter Forecast': ['steven',
#   'has',
#   'to',
#   'get',
#   'connie',
#   'home',
#   'before',
#   'it',
#   'snows'],
#  'Maximum Capacity': ['while',
#   'cleaning',
#   'out',
#   'gregs',
#   'storage',
#   'unit',
#   'greg',
#   'and',
#   'amethyst',
#   'are',
#   'reunited',
#   'with',
#   'their',
#   'favorite',
#   'sitcom',
#   'lil',
#   'butler'],
#  'Marble Madness': ['steven',
#   'and',
#   'the',
#   'gems',
#   'encounter',
#   'another',
#   'droid',
#   'from',
#   'space'],
#  "Rose's Scabbard": ['steven',
#   'joins',
#   'pearl',
#   'on',
#   'a',
#   'special',
#   'mission',
#   'to',
#   'a',
#   'place',
#   'that',
#   'belonged',
#   'to',
#   'rose',
#   'quartz'],
#  'Open Book': ['steven',
#   'and',
#   'connie',
#   'want',
#   'a',
#   'new',
#   'ending',
#   'to',
#   'a',
#   'beloved',
#   'book',
#   'series',
#   'so',
#   'steven',
#   'takes',
#   'them',
#   'into',
#   'roses',
#   'room',
#   'to',
#   'reenact',
#   'it'],
#  'Shirt Club': ['steven',
#   'and',
#   'buck',
#   'dewey',
#   'make',
#   'tshirts',
#   'together'],
#  'Story for Steven': ['greg',
#   'tells',
#   'steven',
#   'the',
#   'full',
#   'story',
#   'of',
#   'how',
#   'he',
#   'met',
#   'rose',
#   'quartz'],
#  'The Message': ['steven',
#   'and',
#   'the',
#   'gems',
#   'try',
#   'to',
#   'retrieve',
#   'a',
#   'message',
#   'from',
#   'the',
#   'wailing',
#   'stone'],
#  'Political Power': ['the',
#   'crystal',
#   'gems',
#   'cause',
#   'a',
#   'power',
#   'outage',
#   'in',
#   'beach',
#   'city',
#   'so',
#   'steven',
#   'helps',
#   'mayor',
#   'dewey',
#   'do',
#   'damage',
#   'control'],
#  'The Return': ['a', 'new', 'threat', 'arrives', 'in', 'beach', 'city'],
#  'Jail Break': ['steven',
#   'teams',
#   'up',
#   'with',
#   'a',
#   'new',
#   'ally',
#   'to',
#   'rescue',
#   'the',
#   'gems'],
#  'Full Disclosure': ['steven',
#   'tries',
#   'to',
#   'avoid',
#   'connie',
#   'so',
#   'he',
#   'doesnt',
#   'have',
#   'to',
#   'tell',
#   'her',
#   'about',
#   'his',
#   'most',
#   'harrowing',
#   'adventure'],
#  'Joy Ride': ['the',
#   'cool',
#   'kids',
#   'help',
#   'steven',
#   'put',
#   'some',
#   'fun',
#   'back',
#   'in',
#   'his',
#   'life'],
#  'Say Uncle': ['a',
#   'longlost',
#   'relative',
#   'of',
#   'stevens',
#   'comes',
#   'to',
#   'town',
#   'to',
#   'aid',
#   'him',
#   'in',
#   'unlocking',
#   'the',
#   'power',
#   'of',
#   'his',
#   'mothers',
#   'gem'],
#  'Love Letters': ['steven',
#   'and',
#   'connie',
#   'help',
#   'jamie',
#   'the',
#   'mailman',
#   'with',
#   'love'],
#  'Reformed': ['steven',
#   'amethyst',
#   'and',
#   'garnet',
#   'chase',
#   'after',
#   'a',
#   'monster',
#   'thats',
#   'been',
#   'loose',
#   'in',
#   'the',
#   'temple'],
#  'Sworn to the Sword': ['connie',
#   'trains',
#   'with',
#   'pearl',
#   'to',
#   'be',
#   'a',
#   'sword',
#   'fighter'],
#  'Rising Tides, Crashing Skies': ['ronaldo',
#   'does',
#   'some',
#   'investigative',
#   'reporting',
#   'on',
#   'whether',
#   'steven',
#   'and',
#   'the',
#   'crystal',
#   'gems',
#   'are',
#   'safe',
#   'for',
#   'beach',
#   'city'],
#  'Keeping It Together': ['steven',
#   'and',
#   'the',
#   'crystal',
#   'gems',
#   'revisit',
#   'the',
#   'kindergarten',
#   'and',
#   'find',
#   'a',
#   'dark',
#   'secret'],
#  'We Need to Talk': ['greg',
#   'tells',
#   'steven',
#   'and',
#   'connie',
#   'the',
#   'story',
#   'of',
#   'how',
#   'he',
#   'learned',
#   'about',
#   'gem',
#   'fusion'],
#  'Chille Tid': ['steven',
#   'and',
#   'the',
#   'crystal',
#   'gems',
#   'try',
#   'to',
#   'relax',
#   'with',
#   'a',
#   'slumber',
#   'party'],
#  'Cry for Help': ['stevens',
#   'favorite',
#   'tv',
#   'show',
#   'gets',
#   'interrupted',
#   'by',
#   'a',
#   'magical',
#   'disturbance'],
#  'Keystone Motel': ['steven',
#   'greg',
#   'and',
#   'garnet',
#   'go',
#   'on',
#   'a',
#   'road',
#   'trip'],
#  'Onion Friend': ['steven',
#   'and',
#   'amethyst',
#   'visit',
#   'the',
#   'strange',
#   'world',
#   'of',
#   'onions',
#   'house'],
#  'Historical Friction': ['steven',
#   'and',
#   'jamie',
#   'put',
#   'on',
#   'a',
#   'play',
#   'about',
#   'the',
#   'founding',
#   'of',
#   'beach',
#   'city'],
#  'Friend Ship': ['the',
#   'crystal',
#   'gems',
#   'explore',
#   'an',
#   'ancient',
#   'gem',
#   'spaceship'],
#  'Nightmare Hospital': ['steven',
#   'and',
#   'connie',
#   'sneak',
#   'into',
#   'a',
#   'hospital',
#   'to',
#   'recover',
#   'roses',
#   'sword'],
#  "Sadie's Song": ['steven',
#   'helps',
#   'sadie',
#   'put',
#   'together',
#   'an',
#   'act',
#   'for',
#   'beachapalooza'],
#  'Catch and Release': ['we',
#   'finally',
#   'see',
#   'inside',
#   'stevens',
#   'bathroom'],
#  'When It Rains': ['steven',
#   'helps',
#   'a',
#   'friend',
#   'whos',
#   'afraid',
#   'of',
#   'thunderstorms'],
#  'Back to the Barn': ['steven',
#   'and',
#   'the',
#   'gems',
#   'head',
#   'back',
#   'to',
#   'the',
#   'family',
#   'barn',
#   'to',
#   'build',
#   'some',
#   'robots'],
#  'Too Far': ['steven',
#   'and',
#   'amethyst',
#   'get',
#   'in',
#   'on',
#   'some',
#   'gem',
#   'gossip'],
#  'The Answer': ['garnet',
#   'finally',
#   'tells',
#   'steven',
#   'the',
#   'story',
#   'of',
#   'how',
#   'she',
#   'came',
#   'to',
#   'be',
#   'a',
#   'crystal',
#   'gem'],
#  "Steven's Birthday": ['steven',
#   'has',
#   'a',
#   'birthday',
#   'party',
#   'out',
#   'at',
#   'the',
#   'barn',
#   'and',
#   'decides',
#   'he',
#   'has',
#   'some',
#   'growing',
#   'up',
#   'to',
#   'do'],
#  "It Could've Been Great": ['the',
#   'gems',
#   'take',
#   'a',
#   'trip',
#   'to',
#   'the',
#   'moon'],
#  'Message Received': ['steven',
#   'has',
#   'doubts',
#   'about',
#   'believing',
#   'in',
#   'everyone'],
#  'Log Date 7 15 2': ['steven',
#   'sneaks',
#   'a',
#   'listen',
#   'to',
#   'a',
#   'friends',
#   'audio',
#   'diary'],
#  'Super Watermelon Island': ['steven',
#   'finds',
#   'out',
#   'what',
#   'happened',
#   'to',
#   'all',
#   'those',
#   'sentient',
#   'watermelons',
#   'he',
#   'created'],
#  'Gem Drill': ['steven', 'takes', 'a', 'journey', 'deep', 'underground'],
#  'Same Old World': ['steven', 'flies', 'around', 'the', 'world'],
#  'Barn Mates': ['steven',
#   'helps',
#   'two',
#   'friends',
#   'get',
#   'along',
#   'at',
#   'the',
#   'barn'],
#  'Hit the Diamond': ['steven',
#   'and',
#   'the',
#   'gems',
#   'engage',
#   'in',
#   'an',
#   'oldfashioned',
#   'game',
#   'of',
#   'baseball'],
#  'Steven Floats': ['steven',
#   'is',
#   'so',
#   'excited',
#   'to',
#   'be',
#   'back',
#   'home',
#   'that',
#   'he',
#   'jumps',
#   'for',
#   'joy',
#   'and',
#   'jumps',
#   'way',
#   'too',
#   'high'],
#  'Drop Beat Dad': ['steven',
#   'helps',
#   'sour',
#   'cream',
#   'put',
#   'on',
#   'a',
#   'show',
#   'even',
#   'though',
#   'sour',
#   'creams',
#   'stepdad',
#   'doesnt',
#   'approve',
#   'of',
#   'djs'],
#  'Mr. Greg': ['steven',
#   'greg',
#   'and',
#   'pearl',
#   'take',
#   'a',
#   'trip',
#   'to',
#   'empire',
#   'city',
#   'to',
#   'live',
#   'the',
#   'good',
#   'life'],
#  'Too Short to Ride': ['steven',
#   'and',
#   'amethyst',
#   'take',
#   'a',
#   'trip',
#   'to',
#   'funland',
#   'but',
#   'run',
#   'into',
#   'trouble',
#   'when',
#   'their',
#   'friend',
#   'is',
#   'too',
#   'short',
#   'to',
#   'ride',
#   'the',
#   'rollercoasters'],
#  'The New Lars': ['steven',
#   'gets',
#   'a',
#   'new',
#   'look',
#   'into',
#   'lars',
#   'life'],
#  'Beach City Drift': ['steven',
#   'and',
#   'connie',
#   'get',
#   'into',
#   'a',
#   'highspeed',
#   'car',
#   'race',
#   'with',
#   'their',
#   'biggest',
#   'foe'],
#  'Restaurant Wars': ['steven',
#   'must',
#   'help',
#   'the',
#   'frymans',
#   'and',
#   'the',
#   'pizzas',
#   'settle',
#   'a',
#   'reignited',
#   'rivalry',
#   'between',
#   'their',
#   'restaurants'],
#  "Kiki's Pizza Delivery Service": ['when',
#   'steven',
#   'accidentally',
#   'projects',
#   'himself',
#   'into',
#   'kikis',
#   'dreams',
#   'and',
#   'saves',
#   'her',
#   'from',
#   'a',
#   'giant',
#   'pizza',
#   'monster',
#   'she',
#   'asks',
#   'him',
#   'to',
#   'help',
#   'her',
#   'out',
#   'with',
#   'what',
#   'turns',
#   'out',
#   'to',
#   'be',
#   'a',
#   'nightly',
#   'stress',
#   'dream'],
#  'Monster Reunion': ['steven',
#   'reunites',
#   'with',
#   'an',
#   'old',
#   'friend',
#   'centipeetle'],
#  'Alone at Sea': ['steven',
#   'and',
#   'greg',
#   'take',
#   'a',
#   'boat',
#   'trip',
#   'out',
#   'to',
#   'sea',
#   'and',
#   'find',
#   'themselves',
#   'in',
#   'dangerous',
#   'water'],
#  'Greg the Babysitter': ['steven',
#   'learns',
#   'the',
#   'tale',
#   'of',
#   'how',
#   'greg',
#   'came',
#   'to',
#   'work',
#   'at',
#   'the',
#   'car',
#   'wash'],
#  'Gem Hunt': ['steven',
#   'and',
#   'connie',
#   'track',
#   'a',
#   'gem',
#   'monster',
#   'through',
#   'the',
#   'wilderness',
#   'but',
#   'her',
#   'tracks',
#   'lead',
#   'them',
#   'to',
#   'mystery'],
#  'Crack the Whip': ['amethyst',
#   'is',
#   'left',
#   'in',
#   'charge',
#   'of',
#   'steven',
#   'and',
#   'connie',
#   'and',
#   'there',
#   'will',
#   'be',
#   'no',
#   'training',
#   'while',
#   'shes',
#   'around'],
#  'Steven vs. Amethyst': ['steven',
#   'and',
#   'amethyst',
#   'get',
#   'competitive',
#   'while',
#   'training',
#   'with',
#   'pearl'],
#  'Bismuth': ['steven',
#   'discovers',
#   'something',
#   'the',
#   'gems',
#   'thought',
#   'was',
#   'lost',
#   'to',
#   'the',
#   'past',
#   'inside',
#   'of',
#   'lions',
#   'mane'],
#  'Beta': ['steven',
#   'and',
#   'amethyst',
#   'visit',
#   'some',
#   'friends',
#   'in',
#   'the',
#   'country',
#   'but',
#   'amethyst',
#   'isnt',
#   'being',
#   'herself'],
#  'Earthlings': ['amethyst',
#   'tries',
#   'to',
#   'exact',
#   'revenge',
#   'with',
#   'a',
#   'showdown',
#   'in',
#   'the',
#   'kindergarten'],
#  'Back to the Moon': ['steven',
#   'and',
#   'the',
#   'gems',
#   'revisit',
#   'the',
#   'moon',
#   'base'],
#  'Bubbled': ['steven', 'gets', 'marooned', 'in', 'his', 'bubble'],
#  'Kindergarten Kid': ['steven',
#   'and',
#   'the',
#   'gems',
#   'deal',
#   'with',
#   'a',
#   'monster',
#   'problem'],
#  'Know Your Fusion': ['steven',
#   'and',
#   'the',
#   'gems',
#   'delve',
#   'deep',
#   'into',
#   'what',
#   'makes',
#   'a',
#   'fusion',
#   'so',
#   'special'],
#  "Buddy's Book": ['steven',
#   'visits',
#   'the',
#   'library',
#   'with',
#   'connie',
#   'and',
#   'uncovers',
#   'a',
#   'long',
#   'lost',
#   'book'],
#  'Mindful Education': ['steven',
#   'and',
#   'connie',
#   'learn',
#   'to',
#   'focus',
#   'better'],
#  'Future Boy Zoltron': ['steven',
#   'tells',
#   'peoples',
#   'fortunes',
#   'at',
#   'funland'],
#  'Last One Out of Beach City': ['steven',
#   'pearl',
#   'and',
#   'amethyst',
#   'attend',
#   'a',
#   'rock',
#   'show'],
#  'Onion Gang': ['steven',
#   'finds',
#   'out',
#   'about',
#   'onions',
#   'secret',
#   'friends'],
#  'Gem Harvest': ['stevens',
#   'autumn',
#   'visit',
#   'to',
#   'the',
#   'barn',
#   'brings',
#   'a',
#   'new',
#   'stranger',
#   'into',
#   'his',
#   'life'],
#  'Three Gems and a Baby': ['greg',
#   'tells',
#   'steven',
#   'about',
#   'their',
#   'first',
#   'winter',
#   'together'],
#  "Steven's Dream": ['a',
#   'strange',
#   'dream',
#   'prompts',
#   'steven',
#   'to',
#   'search',
#   'for',
#   'answers'],
#  'Adventures in Light Distortion': ['steven',
#   'and',
#   'the',
#   'gems',
#   'take',
#   'off',
#   'on',
#   'a',
#   'search',
#   'and',
#   'recovery',
#   'mission'],
#  'Gem Heist': ['the', 'gems', 'try', 'to', 'pull', 'off', 'a', 'heist'],
#  'The Zoo': ['steven', 'visits', 'a', 'special', 'zoo'],
#  'That Will Be All': ['steven',
#   'and',
#   'the',
#   'gems',
#   'make',
#   'a',
#   'daring',
#   'escape'],
#  'The New Crystal Gems': ['connie',
#   'helps',
#   'look',
#   'after',
#   'beach',
#   'city',
#   'while',
#   'steven',
#   'is',
#   'busy'],
#  'Storm in the Room': ['steven',
#   'goes',
#   'into',
#   'his',
#   'room',
#   'in',
#   'the',
#   'temple',
#   'to',
#   'look',
#   'for',
#   'answers'],
#  'Rocknaldo': ['ronaldo',
#   'sets',
#   'out',
#   'to',
#   'find',
#   'all',
#   'the',
#   'rock',
#   'people',
#   'living',
#   'in',
#   'beach',
#   'city'],
#  'Tiger Philanthropist': ['steven',
#   'returns',
#   'to',
#   'the',
#   'ring',
#   'to',
#   'continue',
#   'his',
#   'pro',
#   'wrestling',
#   'odyssey'],
#  'Room for Ruby': ['stevens', 'gem', 'family', 'continues', 'to', 'grow'],
#  'Lion 4: Alternate Ending': ['when',
#   'lion',
#   'coughs',
#   'up',
#   'a',
#   'magical',
#   'key',
#   'steven',
#   'goes',
#   'on',
#   'a',
#   'quest',
#   'to',
#   'discover',
#   'what',
#   'it',
#   'unlocks'],
#  'Doug Out': ['steven',
#   'and',
#   'connie',
#   'join',
#   'connies',
#   'father',
#   'on',
#   'a',
#   'stake',
#   'out'],
#  'The Good Lars': ['steven',
#   'lars',
#   'and',
#   'sadie',
#   'get',
#   'invited',
#   'to',
#   'a',
#   'party',
#   'with',
#   'the',
#   'cool',
#   'kids'],
#  'Are You My Dad?': ['people',
#   'are',
#   'disappearing',
#   'from',
#   'beach',
#   'city',
#   'and',
#   'steven',
#   'tries',
#   'to',
#   'solve',
#   'the',
#   'mystery'],
#  'I Am My Mom': ['steven', 'struggles', 'to', 'fix', 'his', 'mistakes'],
#  'Stuck Together': ['steven',
#   'and',
#   'lars',
#   'spend',
#   'some',
#   'time',
#   'together'],
#  'The Trial': ['steven', 'goes', 'on', 'trial'],
#  'Off Colors': ['steven', 'finds', 'some', 'unusual', 'new', 'allies'],
#  "Lars' Head": ['lars', 'finally', 'lets', 'steven', 'in'],
#  'Dewey Wins[22]': ['steven',
#   'helps',
#   'mayor',
#   'dewey',
#   'run',
#   'a',
#   'difficult',
#   'campaign'],
#  'Gemcation': ['greg',
#   'and',
#   'the',
#   'gems',
#   'take',
#   'steven',
#   'on',
#   'vacation',
#   'to',
#   'help',
#   'him',
#   'relax'],
#  'Raising the Barn': ['pumpkin', 'goes', 'missing'],
#  'Back to the Kindergarten': ['steven',
#   'amethyst',
#   'and',
#   'peridot',
#   'try',
#   'to',
#   'spruce',
#   'up',
#   'the',
#   'kindergarten'],
#  'Sadie Killer': ['steven',
#   'and',
#   'the',
#   'cool',
#   'kids',
#   'start',
#   'a',
#   'band',
#   'but',
#   'they',
#   'have',
#   'trouble',
#   'finding',
#   'their',
#   'sound'],
#  'Kevin Party': ['kevin',
#   'is',
#   'throwing',
#   'a',
#   'party',
#   'and',
#   'steven',
#   'is',
#   'invited'],
#  'Lars of the Stars': ['lars', 'rises', 'to', 'the', 'occasion'],
#  'Jungle Moon': ['stevonnie',
#   'finds',
#   'themself',
#   'alone',
#   'on',
#   'an',
#   'adventure'],
#  'Your Mother and Mine': ['steven',
#   'takes',
#   'garnet',
#   'to',
#   'meet',
#   'some',
#   'of',
#   'his',
#   'new',
#   'friends'],
#  'The Big Show': ['steven',
#   'shoots',
#   'a',
#   'documentary',
#   'that',
#   'follows',
#   'a',
#   'local',
#   'band',
#   'as',
#   'they',
#   'get',
#   'their',
#   'first',
#   'big',
#   'break'],
#  'Pool Hopping': ['garnet',
#   'and',
#   'steven',
#   'explore',
#   'the',
#   'most',
#   'unlikely',
#   'timelines',
#   'in',
#   'beach',
#   'city'],
#  'Letters to Lars': ['steven',
#   'writes',
#   'about',
#   'the',
#   'latest',
#   'news',
#   'of',
#   'beach',
#   'city'],
#  "Can't Go Back[24]": ['ronaldo',
#   'spots',
#   'something',
#   'mysterious',
#   'on',
#   'the',
#   'moon',
#   'and',
#   'steven',
#   'goes',
#   'to',
#   'investigate'],
#  'A Single Pale Rose[24]': ['steven',
#   'helps',
#   'pearl',
#   'find',
#   'her',
#   'phone'],
#  "Now We're Only Falling Apart": ['pearl', 'tells', 'a', 'story'],
#  "What's Your Problem?": ['amethyst',
#   'convinces',
#   'steven',
#   'to',
#   'take',
#   'a',
#   'day',
#   'off',
#   'for',
#   'himself'],
#  'The Question': ['steven',
#   'shows',
#   'some',
#   'city',
#   'slicker',
#   'gems',
#   'how',
#   'the',
#   'cowboys',
#   'lived'],
#  'Made of Honor': ['steven',
#   'has',
#   'a',
#   'big',
#   'surprise',
#   'for',
#   'the',
#   'crystal',
#   'gems'],
#  'Reunited': ['steven',
#   'brings',
#   'everyone',
#   'together',
#   'for',
#   'a',
#   'special',
#   'reunion'],
#  'Legs From Here to Homeworld': ['steven',
#   'travels',
#   'to',
#   'visit',
#   'his',
#   'family'],
#  'Familiar': ['with',
#   'many',
#   'changes',
#   'going',
#   'on',
#   'in',
#   'his',
#   'life',
#   'steven',
#   'tries',
#   'to',
#   'find',
#   'his',
#   'place',
#   'in',
#   'the',
#   'world'],
#  'Together Alone': ['steven',
#   'throws',
#   'a',
#   'party',
#   'to',
#   'bring',
#   'his',
#   'family',
#   'together'],
#  'Escapism': ['steven',
#   'uses',
#   'his',
#   'psychic',
#   'powers',
#   'to',
#   'find',
#   'help'],
#  'Change Your Mind': ['steven', 'faces', 'his', 'biggest', 'challenge', 'yet'],
#  'Steven Universe: The Movie': ['steven',
#   'thinks',
#   'his',
#   'time',
#   'defending',
#   'the',
#   'earth',
#   'is',
#   'over',
#   'but',
#   'when',
#   'a',
#   'new',
#   'threat',
#   'comes',
#   'to',
#   'beach',
#   'city',
#   'steven',
#   'faces',
#   'his',
#   'biggest',
#   'challenge',
#   'yet'],
#  'Little Homeschool': ['welcome',
#   'to',
#   'little',
#   'homeschool',
#   'a',
#   'place',
#   'on',
#   'earth',
#   'where',
#   'gems',
#   'from',
#   'all',
#   'over',
#   'the',
#   'universe',
#   'can',
#   'come',
#   'learn',
#   'how',
#   'to',
#   'live',
#   'together',
#   'peacefully',
#   'but',
#   'theres',
#   'one',
#   'gem',
#   'who',
#   'refuses',
#   'to',
#   'attend'],
#  'Guidance': ['amethyst',
#   'has',
#   'been',
#   'helping',
#   'little',
#   'homeschool',
#   'gems',
#   'find',
#   'jobs',
#   'on',
#   'the',
#   'boardwalk',
#   'but',
#   'steven',
#   'isnt',
#   'sure',
#   'about',
#   'her',
#   'approach'],
#  'Rose Buds': ['steven',
#   'gets',
#   'a',
#   'surprise',
#   'visit',
#   'from',
#   'some',
#   'old',
#   'friends',
#   'and',
#   'an',
#   'even',
#   'more',
#   'surprising',
#   'introduction',
#   'to',
#   'some',
#   'new',
#   'ones'],
#  'Volleyball': ['steven',
#   'is',
#   'determined',
#   'to',
#   'help',
#   'pink',
#   'diamonds',
#   'original',
#   'pearl',
#   'heal',
#   'the',
#   'scar',
#   'on',
#   'her',
#   'face'],
#  'Bluebird': ['steven',
#   'questions',
#   'the',
#   'motives',
#   'of',
#   'a',
#   'mysterious',
#   'fusion',
#   'that',
#   'suddenly',
#   'shows',
#   'up',
#   'at',
#   'his',
#   'house'],
#  'A Very Special Episode': ['rainbow',
#   'quartz',
#   'promised',
#   'to',
#   'hang',
#   'out',
#   'with',
#   'onion',
#   'the',
#   'same',
#   'day',
#   'sunstone',
#   'scheduled',
#   'a',
#   'home',
#   'safety',
#   'geminar',
#   'how',
#   'can',
#   'steven',
#   'be',
#   'in',
#   'two',
#   'places',
#   'and',
#   'two',
#   'fusions',
#   'at',
#   'once'],
#  'Snow Day': ['steven',
#   'and',
#   'the',
#   'crystal',
#   'gems',
#   'get',
#   'a',
#   'chance',
#   'to',
#   'catch',
#   'up',
#   'when',
#   'theyre',
#   'all',
#   'snowed',
#   'in',
#   'together'],
#  'Why So Blue?': ['steven',
#   'has',
#   'heard',
#   'rumors',
#   'of',
#   'a',
#   'pair',
#   'of',
#   'gems',
#   'that',
#   'are',
#   'still',
#   'destroying',
#   'worlds',
#   'if',
#   'he',
#   'cant',
#   'stop',
#   'them',
#   'maybe',
#   'lapis',
#   'can'],
#  'Little Graduation': ['steven',
#   'and',
#   'the',
#   'gems',
#   'celebrate',
#   'little',
#   'homeschools',
#   'first',
#   'graduating',
#   'class'],
#  'Prickly Pair': ['after',
#   'leaving',
#   'little',
#   'homeschool',
#   'steven',
#   'has',
#   'found',
#   'a',
#   'new',
#   'hobby',
#   'plants'],
#  'In Dreams': ['stevens',
#   'dreams',
#   'start',
#   'broadcasting',
#   'onto',
#   'his',
#   'bedroom',
#   'tv'],
#  'Bismuth Casual': ['pearl',
#   'invites',
#   'bismuth',
#   'to',
#   'the',
#   'roller',
#   'rink',
#   'for',
#   'a',
#   'lesson',
#   'on',
#   'how',
#   'to',
#   'forge',
#   'human',
#   'relationships'],
#  'Together Forever': ['connie',
#   'has',
#   'a',
#   'very',
#   'clear',
#   'vision',
#   'of',
#   'her',
#   'future',
#   'and',
#   'steven',
#   'wants',
#   'to',
#   'make',
#   'sure',
#   'hes',
#   'a',
#   'part',
#   'of',
#   'it'],
#  'Growing Pains': ['steven',
#   'sees',
#   'a',
#   'doctor',
#   'for',
#   'the',
#   'first',
#   'time'],
#  'Mr. Universe': ['greg',
#   'takes',
#   'steven',
#   'on',
#   'the',
#   'road',
#   'to',
#   'find',
#   'the',
#   'origins',
#   'of',
#   'the',
#   'universe',
#   'name'],
#  'Fragments': ['steven',
#   'heads',
#   'to',
#   'the',
#   'woods',
#   'to',
#   'train',
#   'with',
#   'a',
#   'powerful',
#   'mentor'],
#  'Homeworld Bound': ['steven',
#   'heads',
#   'to',
#   'the',
#   'diamonds',
#   'for',
#   'advice',
#   'on',
#   'how',
#   'to',
#   'control',
#   'his',
#   'new',
#   'powers'],
#  "Everything's Fine": ['steven',
#   'insists',
#   'that',
#   'everything',
#   'is',
#   'fine'],
#  'I Am My Monster': ['everything', 'is', 'not', 'fine'],
#  'The Future': ['steven', 'is', 'finally', 'ready', 'to', 'move', 'on']}

# %%
# Find most salient

def build_dictionary(document, corpus):
    '''
    Build a dictionary that maps tokens in a specific doc to their
    tf-idf values.

    Inputs:
        - document (list): a list of tokens
        - corpus (dict): maps an identifier to a list of tokens

    Returns: dictionary i.e., {token: tf-idf}
    '''
    token_to_tfidf = {}

    for token in document:
        if token not in token_to_tfidf:
            token_to_tfidf[token] = calculate_tfidf(token, document, corpus)

    return token_to_tfidf


def find_most_salient(corpus, k):
    '''
    Takes a collection of documents and an integer k and returns 
    a dictionary of the k most salient terms, that is, the terms with 
    the highest tf–idf, for each document. 
    
    Inputs:
        - corpus (dict): maps an identifier to a list of tokens
        - k (int): number of terms per document to pull
        
    Returns a dictionary where the key is the identifier, and the 
        value, a list of the k most salient terms
    '''
    
    k_most_salient = {}

    for doc_id, tokens in corpus.items():
        most_salient_by_doc = []

        if tokens:
            token_to_tfidf = build_dictionary(tokens, corpus)
            sorted_list = sort_by_count(token_to_tfidf)

            for token, count in sorted_list[:k]:
                most_salient_by_doc.append(token)

        k_most_salient[doc_id] = most_salient_by_doc

    return k_most_salient

# %%
most_salient = find_most_salient(corpus, 3)

# %%
most_salient
# Out:
# {'Gem Glow': ['ice', 'sandwiches', 'trick'],
#  'Laser Light Cannon': ['comet', 'hurtles', 'toward'],
#  'Cheeseburger Backpack': ['treacherous', 'packed', 'totally'],
#  'Together Breakfast': ['breakfast', 'tradition', 'instead'],
#  'Frybo': ['boardie', 'kid', 'grueling'],
#  'Cat Fingers': ['shape', 'master', 'shifting'],
#  'Bubble Buddies': ['looks', 'like', 'hero'],
#  'Serious Steven': ['prove', 'worthy', 'navigate'],
#  'Tiger Millionaire': ['league', 'joins', 'underground'],
#  "Steven's Lion": ['quite', 'why', 'makes'],
#  'Arcade Mania': ['arcade', 'allure', 'video'],
#  'Giant Woman': ['during', 'sky', 'convince'],
#  'So Many Birthdays': ['thousands', 'years', 'birthdays'],
#  'Lars and the Cool Kids': ['teenage', 'shenanigans', 'hang'],
#  'Onion Trade': ['toy', 'trade', 'escalates'],
#  'Steven the Sword Fighter': ['art', 'swordfighting', 'holographic'],
#  'Lion 2: The Movie': ['movie', 'theater', 'other'],
#  'Beach Party': ['pizza', 'battle', 'damages'],
#  "Rose's Room": ['desire', 'alonetime', 'every'],
#  'Coach Steven': ['seeing', 'sugilite', 'super'],
#  'Joking Victim': ['pawns', 'working', 'donut'],
#  'Steven and the Stevens': ['needs', 'musical', 'partner'],
#  'Monster Buddies': ['releases', 'tame', 'its'],
#  'An Indirect Kiss': ['cracks', 'gemstone', 'go'],
#  'Mirror Gem': ['befriends', 'mirror', 'mysteriously'],
#  'Ocean Gem': ['ocean', 'disappears', 'summer'],
#  'House Guest': ['injuring', 'leg', 'unintentionally'],
#  'Space Race': ['let', 'wonders', 'cosmos'],
#  'Secret Team': ['pop', 'bubbled', 'form'],
#  'Island Adventure': ['friendship', 'vacation', 'mend'],
#  'Keep Beach City Weird': ['caught', 'ronaldos', 'paranormal'],
#  'Fusion Cuisine': ['effort', 'win', 'parents'],
#  "Garnet's Universe": ['imagines', 'does', 'day'],
#  'Watermelon Steven': ['grows', 'patch', 'stevenshaped'],
#  'Lion 3: Straight to Video': ['wont', 'laying', 'sleeps'],
#  'Warp Tour': ['creepy', 'traversing', 'warp'],
#  'Alone Together': ['use', 'teach', 'fusion'],
#  'The Test': ['simply', 'test', 'demands'],
#  'Future Vision': ['becomes', 'curious', 'possible'],
#  'On the Run': ['road', 'life', 'try'],
#  'Horror Club': ['lighthouse', 'watch', 'scary'],
#  'Winter Forecast': ['before', 'snows', 'home'],
#  'Maximum Capacity': ['cleaning', 'gregs', 'storage'],
#  'Marble Madness': ['encounter', 'another', 'droid'],
#  "Rose's Scabbard": ['belonged', 'joins', 'rose'],
#  'Open Book': ['want', 'ending', 'beloved'],
#  'Shirt Club': ['buck', 'tshirts', 'dewey'],
#  'Story for Steven': ['full', 'met', 'rose'],
#  'The Message': ['message', 'wailing', 'stone'],
#  'Political Power': ['cause', 'outage', 'damage'],
#  'The Return': ['arrives', 'threat', 'new'],
#  'Jail Break': ['teams', 'ally', 'rescue'],
#  'Full Disclosure': ['avoid', 'harrowing', 'doesnt'],
#  'Joy Ride': ['fun', 'back', 'cool'],
#  'Say Uncle': ['longlost', 'relative', 'aid'],
#  'Love Letters': ['mailman', 'love', 'jamie'],
#  'Reformed': ['chase', 'thats', 'loose'],
#  'Sworn to the Sword': ['trains', 'fighter', 'sword'],
#  'Rising Tides, Crashing Skies': ['investigative', 'reporting', 'whether'],
#  'Keeping It Together': ['dark', 'revisit', 'kindergarten'],
#  'We Need to Talk': ['learned', 'story', 'fusion'],
#  'Chille Tid': ['slumber', 'relax', 'party'],
#  'Cry for Help': ['interrupted', 'disturbance', 'tv'],
#  'Keystone Motel': ['go', 'road', 'trip'],
#  'Onion Friend': ['onions', 'house', 'strange'],
#  'Historical Friction': ['play', 'founding', 'jamie'],
#  'Friend Ship': ['explore', 'ancient', 'spaceship'],
#  'Nightmare Hospital': ['sneak', 'hospital', 'recover'],
#  "Sadie's Song": ['act', 'beachapalooza', 'put'],
#  'Catch and Release': ['we', 'bathroom', 'see'],
#  'When It Rains': ['whos', 'afraid', 'thunderstorms'],
#  'Back to the Barn': ['head', 'robots', 'build'],
#  'Too Far': ['gossip', 'get', 'some'],
#  'The Answer': ['she', 'came', 'finally'],
#  "Steven's Birthday": ['birthday', 'growing', 'decides'],
#  "It Could've Been Great": ['moon', 'trip', 'take'],
#  'Message Received': ['doubts', 'believing', 'everyone'],
#  'Log Date 7 15 2': ['sneaks', 'listen', 'audio'],
#  'Super Watermelon Island': ['happened', 'those', 'sentient'],
#  'Gem Drill': ['journey', 'deep', 'underground'],
#  'Same Old World': ['flies', 'world', 'around'],
#  'Barn Mates': ['along', 'two', 'barn'],
#  'Hit the Diamond': ['engage', 'oldfashioned', 'game'],
#  'Steven Floats': ['jumps', 'excited', 'joy'],
#  'Drop Beat Dad': ['sour', 'though', 'creams'],
#  'Mr. Greg': ['empire', 'good', 'live'],
#  'Too Short to Ride': ['short', 'rollercoasters', 'run'],
#  'The New Lars': ['look', 'gets', 'life'],
#  'Beach City Drift': ['highspeed', 'race', 'foe'],
#  'Restaurant Wars': ['frymans', 'pizzas', 'settle'],
#  "Kiki's Pizza Delivery Service": ['projects', 'kikis', 'saves'],
#  'Monster Reunion': ['reunites', 'centipeetle', 'friend'],
#  'Alone at Sea': ['boat', 'themselves', 'dangerous'],
#  'Greg the Babysitter': ['tale', 'wash', 'came'],
#  'Gem Hunt': ['track', 'wilderness', 'tracks'],
#  'Crack the Whip': ['left', 'charge', 'there'],
#  'Steven vs. Amethyst': ['competitive', 'training', 'while'],
#  'Bismuth': ['thought', 'lions', 'mane'],
#  'Beta': ['country', 'being', 'isnt'],
#  'Earthlings': ['exact', 'revenge', 'showdown'],
#  'Back to the Moon': ['base', 'revisit', 'moon'],
#  'Bubbled': ['marooned', 'bubble', 'gets'],
#  'Kindergarten Kid': ['deal', 'problem', 'monster'],
#  'Know Your Fusion': ['delve', 'deep', 'makes'],
#  "Buddy's Book": ['library', 'uncovers', 'long'],
#  'Mindful Education': ['focus', 'better', 'learn'],
#  'Future Boy Zoltron': ['peoples', 'fortunes', 'funland'],
#  'Last One Out of Beach City': ['attend', 'rock', 'show'],
#  'Onion Gang': ['onions', 'secret', 'finds'],
#  'Gem Harvest': ['autumn', 'stranger', 'brings'],
#  'Three Gems and a Baby': ['winter', 'first', 'tells'],
#  "Steven's Dream": ['prompts', 'dream', 'search'],
#  'Adventures in Light Distortion': ['recovery', 'search', 'off'],
#  'Gem Heist': ['pull', 'heist', 'off'],
#  'The Zoo': ['zoo', 'visits', 'special'],
#  'That Will Be All': ['daring', 'escape', 'make'],
#  'The New Crystal Gems': ['busy', 'look', 'after'],
#  'Storm in the Room': ['room', 'look', 'answers'],
#  'Rocknaldo': ['sets', 'living', 'rock'],
#  'Tiger Philanthropist': ['returns', 'ring', 'continue'],
#  'Room for Ruby': ['continues', 'grow', 'family'],
#  'Lion 4: Alternate Ending': ['coughs', 'key', 'quest'],
#  'Doug Out': ['join', 'father', 'stake'],
#  'The Good Lars': ['invited', 'cool', 'kids'],
#  'Are You My Dad?': ['disappearing', 'solve', 'people'],
#  'I Am My Mom': ['struggles', 'fix', 'mistakes'],
#  'Stuck Together': ['spend', 'time', 'lars'],
#  'The Trial': ['trial', 'goes', 'on'],
#  'Off Colors': ['unusual', 'allies', 'finds'],
#  "Lars' Head": ['lets', 'finally', 'lars'],
#  'Dewey Wins[22]': ['difficult', 'campaign', 'mayor'],
#  'Gemcation': ['vacation', 'relax', 'him'],
#  'Raising the Barn': ['pumpkin', 'missing', 'goes'],
#  'Back to the Kindergarten': ['peridot', 'spruce', 'kindergarten'],
#  'Sadie Killer': ['finding', 'sound', 'start'],
#  'Kevin Party': ['kevin', 'throwing', 'invited'],
#  'Lars of the Stars': ['rises', 'occasion', 'lars'],
#  'Jungle Moon': ['stevonnie', 'themself', 'alone'],
#  'Your Mother and Mine': ['meet', 'takes', 'friends'],
#  'The Big Show': ['shoots', 'documentary', 'follows'],
#  'Pool Hopping': ['unlikely', 'timelines', 'explore'],
#  'Letters to Lars': ['writes', 'latest', 'news'],
#  "Can't Go Back[24]": ['spots', 'investigate', 'mysterious'],
#  'A Single Pale Rose[24]': ['phone', 'find', 'her'],
#  "Now We're Only Falling Apart": ['story', 'tells', 'pearl'],
#  "What's Your Problem?": ['convinces', 'day', 'off'],
#  'The Question': ['slicker', 'cowboys', 'lived'],
#  'Made of Honor': ['surprise', 'big', 'has'],
#  'Reunited': ['reunion', 'brings', 'everyone'],
#  'Legs From Here to Homeworld': ['travels', 'visit', 'family'],
#  'Familiar': ['many', 'changes', 'going'],
#  'Together Alone': ['throws', 'bring', 'party'],
#  'Escapism': ['psychic', 'uses', 'powers'],
#  'Change Your Mind': ['faces', 'challenge', 'yet'],
#  'Steven Universe: The Movie': ['defending', 'earth', 'threat'],
#  'Little Homeschool': ['welcome', 'come', 'peacefully'],
#  'Guidance': ['helping', 'jobs', 'boardwalk'],
#  'Rose Buds': ['more', 'surprising', 'introduction'],
#  'Volleyball': ['pink', 'original', 'scar'],
#  'Bluebird': ['questions', 'motives', 'suddenly'],
#  'A Very Special Episode': ['two', 'rainbow', 'promised'],
#  'Snow Day': ['chance', 'catch', 'theyre'],
#  'Why So Blue?': ['heard', 'rumors', 'pair'],
#  'Little Graduation': ['celebrate', 'homeschools', 'graduating'],
#  'Prickly Pair': ['leaving', 'found', 'hobby'],
#  'In Dreams': ['broadcasting', 'onto', 'bedroom'],
#  'Bismuth Casual': ['invites', 'bismuth', 'roller'],
#  'Together Forever': ['very', 'clear', 'vision'],
#  'Growing Pains': ['doctor', 'sees', 'time'],
#  'Mr. Universe': ['origins', 'name', 'universe'],
#  'Fragments': ['woods', 'train', 'mentor'],
#  'Homeworld Bound': ['advice', 'diamonds', 'control'],
#  "Everything's Fine": ['insists', 'everything', 'fine'],
#  'I Am My Monster': ['not', 'everything', 'fine'],
#  'The Future': ['ready', 'move', 'finally']}

# %%
## Test with transcripts?
transcripts_df = pd.read_csv(data_pathname + 'transcripts.csv')

# %%
transcripts_df.head()
# Out:
#     episode speaker                                            actions  \
# 0  Gem Glow     NaN                                                 []
# 1  Gem Glow     NaN                                                 []
# 2  Gem Glow  Steven                                                 []
# 3  Gem Glow     NaN                                                 []
# 4  Gem Glow  Steven  ['looking at an empty freezer', 'grabs Lars ar...
#
#                                                quote  \
# 0                                                NaN
# 1                                                NaN
# 2                                   NOOOOOOOOOOOOO!!
# 3                                                NaN
# 4  This can't be happening! This has to be a drea...
#
#                       location description
# 0  Open Overview of Beach City         NaN
# 1        Trans. Ext. Big Donut         NaN
# 2                          NaN         NaN
# 3        Trans. Int. Big Donut         NaN
# 4                          NaN         NaN

# %%
transcripts_df.shape
# Out:
# (30377, 6)

# %%
valid_transcripts = transcripts_df.loc[transcripts_df['quote'].notna(), :]

# %%
valid_transcripts['list_of_tokens'] = valid_transcripts.apply(lambda row: create_list_tokens(row['quote']), axis = 1)
valid_transcripts['list_of_tokens'].head()
# Out:
# <ipython-input-234-ee9f8b86e979>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   valid_transcripts['list_of_tokens'] = valid_transcripts.apply(lambda row: create_list_tokens(row['quote']), axis = 1)
# 2                                     [nooooooooooooo]
# 4    [this, cant, be, happening, this, has, to, be,...
# 5              [get, off, me, man, im, stocking, here]
# 6    [im, sorry, steven, i, guess, they, stopped, m...
# 7    [stopped, making, them, why, in, the, world, w...
# Name: list_of_tokens, dtype: object

# %%
valid_transcripts.head()
# Out:
#     episode speaker                                            actions  \
# 2  Gem Glow  Steven                                                 []
# 4  Gem Glow  Steven  ['looking at an empty freezer', 'grabs Lars ar...
# 5  Gem Glow    Lars                              ['shakes Steven off']
# 6  Gem Glow   Sadie                                                 []
# 7  Gem Glow  Steven                                                 []
#
#                                                quote location description  \
# 2                                   NOOOOOOOOOOOOO!!      NaN         NaN
# 4  This can't be happening! This has to be a drea...      NaN         NaN
# 5                 Get off me man, I'm stocking here!      NaN         NaN
# 6  I'm sorry, Steven. I guess they stopped making...      NaN         NaN
# 7  Stopped making them?! Why in the world would t...      NaN         NaN
#
#                                       list_of_tokens
# 2                                   [nooooooooooooo]
# 4  [this, cant, be, happening, this, has, to, be,...
# 5            [get, off, me, man, im, stocking, here]
# 6  [im, sorry, steven, i, guess, they, stopped, m...
# 7  [stopped, making, them, why, in, the, world, w...

# %%
# NOTE:
# Can't just use the episode name as a key becuase these are not unique
# The transcript corpus has to have one long list of tokens 
# I can create a corpus where each episode is a document
# Alternatively, one corpus per episode, where each document represents a speaker
# Alternatively, one corpus per speaker, where each document represents an episode

# TEST-RUN: Try limiting transcripts to just Gem Glow
# Each speaker will have their own document

gem_glow_corpus = {}
gem_glow_transcripts = valid_transcripts.loc[valid_transcripts['episode'] == 'Gem Glow', :]

gem_glow_transcripts.head()
# Out:
#     episode speaker                                            actions  \
# 2  Gem Glow  Steven                                                 []
# 4  Gem Glow  Steven  ['looking at an empty freezer', 'grabs Lars ar...
# 5  Gem Glow    Lars                              ['shakes Steven off']
# 6  Gem Glow   Sadie                                                 []
# 7  Gem Glow  Steven                                                 []
#
#                                                quote location description  \
# 2                                   NOOOOOOOOOOOOO!!      NaN         NaN
# 4  This can't be happening! This has to be a drea...      NaN         NaN
# 5                 Get off me man, I'm stocking here!      NaN         NaN
# 6  I'm sorry, Steven. I guess they stopped making...      NaN         NaN
# 7  Stopped making them?! Why in the world would t...      NaN         NaN
#
#                                       list_of_tokens
# 2                                   [nooooooooooooo]
# 4  [this, cant, be, happening, this, has, to, be,...
# 5            [get, off, me, man, im, stocking, here]
# 6  [im, sorry, steven, i, guess, they, stopped, m...
# 7  [stopped, making, them, why, in, the, world, w...

# %%
speaker_tokens = {}

for i in range(len(gem_glow_transcripts)):
    speaker = gem_glow_transcripts.iloc[i]['speaker']
    tokens = gem_glow_transcripts.iloc[i]['list_of_tokens']
    
    if speaker not in speaker_tokens:
        speaker_tokens[speaker] = tokens
    else:
        speaker_tokens[speaker].extend(tokens)
        
speaker_tokens
# Out:
# {'Steven': ['nooooooooooooo',
#   'this',
#   'cant',
#   'be',
#   'happening',
#   'this',
#   'has',
#   'to',
#   'be',
#   'a',
#   'dream',
#   'lars',
#   'lars',
#   'please',
#   'tell',
#   'me',
#   'im',
#   'dreaming',
#   'stopped',
#   'making',
#   'them',
#   'why',
#   'in',
#   'the',
#   'world',
#   'would',
#   'they',
#   'stop',
#   'making',
#   'cookie',
#   'cats',
#   'theyre',
#   'only',
#   'the',
#   'most',
#   'scrumptious',
#   'and',
#   'delicious',
#   'icecream',
#   'sandwich',
#   'ever',
#   'made',
#   'dont',
#   'they',
#   'have',
#   'laws',
#   'for',
#   'this',
#   'not',
#   'lion',
#   'lickers',
#   'nobody',
#   'likes',
#   'them',
#   'they',
#   'dont',
#   'even',
#   'look',
#   'like',
#   'lions',
#   'kids',
#   'these',
#   'days',
#   'ill',
#   'tell',
#   'ya',
#   'what',
#   'thats',
#   'not',
#   'how',
#   'it',
#   'works',
#   'lars',
#   'right',
#   'oh',
#   'sweet',
#   'cookie',
#   'cats',
#   'with',
#   'your',
#   'crunchy',
#   'cookie',
#   'outside',
#   'and',
#   'your',
#   'icy',
#   'creamy',
#   'insides',
#   'you',
#   'were',
#   'too',
#   'good',
#   'for',
#   'this',
#   'world',
#   'hey',
#   'guys',
#   'you',
#   'wont',
#   'believe',
#   'this',
#   'awesome',
#   'what',
#   'are',
#   'these',
#   'things',
#   'aw',
#   'you',
#   'dont',
#   'have',
#   'to',
#   'get',
#   'rid',
#   'of',
#   'them',
#   'theyre',
#   'really',
#   'cool',
#   'oh',
#   'oh',
#   'can',
#   'i',
#   'come',
#   'can',
#   'i',
#   'can',
#   'i',
#   'aw',
#   'man',
#   'hey',
#   'get',
#   'out',
#   'of',
#   'there',
#   'go',
#   'on',
#   'shoo',
#   'shoo',
#   'aw',
#   'they',
#   'got',
#   'into',
#   'everything',
#   'not',
#   'cool',
#   'no',
#   'way',
#   'iit',
#   'cant',
#   'be',
#   'whawhere',
#   'did',
#   'you',
#   'get',
#   'these',
#   'i',
#   'thought',
#   'they',
#   'stopped',
#   'making',
#   'them',
#   'oohhhhh',
#   'hes',
#   'a',
#   'frozen',
#   'treat',
#   'with',
#   'an',
#   'all',
#   'new',
#   'taste',
#   'cause',
#   'he',
#   'came',
#   'to',
#   'this',
#   'planet',
#   'from',
#   'outer',
#   'space',
#   'a',
#   'refugee',
#   'of',
#   'an',
#   'interstellar',
#   'war',
#   'but',
#   'now',
#   'hes',
#   'at',
#   'your',
#   'local',
#   'grocery',
#   'store',
#   'cookie',
#   'cat',
#   'hes',
#   'a',
#   'pet',
#   'for',
#   'your',
#   'tummy',
#   'cookie',
#   'cat',
#   'hes',
#   'super',
#   'duper',
#   'yummy',
#   'cookie',
#   'cat',
#   'he',
#   'left',
#   'his',
#   'family',
#   'behind',
#   'cookie',
#   'caaaaat',
#   'now',
#   'available',
#   'at',
#   'gurgens',
#   'off',
#   'route',
#   'i',
#   'cant',
#   'believe',
#   'you',
#   'did',
#   'this',
#   'im',
#   'gonna',
#   'save',
#   'these',
#   'forever',
#   'right',
#   'after',
#   'i',
#   'eat',
#   'this',
#   'one',
#   'hello',
#   'old',
#   'friend',
#   'oh',
#   'so',
#   'good',
#   'stevens',
#   'gem',
#   'begins',
#   'to',
#   'glow',
#   'i',
#   'like',
#   'to',
#   'eat',
#   'the',
#   'ears',
#   'first',
#   'wha',
#   'my',
#   'gem',
#   'i',
#   'dont',
#   'know',
#   'how',
#   'aaaah',
#   'its',
#   'fading',
#   'how',
#   'do',
#   'i',
#   'make',
#   'it',
#   'come',
#   'back',
#   'ah',
#   'i',
#   'was',
#   'really',
#   'close',
#   'that',
#   'time',
#   'can',
#   'one',
#   'of',
#   'you',
#   'just',
#   'explain',
#   'how',
#   'to',
#   'summon',
#   'a',
#   'weapon',
#   'wah',
#   'yeah',
#   'i',
#   'need',
#   'to',
#   'practice',
#   'really',
#   'hard',
#   'so',
#   'i',
#   'can',
#   'dance',
#   'like',
#   'a',
#   'tree',
#   'i',
#   'think',
#   'so',
#   'im',
#   'supposed',
#   'to',
#   'work',
#   'really',
#   'hard',
#   'and',
#   'not',
#   'try',
#   'at',
#   'all',
#   'at',
#   'the',
#   'same',
#   'time',
#   'i',
#   'think',
#   'my',
#   'best',
#   'bet',
#   'is',
#   'to',
#   'recreate',
#   'what',
#   'happened',
#   'the',
#   'last',
#   'time',
#   'my',
#   'gem',
#   'glowed',
#   'so',
#   'garnet',
#   'and',
#   'amethyst',
#   'were',
#   'here',
#   'pearl',
#   'was',
#   'next',
#   'to',
#   'the',
#   'fridge',
#   'hmm',
#   'amethyst',
#   'i',
#   'think',
#   'your',
#   'arms',
#   'were',
#   'crossed',
#   'and',
#   'pearl',
#   'your',
#   'foot',
#   'was',
#   'like',
#   'this',
#   'and',
#   'garnet',
#   'uh',
#   'yeah',
#   'then',
#   'i',
#   'took',
#   'a',
#   'bite',
#   'of',
#   'this',
#   'cookie',
#   'cat',
#   'oh',
#   'wait',
#   'i',
#   'sang',
#   'the',
#   'song',
#   'first',
#   'uh',
#   'hes',
#   'a',
#   'frozen',
#   'treat',
#   'all',
#   'new',
#   'taste',
#   'interstellar',
#   'war',
#   'now',
#   'available',
#   'at',
#   'gurgens',
#   'awww',
#   'it',
#   'was',
#   'funnier',
#   'last',
#   'time',
#   'maybe',
#   'im',
#   'not',
#   'a',
#   'real',
#   'crystal',
#   'gem',
#   'yeah',
#   'even',
#   'if',
#   'i',
#   'dont',
#   'have',
#   'powers',
#   'ive',
#   'still',
#   'got',
#   'cookie',
#   'cat',
#   'mmm',
#   'so',
#   'good',
#   'whoa',
#   'what',
#   'i',
#   'get',
#   'a',
#   'shield',
#   'oh',
#   'yeah',
#   'huh',
#   'cookie',
#   'cat',
#   'i',
#   'summon',
#   'my',
#   'weapon',
#   'by',
#   'eating',
#   'ice',
#   'cream',
#   'what',
#   'was',
#   'that',
#   'no',
#   'way',
#   'im',
#   'coming',
#   'too',
#   'hey',
#   'leave',
#   'them',
#   'alone',
#   'cookie',
#   'cat',
#   'crystal',
#   'combo',
#   'powers',
#   'activate',
#   'the',
#   'centipeetle',
#   'mother',
#   'stares',
#   'maniacally',
#   'as',
#   'nothing',
#   'happens',
#   'uhoh',
#   'aaaah',
#   'goodbye',
#   'my',
#   'friends',
#   'why',
#   'isnt',
#   'it',
#   'working',
#   'no',
#   'oh',
#   'no',
#   'no',
#   'no',
#   'no',
#   'no',
#   'cookie',
#   'cat',
#   'hes',
#   'a',
#   'pet',
#   'for',
#   'your',
#   'tummy',
#   'cookie',
#   'cat',
#   'hes',
#   'super',
#   'duper',
#   'yummy',
#   'cookie',
#   'cat',
#   'he',
#   'left',
#   'his',
#   'family',
#   'behind',
#   'cookie',
#   'caaat',
#   'now',
#   'available',
#   'nowhere',
#   'farewell',
#   'sweet',
#   'cookie',
#   'cats',
#   'ill',
#   'always',
#   'remember',
#   'the',
#   'time',
#   'we',
#   'spent',
#   'together',
#   'shh',
#   'hush',
#   'now',
#   'only',
#   'a',
#   'little',
#   'im',
#   'okay',
#   'guys',
#   'i',
#   'just',
#   'ugh',
#   'i',
#   'think',
#   'i',
#   'ate',
#   'too',
#   'many',
#   'cookie',
#   'cats'],
#  'Lars': ['get',
#   'off',
#   'me',
#   'man',
#   'im',
#   'stocking',
#   'here',
#   'tough',
#   'bits',
#   'man',
#   'nobody',
#   'buys',
#   'them',
#   'anymore',
#   'i',
#   'guess',
#   'they',
#   'couldnt',
#   'compete',
#   'with',
#   'lion',
#   'lickers',
#   'well',
#   'if',
#   'you',
#   'miss',
#   'your',
#   'wimpy',
#   'ice',
#   'cream',
#   'so',
#   'much',
#   'why',
#   'dont',
#   'you',
#   'make',
#   'some',
#   'with',
#   'your',
#   'magic',
#   'belly',
#   'button',
#   'runs',
#   'outside',
#   'and',
#   'drops',
#   'trash',
#   'bag',
#   'aaah',
#   'again'],
#  'Sadie': ['im',
#   'sorry',
#   'steven',
#   'i',
#   'guess',
#   'they',
#   'stopped',
#   'making',
#   'them',
#   'ugh',
#   'steven',
#   'do',
#   'you',
#   'want',
#   'to',
#   'take',
#   'the',
#   'freezer',
#   'with',
#   'you'],
#  'Amethyst': ['sup',
#   'steven',
#   'um',
#   'you',
#   'guys',
#   'these',
#   'things',
#   'dont',
#   'have',
#   'gems',
#   'we',
#   'went',
#   'out',
#   'and',
#   'stole',
#   'a',
#   'bunch',
#   'it',
#   'was',
#   'everyones',
#   'idea',
#   'uh',
#   'steven',
#   'quick',
#   'try',
#   'and',
#   'summon',
#   'your',
#   'weapon',
#   'yeah',
#   'and',
#   'try',
#   'not',
#   'to',
#   'poop',
#   'yourself',
#   'either',
#   'did',
#   'pearl',
#   'tell',
#   'you',
#   'the',
#   'petal',
#   'thing',
#   'listen',
#   'steven',
#   'all',
#   'that',
#   'practice',
#   'stuff',
#   'is',
#   'no',
#   'fun',
#   'whenever',
#   'i',
#   'need',
#   'to',
#   'summon',
#   'my',
#   'weapon',
#   'it',
#   'just',
#   'happens',
#   'see',
#   'didnt',
#   'try',
#   'at',
#   'all',
#   'steven',
#   'scratches',
#   'his',
#   'head',
#   'okay',
#   'your',
#   'majesty',
#   'and',
#   'youre',
#   'fun',
#   'to',
#   'have',
#   'around',
#   'even',
#   'if',
#   'your',
#   'gem',
#   'is',
#   'useless',
#   'pearl',
#   'gets',
#   'angry',
#   'at',
#   'amethyst',
#   'i',
#   'mean',
#   'youre',
#   'one',
#   'of',
#   'us',
#   'steven',
#   'were',
#   'not',
#   'the',
#   'crystal',
#   'gems',
#   'without',
#   'you',
#   'garnet',
#   'nods',
#   'we',
#   'could',
#   'really',
#   'use',
#   'stevens',
#   'shield',
#   'right',
#   'about',
#   'now',
#   'can',
#   'we',
#   'save',
#   'ourselves',
#   'first',
#   'yes',
#   'are',
#   'you',
#   'crying',
#   'well',
#   'i',
#   'guess',
#   'your',
#   'powers',
#   'dont',
#   'come',
#   'from',
#   'ice',
#   'cream'],
#  'Pearl': ['ugh',
#   'sorry',
#   'steven',
#   'well',
#   'get',
#   'these',
#   'centipeetles',
#   'out',
#   'of',
#   'your',
#   'room',
#   'we',
#   'think',
#   'they',
#   'were',
#   'trying',
#   'to',
#   'get',
#   'into',
#   'the',
#   'temple',
#   'we',
#   'should',
#   'probably',
#   'find',
#   'it',
#   'before',
#   'anyone',
#   'gets',
#   'hurt',
#   'steven',
#   'until',
#   'you',
#   'learn',
#   'to',
#   'control',
#   'the',
#   'powers',
#   'in',
#   'your',
#   'gem',
#   'well',
#   'take',
#   'care',
#   'of',
#   'protecting',
#   'humanity',
#   'okay',
#   'well',
#   'we',
#   'heard',
#   'that',
#   'too',
#   'and',
#   'since',
#   'theyre',
#   'your',
#   'favorite',
#   'i',
#   'went',
#   'back',
#   'and',
#   'paid',
#   'for',
#   'them',
#   'all',
#   'that',
#   'matters',
#   'is',
#   'that',
#   'steven',
#   'is',
#   'happy',
#   'calm',
#   'down',
#   'steven',
#   'breathe',
#   'dont',
#   'force',
#   'it',
#   'oh',
#   'ill',
#   'go',
#   'first',
#   'pay',
#   'attention',
#   'to',
#   'these',
#   'petals',
#   'steven',
#   'the',
#   'petals',
#   'dance',
#   'seems',
#   'improvised',
#   'but',
#   'it',
#   'is',
#   'being',
#   'calculated',
#   'in',
#   'real',
#   'time',
#   'based',
#   'on',
#   'the',
#   'physical',
#   'properties',
#   'of',
#   'this',
#   'planet',
#   'with',
#   'hard',
#   'work',
#   'and',
#   'dedication',
#   'you',
#   'can',
#   'master',
#   'the',
#   'magical',
#   'properties',
#   'of',
#   'your',
#   'gem',
#   'and',
#   'perform',
#   'your',
#   'own',
#   'dance',
#   'like',
#   'so',
#   'steven',
#   'is',
#   'in',
#   'awe',
#   'i',
#   'dont',
#   'think',
#   'it',
#   'works',
#   'this',
#   'way',
#   'steven',
#   'dont',
#   'be',
#   'silly',
#   'steven',
#   'of',
#   'course',
#   'you',
#   'are',
#   'steven',
#   'its',
#   'a',
#   'shield',
#   'whats',
#   'in',
#   'these',
#   'things',
#   'stay',
#   'in',
#   'the',
#   'house',
#   'steven',
#   'we',
#   'need',
#   'to',
#   'save',
#   'steven',
#   'of',
#   'course',
#   'they',
#   'dont',
#   'come',
#   'from',
#   'ice',
#   'cream',
#   'dont',
#   'worry',
#   'steven',
#   'im',
#   'sure',
#   'some',
#   'day',
#   'youll',
#   'figure',
#   'out',
#   'how',
#   'to',
#   'activate',
#   'your',
#   'gem'],
#  'Garnet': ['that',
#   'means',
#   'there',
#   'must',
#   'be',
#   'a',
#   'mother',
#   'somewhere',
#   'nearby',
#   'the',
#   'whole',
#   'thing',
#   'was',
#   'my',
#   'idea',
#   'not',
#   'really',
#   'please',
#   'dont',
#   'yes',
#   'or',
#   'you',
#   'could',
#   'link',
#   'your',
#   'mind',
#   'with',
#   'the',
#   'energy',
#   'of',
#   'all',
#   'existing',
#   'matter',
#   'channeling',
#   'the',
#   'collective',
#   'power',
#   'of',
#   'the',
#   'universe',
#   'through',
#   'your',
#   'gem',
#   'which',
#   'results',
#   'in',
#   'at',
#   'least',
#   'thats',
#   'my',
#   'way',
#   'of',
#   'doin',
#   'it',
#   'its',
#   'the',
#   'mother',
#   'steven',
#   'gems',
#   'weapons',
#   'the',
#   'gems',
#   'summon',
#   'their',
#   'weapons',
#   'and',
#   'burst',
#   'out',
#   'of',
#   'cover',
#   'from',
#   'the',
#   'hand',
#   'statue',
#   'lets',
#   'do',
#   'it',
#   'yes',
#   'in',
#   'your',
#   'own',
#   'steveny',
#   'way'],
#  'Garnet, Pearl & Amethyst': ['steven', 'no']}

# %%
most_salient_gem_glow = {}
most_salient_gem_glow = find_most_salient(speaker_tokens, 2)

# %%
most_salient_gem_glow
# Out:
# {'Steven': ['cookie', 'cat'],
#  'Lars': ['stocking', 'tough'],
#  'Sadie': ['want', 'freezer'],
#  'Amethyst': ['fun', 'youre'],
#  'Pearl': ['petals', 'properties'],
#  'Garnet': ['weapons', 'means'],
#  'Garnet, Pearl & Amethyst': ['no', 'steven']}

# %%
def build_corpus(df, index, doc_col, filter_by=None):
    '''
    Takes a pandas dataframe and returns a corpus i.e., a dictionary where the
        key is some identifier and the value is the document

    Inputs:
        - df (pandas DataFrame): dataset with columns for index and document
        - index (str): name of the column to use as key
        - doc_col (str): name of the column containing the document i.e., a list
                         of strings
        - filter_by (tuple of strings): column, value to limit the data by

    Returns a dictionary of documents mapped to their identifier
    '''
    corpus = {}

    if filter_by:
        filter_col, filter_val = limit_by
        df = df.loc[df[filter_col] == filter_val, :]

    for i in range(len(df)):
        id = df.iloc[i][index]
        doc = df.iloc[i][doc_col]

        if id not in corpus:
            corpus[id] = doc
        else:
            corpus[id].extend(doc)

    return corpus

# %%
by_episode_corpus = build_corpus(valid_transcripts, 'episode', 'list_of_tokens')

# %%
by_episode_corpus
# Out:
# {'Gem Glow': ['nooooooooooooo',
#   'this',
#   'cant',
#   'be',
#   'happening',
#   'this',
#   'has',
#   'to',
#   'be',
#   'a',
#   'dream',
#   'lars',
#   'lars',
#   'please',
#   'tell',
#   'me',
#   'im',
#   'dreaming',
#   'stopped',
#   'making',
#   'them',
#   'why',
#   'in',
#   'the',
#   'world',
#   'would',
#   'they',
#   'stop',
#   'making',
#   'cookie',
#   'cats',
#   'theyre',
#   'only',
#   'the',
#   'most',
#   'scrumptious',
#   'and',
#   'delicious',
#   'icecream',
#   'sandwich',
#   'ever',
#   'made',
#   'dont',
#   'they',
#   'have',
#   'laws',
#   'for',
#   'this',
#   'not',
#   'lion',
#   'lickers',
#   'nobody',
#   'likes',
#   'them',
#   'they',
#   'dont',
#   'even',
#   'look',
#   'like',
#   'lions',
#   'kids',
#   'these',
#   'days',
#   'ill',
#   'tell',
#   'ya',
#   'what',
#   'thats',
#   'not',
#   'how',
#   'it',
#   'works',
#   'lars',
#   'right',
#   'oh',
#   'sweet',
#   'cookie',
#   'cats',
#   'with',
#   'your',
#   'crunchy',
#   'cookie',
#   'outside',
#   'and',
#   'your',
#   'icy',
#   'creamy',
#   'insides',
#   'you',
#   'were',
#   'too',
#   'good',
#   'for',
#   'this',
#   'world',
#   'hey',
#   'guys',
#   'you',
#   'wont',
#   'believe',
#   'this',
#   'awesome',
#   'what',
#   'are',
#   'these',
#   'things',
#   'aw',
#   'you',
#   'dont',
#   'have',
#   'to',
#   'get',
#   'rid',
#   'of',
#   'them',
#   'theyre',
#   'really',
#   'cool',
#   'oh',
#   'oh',
#   'can',
#   'i',
#   'come',
#   'can',
#   'i',
#   'can',
#   'i',
#   'aw',
#   'man',
#   'hey',
#   'get',
#   'out',
#   'of',
#   'there',
#   'go',
#   'on',
#   'shoo',
#   'shoo',
#   'aw',
#   'they',
#   'got',
#   'into',
#   'everything',
#   'not',
#   'cool',
#   'no',
#   'way',
#   'iit',
#   'cant',
#   'be',
#   'whawhere',
#   'did',
#   'you',
#   'get',
#   'these',
#   'i',
#   'thought',
#   'they',
#   'stopped',
#   'making',
#   'them',
#   'oohhhhh',
#   'hes',
#   'a',
#   'frozen',
#   'treat',
#   'with',
#   'an',
#   'all',
#   'new',
#   'taste',
#   'cause',
#   'he',
#   'came',
#   'to',
#   'this',
#   'planet',
#   'from',
#   'outer',
#   'space',
#   'a',
#   'refugee',
#   'of',
#   'an',
#   'interstellar',
#   'war',
#   'but',
#   'now',
#   'hes',
#   'at',
#   'your',
#   'local',
#   'grocery',
#   'store',
#   'cookie',
#   'cat',
#   'hes',
#   'a',
#   'pet',
#   'for',
#   'your',
#   'tummy',
#   'cookie',
#   'cat',
#   'hes',
#   'super',
#   'duper',
#   'yummy',
#   'cookie',
#   'cat',
#   'he',
#   'left',
#   'his',
#   'family',
#   'behind',
#   'cookie',
#   'caaaaat',
#   'now',
#   'available',
#   'at',
#   'gurgens',
#   'off',
#   'route',
#   'i',
#   'cant',
#   'believe',
#   'you',
#   'did',
#   'this',
#   'im',
#   'gonna',
#   'save',
#   'these',
#   'forever',
#   'right',
#   'after',
#   'i',
#   'eat',
#   'this',
#   'one',
#   'hello',
#   'old',
#   'friend',
#   'oh',
#   'so',
#   'good',
#   'stevens',
#   'gem',
#   'begins',
#   'to',
#   'glow',
#   'i',
#   'like',
#   'to',
#   'eat',
#   'the',
#   'ears',
#   'first',
#   'wha',
#   'my',
#   'gem',
#   'i',
#   'dont',
#   'know',
#   'how',
#   'aaaah',
#   'its',
#   'fading',
#   'how',
#   'do',
#   'i',
#   'make',
#   'it',
#   'come',
#   'back',
#   'ah',
#   'i',
#   'was',
#   'really',
#   'close',
#   'that',
#   'time',
#   'can',
#   'one',
#   'of',
#   'you',
#   'just',
#   'explain',
#   'how',
#   'to',
#   'summon',
#   'a',
#   'weapon',
#   'wah',
#   'yeah',
#   'i',
#   'need',
#   'to',
#   'practice',
#   'really',
#   'hard',
#   'so',
#   'i',
#   'can',
#   'dance',
#   'like',
#   'a',
#   'tree',
#   'i',
#   'think',
#   'so',
#   'im',
#   'supposed',
#   'to',
#   'work',
#   'really',
#   'hard',
#   'and',
#   'not',
#   'try',
#   'at',
#   'all',
#   'at',
#   'the',
#   'same',
#   'time',
#   'i',
#   'think',
#   'my',
#   'best',
#   'bet',
#   'is',
#   'to',
#   'recreate',
#   'what',
#   'happened',
#   'the',
#   'last',
#   'time',
#   'my',
#   'gem',
#   'glowed',
#   'so',
#   'garnet',
#   'and',
#   'amethyst',
#   'were',
#   'here',
#   'pearl',
#   'was',
#   'next',
#   'to',
#   'the',
#   'fridge',
#   'hmm',
#   'amethyst',
#   'i',
#   'think',
#   'your',
#   'arms',
#   'were',
#   'crossed',
#   'and',
#   'pearl',
#   'your',
#   'foot',
#   'was',
#   'like',
#   'this',
#   'and',
#   'garnet',
#   'uh',
#   'yeah',
#   'then',
#   'i',
#   'took',
#   'a',
#   'bite',
#   'of',
#   'this',
#   'cookie',
#   'cat',
#   'oh',
#   'wait',
#   'i',
#   'sang',
#   'the',
#   'song',
#   'first',
#   'uh',
#   'hes',
#   'a',
#   'frozen',
#   'treat',
#   'all',
#   'new',
#   'taste',
#   'interstellar',
#   'war',
#   'now',
#   'available',
#   'at',
#   'gurgens',
#   'awww',
#   'it',
#   'was',
#   'funnier',
#   'last',
#   'time',
#   'maybe',
#   'im',
#   'not',
#   'a',
#   'real',
#   'crystal',
#   'gem',
#   'yeah',
#   'even',
#   'if',
#   'i',
#   'dont',
#   'have',
#   'powers',
#   'ive',
#   'still',
#   'got',
#   'cookie',
#   'cat',
#   'mmm',
#   'so',
#   'good',
#   'whoa',
#   'what',
#   'i',
#   'get',
#   'a',
#   'shield',
#   'oh',
#   'yeah',
#   'huh',
#   'cookie',
#   'cat',
#   'i',
#   'summon',
#   'my',
#   'weapon',
#   'by',
#   'eating',
#   'ice',
#   'cream',
#   'what',
#   'was',
#   'that',
#   'no',
#   'way',
#   'im',
#   'coming',
#   'too',
#   'hey',
#   'leave',
#   'them',
#   'alone',
#   'cookie',
#   'cat',
#   'crystal',
#   'combo',
#   'powers',
#   'activate',
#   'the',
#   'centipeetle',
#   'mother',
#   'stares',
#   'maniacally',
#   'as',
#   'nothing',
#   'happens',
#   'uhoh',
#   'aaaah',
#   'goodbye',
#   'my',
#   'friends',
#   'why',
#   'isnt',
#   'it',
#   'working',
#   'no',
#   'oh',
#   'no',
#   'no',
#   'no',
#   'no',
#   'no',
#   'cookie',
#   'cat',
#   'hes',
#   'a',
#   'pet',
#   'for',
#   'your',
#   'tummy',
#   'cookie',
#   'cat',
#   'hes',
#   'super',
#   'duper',
#   'yummy',
#   'cookie',
#   'cat',
#   'he',
#   'left',
#   'his',
#   'family',
#   'behind',
#   'cookie',
#   'caaat',
#   'now',
#   'available',
#   'nowhere',
#   'farewell',
#   'sweet',
#   'cookie',
#   'cats',
#   'ill',
#   'always',
#   'remember',
#   'the',
#   'time',
#   'we',
#   'spent',
#   'together',
#   'shh',
#   'hush',
#   'now',
#   'only',
#   'a',
#   'little',
#   'im',
#   'okay',
#   'guys',
#   'i',
#   'just',
#   'ugh',
#   'i',
#   'think',
#   'i',
#   'ate',
#   'too',
#   'many',
#   'cookie',
#   'cats',
#   'this',
#   'cant',
#   'be',
#   'happening',
#   'this',
#   'has',
#   'to',
#   'be',
#   'a',
#   'dream',
#   'lars',
#   'lars',
#   'please',
#   'tell',
#   'me',
#   'im',
#   'dreaming',
#   'get',
#   'off',
#   'me',
#   'man',
#   'im',
#   'stocking',
#   'here',
#   'tough',
#   'bits',
#   'man',
#   'nobody',
#   'buys',
#   'them',
#   'anymore',
#   'i',
#   'guess',
#   'they',
#   'couldnt',
#   'compete',
#   'with',
#   'lion',
#   'lickers',
#   'well',
#   'if',
#   'you',
#   'miss',
#   'your',
#   'wimpy',
#   'ice',
#   'cream',
#   'so',
#   'much',
#   'why',
#   'dont',
#   'you',
#   'make',
#   'some',
#   'with',
#   'your',
#   'magic',
#   'belly',
#   'button',
#   'runs',
#   'outside',
#   'and',
#   'drops',
#   'trash',
#   'bag',
#   'aaah',
#   'again',
#   'im',
#   'sorry',
#   'steven',
#   'i',
#   'guess',
#   'they',
#   'stopped',
#   'making',
#   'them',
#   'ugh',
#   'steven',
#   'do',
#   'you',
#   'want',
#   'to',
#   'take',
#   'the',
#   'freezer',
#   'with',
#   'you',
#   'stopped',
#   'making',
#   'them',
#   'why',
#   'in',
#   'the',
#   'world',
#   'would',
#   'they',
#   'stop',
#   'making',
#   'cookie',
#   'cats',
#   'theyre',
#   'only',
#   'the',
#   'most',
#   'scrumptious',
#   'and',
#   'delicious',
#   'icecream',
#   'sandwich',
#   'ever',
#   'made',
#   'dont',
#   'they',
#   'have',
#   'laws',
#   'for',
#   'this',
#   'tough',
#   'bits',
#   'man',
#   'nobody',
#   'buys',
#   'them',
#   'anymore',
#   'i',
#   'guess',
#   'they',
#   'couldnt',
#   'compete',
#   'with',
#   'lion',
#   'lickers',
#   'not',
#   'lion',
#   'lickers',
#   'nobody',
#   'likes',
#   'them',
#   'they',
#   'dont',
#   'even',
#   'look',
#   'like',
#   'lions',
#   'kids',
#   'these',
#   'days',
#   'ill',
#   'tell',
#   'ya',
#   'what',
#   'well',
#   'if',
#   'you',
#   'miss',
#   'your',
#   'wimpy',
#   'ice',
#   'cream',
#   'so',
#   'much',
#   'why',
#   'dont',
#   'you',
#   'make',
#   'some',
#   'with',
#   'your',
#   'magic',
#   'belly',
#   'button',
#   'thats',
#   'not',
#   'how',
#   'it',
#   'works',
#   'lars',
#   'right',
#   'oh',
#   'sweet',
#   'cookie',
#   'cats',
#   'with',
#   'your',
#   'crunchy',
#   'cookie',
#   'outside',
#   'and',
#   'your',
#   'icy',
#   'creamy',
#   'insides',
#   'you',
#   'were',
#   'too',
#   'good',
#   'for',
#   'this',
#   'world',
#   'ugh',
#   'steven',
#   'do',
#   'you',
#   'want',
#   'to',
#   'take',
#   'the',
#   'freezer',
#   'with',
#   'you',
#   'hey',
#   'guys',
#   'you',
#   'wont',
#   'believe',
#   'this',
#   'sup',
#   'steven',
#   'um',
#   'you',
#   'guys',
#   'these',
#   'things',
#   'dont',
#   'have',
#   'gems',
#   'we',
#   'went',
#   'out',
#   'and',
#   'stole',
#   'a',
#   'bunch',
#   'it',
#   'was',
#   'everyones',
#   'idea',
#   'uh',
#   'steven',
#   'quick',
#   'try',
#   'and',
#   'summon',
#   'your',
#   'weapon',
#   'yeah',
#   'and',
#   'try',
#   'not',
#   'to',
#   'poop',
#   'yourself',
#   'either',
#   'did',
#   'pearl',
#   'tell',
#   'you',
#   'the',
#   'petal',
#   'thing',
#   'listen',
#   'steven',
#   'all',
#   'that',
#   'practice',
#   'stuff',
#   'is',
#   'no',
#   'fun',
#   'whenever',
#   'i',
#   'need',
#   'to',
#   'summon',
#   'my',
#   'weapon',
#   'it',
#   'just',
#   'happens',
#   'see',
#   'didnt',
#   'try',
#   'at',
#   'all',
#   'steven',
#   'scratches',
#   'his',
#   'head',
#   'okay',
#   'your',
#   'majesty',
#   'and',
#   'youre',
#   'fun',
#   'to',
#   'have',
#   'around',
#   'even',
#   'if',
#   'your',
#   'gem',
#   'is',
#   'useless',
#   'pearl',
#   'gets',
#   'angry',
#   'at',
#   'amethyst',
#   'i',
#   'mean',
#   'youre',
#   'one',
#   'of',
#   'us',
#   'steven',
#   'were',
#   'not',
#   'the',
#   'crystal',
#   'gems',
#   'without',
#   'you',
#   'garnet',
#   'nods',
#   'we',
#   'could',
#   'really',
#   'use',
#   'stevens',
#   'shield',
#   'right',
#   'about',
#   'now',
#   'can',
#   'we',
#   'save',
#   'ourselves',
#   'first',
#   'yes',
#   'are',
#   'you',
#   'crying',
#   'well',
#   'i',
#   'guess',
#   'your',
#   'powers',
#   'dont',
#   'come',
#   'from',
#   'ice',
#   'cream',
#   'awesome',
#   'what',
#   'are',
#   'these',
#   'things',
#   'ugh',
#   'sorry',
#   'steven',
#   'well',
#   'get',
#   'these',
#   'centipeetles',
#   'out',
#   'of',
#   'your',
#   'room',
#   'we',
#   'think',
#   'they',
#   'were',
#   'trying',
#   'to',
#   'get',
#   'into',
#   'the',
#   'temple',
#   'we',
#   'should',
#   'probably',
#   'find',
#   'it',
#   'before',
#   'anyone',
#   'gets',
#   'hurt',
#   'steven',
#   'until',
#   'you',
#   'learn',
#   'to',
#   'control',
#   'the',
#   'powers',
#   'in',
#   'your',
#   'gem',
#   'well',
#   'take',
#   'care',
#   'of',
#   'protecting',
#   'humanity',
#   'okay',
#   'well',
#   'we',
#   'heard',
#   'that',
#   'too',
#   'and',
#   'since',
#   'theyre',
#   'your',
#   'favorite',
#   'i',
#   'went',
#   'back',
#   'and',
#   'paid',
#   'for',
#   'them',
#   'all',
#   'that',
#   'matters',
#   'is',
#   'that',
#   'steven',
#   'is',
#   'happy',
#   'calm',
#   'down',
#   'steven',
#   'breathe',
#   'dont',
#   'force',
#   'it',
#   'oh',
#   'ill',
#   'go',
#   'first',
#   'pay',
#   'attention',
#   'to',
#   'these',
#   'petals',
#   'steven',
#   'the',
#   'petals',
#   'dance',
#   ...],
#  'Laser Light Cannon': ['hey',
#   'fryman',
#   'give',
#   'me',
#   'the',
#   'bits',
#   'steven',
#   'were',
#   'closed',
#   'aww',
#   'what',
#   'give',
#   'em',
#   'the',
#   'bits',
#   'the',
#   'bits',
#   'the',
#   'bits',
#   'the',
#   'bits',
#   'the',
#   'bits',
#   'the',
#   'bits',
#   'okay',
#   'okay',
#   'take',
#   'it',
#   'easy',
#   'on',
#   'the',
#   'counter',
#   'will',
#   'ya',
#   'yes',
#   'i',
#   'can',
#   'give',
#   'you',
#   'actual',
#   'fries',
#   'if',
#   'you',
#   'want',
#   'just',
#   'the',
#   'bits',
#   'please',
#   'thanks',
#   'ah',
#   'sunset',
#   'my',
#   'favorite',
#   'time',
#   'of',
#   'day',
#   'when',
#   'the',
#   'sun',
#   'goes',
#   'down',
#   'and',
#   'the',
#   'second',
#   'sun',
#   'gets',
#   'bigger',
#   'and',
#   'bigger',
#   'in',
#   'the',
#   'sky',
#   'yeah',
#   'that',
#   'big',
#   'hot',
#   'second',
#   'su',
#   'oh',
#   'no',
#   'what',
#   'is',
#   'that',
#   'doing',
#   'here',
#   'huh',
#   'what',
#   'is',
#   'it',
#   'amethyst',
#   'picks',
#   'him',
#   'up',
#   'causing',
#   'him',
#   'to',
#   'drop',
#   'the',
#   'bag',
#   'of',
#   'bits',
#   'ah',
#   'my',
#   'bits',
#   'amethyst',
#   'carries',
#   'him',
#   'away',
#   'this',
#   'is',
#   'bad',
#   'look',
#   'at',
#   'the',
#   'size',
#   'of',
#   'it',
#   'i',
#   'had',
#   'no',
#   'idea',
#   'these',
#   'things',
#   'were',
#   'so',
#   'big',
#   'garnet',
#   'pearl',
#   'we',
#   'saw',
#   'some',
#   'of',
#   'us',
#   'are',
#   'trying',
#   'to',
#   'protect',
#   'humanity',
#   'where',
#   'were',
#   'you',
#   'eating',
#   'fry',
#   'bits',
#   'pearl',
#   'groans',
#   'oh',
#   'can',
#   'i',
#   'see',
#   'woah',
#   'the',
#   'orb',
#   'rotates',
#   'and',
#   'opens',
#   'into',
#   'a',
#   'eye',
#   'its',
#   'a',
#   'giant',
#   'eyeball',
#   'awesome',
#   'not',
#   'awesome',
#   'its',
#   'a',
#   'red',
#   'eye',
#   'a',
#   'red',
#   'eye',
#   'its',
#   'going',
#   'to',
#   'infect',
#   'us',
#   'all',
#   'thats',
#   'pink',
#   'eye',
#   'steven',
#   'amethyst',
#   'laughs',
#   'its',
#   'going',
#   'to',
#   'crash',
#   'into',
#   'beach',
#   'city',
#   'and',
#   'crush',
#   'us',
#   'along',
#   'with',
#   'a',
#   'bunch',
#   'of',
#   'oblivious',
#   'innocent',
#   'people',
#   'we',
#   'have',
#   'to',
#   'stop',
#   'it',
#   'what',
#   'are',
#   'we',
#   'going',
#   'to',
#   'do',
#   'the',
#   'only',
#   'thing',
#   'powerful',
#   'enough',
#   'to',
#   'destroy',
#   'it',
#   'is',
#   'a',
#   'laser',
#   'cannon',
#   'that',
#   'belonged',
#   'to',
#   'rose',
#   'quartz',
#   'my',
#   'mom',
#   'if',
#   'rose',
#   'were',
#   'here',
#   'this',
#   'would',
#   'be',
#   'so',
#   'easy',
#   'i',
#   'know',
#   'but',
#   'shes',
#   'not',
#   'and',
#   'the',
#   'cannon',
#   'is',
#   'missing',
#   'well',
#   'have',
#   'to',
#   'find',
#   'another',
#   'solution',
#   'if',
#   'it',
#   'belonged',
#   'to',
#   'my',
#   'mom',
#   'i',
#   'bet',
#   'my',
#   'dad',
#   'knows',
#   'where',
#   'it',
#   'is',
#   'he',
#   'can',
#   'help',
#   'us',
#   'save',
#   'the',
#   'day',
#   'the',
#   'crystal',
#   'gems',
#   'are',
#   'speechless',
#   'huh',
#   'ehh',
#   'greg',
#   'is',
#   'nice',
#   'steven',
#   'but',
#   'i',
#   'doubt',
#   'rose',
#   'would',
#   'entrust',
#   'someone',
#   'like',
#   'him',
#   'with',
#   'such',
#   'a',
#   'powerful',
#   'weapon',
#   'your',
#   'dad',
#   'is',
#   'kind',
#   'of',
#   'a',
#   'mess',
#   'steven',
#   'amethyst',
#   'im',
#   'just',
#   'sayin',
#   'even',
#   'if',
#   'she',
#   'did',
#   'leave',
#   'it',
#   'with',
#   'him',
#   'he',
#   'probably',
#   'broke',
#   'it',
#   'or',
#   'lost',
#   'it',
#   'or',
#   'dropped',
#   'it',
#   'in',
#   'the',
#   'ocean',
#   'by',
#   'now',
#   'true',
#   'no',
#   'way',
#   'im',
#   'sure',
#   'hes',
#   'just',
#   'keeping',
#   'it',
#   'somewhere',
#   'safe',
#   'ill',
#   'go',
#   'ask',
#   'him',
#   'we',
#   'can',
#   'handle',
#   'this',
#   'steven',
#   'ready',
#   'ugh',
#   'im',
#   'gonna',
#   'go',
#   'okay',
#   'good',
#   'luck',
#   'dad',
#   'its',
#   'me',
#   'dad',
#   'are',
#   'you',
#   'in',
#   'there',
#   'wake',
#   'up',
#   'we',
#   'have',
#   'to',
#   'save',
#   'the',
#   'world',
#   'dad',
#   'whos',
#   'there',
#   'i',
#   'have',
#   'a',
#   'waffle',
#   'iron',
#   'dad',
#   'its',
#   'me',
#   'steven',
#   'steven',
#   'jumps',
#   'down',
#   'of',
#   'the',
#   'van',
#   'and',
#   'hugs',
#   'him',
#   'i',
#   'almost',
#   'waffled',
#   'your',
#   'face',
#   'what',
#   'are',
#   'you',
#   'doing',
#   'up',
#   'so',
#   'late',
#   'what',
#   'do',
#   'you',
#   'mean',
#   'the',
#   'sun',
#   'just',
#   'went',
#   'down',
#   'an',
#   'hour',
#   'ago',
#   'oh',
#   'heh',
#   'it',
#   'was',
#   'a',
#   'slow',
#   'day',
#   'at',
#   'the',
#   'car',
#   'wash',
#   'anyway',
#   'whats',
#   'up',
#   'just',
#   'needed',
#   'to',
#   'see',
#   'your',
#   'old',
#   'man',
#   'pal',
#   'around',
#   'learn',
#   'some',
#   'lessons',
#   'about',
#   'life',
#   'no',
#   'i',
#   'need',
#   'the',
#   'light',
#   'cannon',
#   'that',
#   'belonged',
#   'to',
#   'mom',
#   'to',
#   'blow',
#   'up',
#   'that',
#   'eyeball',
#   'eyeball',
#   'that',
#   'wait',
#   'is',
#   'that',
#   'a',
#   'magical',
#   'thing',
#   'the',
#   'gems',
#   'told',
#   'me',
#   'not',
#   'to',
#   'get',
#   'involved',
#   'with',
#   'magic',
#   'stuff',
#   'it',
#   'it',
#   'could',
#   'be',
#   'dangerous',
#   'or',
#   'interfere',
#   'with',
#   'whats',
#   'left',
#   'of',
#   'my',
#   'hair',
#   'but',
#   'they',
#   'need',
#   'moms',
#   'cannon',
#   'youve',
#   'gotta',
#   'know',
#   'where',
#   'it',
#   'is',
#   'like',
#   'a',
#   'cave',
#   'dungeon',
#   'or',
#   'a',
#   'cloud',
#   'fortress',
#   'or',
#   'in',
#   'a',
#   'clam',
#   'at',
#   'the',
#   'bottom',
#   'of',
#   'the',
#   'ocean',
#   'well',
#   'i',
#   'dont',
#   'know',
#   'about',
#   'all',
#   'that',
#   'but',
#   'i',
#   'have',
#   'an',
#   'idea',
#   'where',
#   'it',
#   'might',
#   'be',
#   'a',
#   'magical',
#   'storage',
#   'unit',
#   'ha',
#   'not',
#   'exactly',
#   'but',
#   'some',
#   'would',
#   'say',
#   'theres',
#   'magic',
#   'inside',
#   'its',
#   'just',
#   'a',
#   'shed',
#   'i',
#   'use',
#   'to',
#   'keep',
#   'things',
#   'that',
#   'dont',
#   'fit',
#   'in',
#   'the',
#   'van',
#   'if',
#   'its',
#   'anywhere',
#   'itll',
#   'be',
#   'in',
#   'here',
#   'if',
#   'im',
#   'going',
#   'in',
#   'there',
#   'im',
#   'gonna',
#   'need',
#   'some',
#   'gear',
#   'here',
#   'i',
#   'go',
#   'good',
#   'luck',
#   'woah',
#   'cool',
#   'its',
#   'like',
#   'a',
#   'dad',
#   'museum',
#   'there',
#   'it',
#   'is',
#   'do',
#   'you',
#   'golf',
#   'eh',
#   'id',
#   'like',
#   'to',
#   'think',
#   'of',
#   'myself',
#   'as',
#   'someone',
#   'who',
#   'would',
#   'golf',
#   'eventually',
#   'hmm',
#   'yes',
#   'a',
#   'drum',
#   'no',
#   'no',
#   'oh',
#   'my',
#   'gosh',
#   'oh',
#   'my',
#   'gosh',
#   'oh',
#   'my',
#   'gosh',
#   'is',
#   'this',
#   'buy',
#   'tshirt',
#   'cannons',
#   'hey',
#   'theres',
#   'a',
#   'bunch',
#   'of',
#   'copies',
#   'of',
#   'your',
#   'old',
#   'cd',
#   'huh',
#   'oh',
#   'man',
#   'i',
#   'couldnt',
#   'give',
#   'those',
#   'things',
#   'away',
#   'you',
#   'know',
#   'before',
#   'i',
#   'ran',
#   'the',
#   'car',
#   'wash',
#   'when',
#   'i',
#   'was',
#   'a',
#   'oneman',
#   'band',
#   'i',
#   'traveled',
#   'the',
#   'whole',
#   'country',
#   'i',
#   'know',
#   'dad',
#   'when',
#   'i',
#   'came',
#   'to',
#   'play',
#   'a',
#   'concert',
#   'here',
#   'in',
#   'beach',
#   'city',
#   'no',
#   'one',
#   'showed',
#   'up',
#   'except',
#   'an',
#   'alligator',
#   'no',
#   'it',
#   'was',
#   'your',
#   'mother',
#   'hahaha',
#   'i',
#   'know',
#   'and',
#   'we',
#   'were',
#   'always',
#   'together',
#   'after',
#   'that',
#   'until',
#   'she',
#   'gave',
#   'up',
#   'her',
#   'physical',
#   'form',
#   'to',
#   'bring',
#   'you',
#   'into',
#   'the',
#   'world',
#   'i',
#   'dont',
#   'know',
#   'what',
#   'a',
#   'magic',
#   'lady',
#   'like',
#   'her',
#   'ever',
#   'saw',
#   'in',
#   'a',
#   'plain',
#   'old',
#   'dope',
#   'like',
#   'me',
#   'uh',
#   'dad',
#   'i',
#   'broke',
#   'a',
#   'photo',
#   'its',
#   'okay',
#   'buddy',
#   'if',
#   'every',
#   'pork',
#   'chop',
#   'were',
#   'perfect',
#   'we',
#   'wouldnt',
#   'have',
#   'hot',
#   'dogs',
#   'huh',
#   'the',
#   'light',
#   'cannon',
#   'oh',
#   'boy',
#   'that',
#   'things',
#   'giving',
#   'me',
#   'the',
#   'willies',
#   'dad',
#   'i',
#   'found',
#   'it',
#   'really',
#   'get',
#   'the',
#   'van',
#   'with',
#   'the',
#   'other',
#   'end',
#   'tied',
#   'to',
#   'his',
#   'van',
#   'greg',
#   'pulls',
#   'the',
#   'cannon',
#   'out',
#   'of',
#   'the',
#   'shed',
#   'along',
#   'with',
#   'all',
#   'his',
#   'other',
#   'possessions',
#   'which',
#   'collapse',
#   'afterwards',
#   'this',
#   'thing',
#   'could',
#   'save',
#   'the',
#   'city',
#   'weve',
#   'gotta',
#   'get',
#   'it',
#   'to',
#   'the',
#   'beach',
#   'how',
#   'its',
#   'too',
#   'big',
#   'for',
#   'the',
#   'van',
#   'easy',
#   'does',
#   'it',
#   'they',
#   'drop',
#   'the',
#   'cannon',
#   'onto',
#   'the',
#   'wagon',
#   'and',
#   'its',
#   'base',
#   'breaks',
#   'from',
#   'the',
#   'cannons',
#   'weight',
#   'steven',
#   'and',
#   'greg',
#   'are',
#   'speechless',
#   'is',
#   'it',
#   'gonna',
#   'be',
#   'okay',
#   'if',
#   'every',
#   'pork',
#   'chop',
#   'were',
#   'perfect',
#   'we',
#   'wouldnt',
#   'have',
#   'hot',
#   'dogs',
#   'that',
#   'things',
#   'getting',
#   'huge',
#   'its',
#   'freaking',
#   'me',
#   'out',
#   'cant',
#   'the',
#   'van',
#   'go',
#   'any',
#   'faster',
#   'this',
#   'is',
#   'faster',
#   'dont',
#   'worry',
#   'come',
#   'on',
#   'lets',
#   'put',
#   'on',
#   'your',
#   'cd',
#   'what',
#   'really',
#   'come',
#   'on',
#   'youve',
#   'heard',
#   'it',
#   'you',
#   'come',
#   'on',
#   'throw',
#   'me',
#   'again',
#   'i',
#   'think',
#   'im',
#   'cracking',
#   'it',
#   'is',
#   'that',
#   'hey',
#   'guys',
#   'he',
#   'really',
#   'had',
#   'it',
#   'were',
#   'saved',
#   'woah',
#   'whoa',
#   'whoa',
#   'whoa',
#   'easy',
#   'the',
#   'buildings',
#   'sign',
#   'gets',
#   'ripped',
#   'off',
#   'and',
#   'mr',
#   'fryman',
#   'dodges',
#   'out',
#   'of',
#   'its',
#   'way',
#   'we',
#   'have',
#   'to',
#   'use',
#   'it',
#   'now',
#   'i',
#   'dont',
#   'know',
#   'how',
#   'it',
#   'works',
#   'it',
#   'was',
#   'roses',
#   'dad',
#   'how',
#   'do',
#   'we',
#   'use',
#   'it',
#   'greg',
#   'shrugs',
#   'steven',
#   'this',
#   'is',
#   'serious',
#   'the',
#   'gem',
#   'you',
#   'have',
#   'roses',
#   'gem',
#   'thats',
#   'it',
#   'ahhh',
#   'come',
#   'on',
#   'stop',
#   'that',
#   'its',
#   'no',
#   'use',
#   'fine',
#   'forget',
#   'it',
#   'throw',
#   'me',
#   'again',
#   'thats',
#   'not',
#   'going',
#   ...],
#  'Cheeseburger Backpack': ['hey',
#   'mr',
#   'postman',
#   'bring',
#   'me',
#   'a',
#   'post',
#   'bring',
#   'me',
#   'the',
#   'post',
#   'that',
#   'i',
#   'love',
#   'the',
#   'most',
#   'huh',
#   'my',
#   'song',
#   'came',
#   'true',
#   'do',
#   'you',
#   'have',
#   'a',
#   'package',
#   'for',
#   'me',
#   'today',
#   'hold',
#   'on',
#   'let',
#   'me',
#   'see',
#   'what',
#   'ive',
#   'got',
#   'here',
#   'did',
#   'you',
#   'order',
#   'a',
#   'loaf',
#   'of',
#   'bread',
#   'with',
#   'a',
#   'stamp',
#   'on',
#   'it',
#   'no',
#   'did',
#   'you',
#   'order',
#   'a',
#   'jury',
#   'summon',
#   'for',
#   'rj',
#   'finkle',
#   'thats',
#   'not',
#   'me',
#   'im',
#   'steven',
#   'oh',
#   'right',
#   'right',
#   'right',
#   'steven',
#   'here',
#   'it',
#   'is',
#   'steven',
#   'universe',
#   'ha',
#   'this',
#   'thing',
#   'is',
#   'gonna',
#   'help',
#   'me',
#   'save',
#   'the',
#   'world',
#   'really',
#   'it',
#   'says',
#   'its',
#   'from',
#   'wacky',
#   'sacks',
#   'supply',
#   'company',
#   'garnet',
#   'amethyst',
#   'and',
#   'pearl',
#   'think',
#   'i',
#   'shouldnt',
#   'go',
#   'on',
#   'magic',
#   'adventures',
#   'because',
#   'i',
#   'dont',
#   'know',
#   'how',
#   'to',
#   'use',
#   'my',
#   'gem',
#   'powers',
#   'that',
#   'seems',
#   'reasonable',
#   'but',
#   'there',
#   'are',
#   'other',
#   'ways',
#   'i',
#   'can',
#   'help',
#   'with',
#   'a',
#   'wacky',
#   'sack',
#   'exactly',
#   'do',
#   'you',
#   'know',
#   'how',
#   'you',
#   'can',
#   'save',
#   'my',
#   'world',
#   'sign',
#   'here',
#   'please',
#   'aah',
#   'barb',
#   'yells',
#   'at',
#   'me',
#   'if',
#   'i',
#   'dont',
#   'get',
#   'signatures',
#   'thats',
#   'awful',
#   'stevens',
#   'house',
#   'suddenly',
#   'starts',
#   'glowing',
#   'from',
#   'the',
#   'inside',
#   'garnet',
#   'amethyst',
#   'and',
#   'pearl',
#   'are',
#   'back',
#   'wait',
#   'steven',
#   'what',
#   'is',
#   'a',
#   'wacky',
#   'sack',
#   'huh',
#   'hello',
#   'steven',
#   'amethyst',
#   'we',
#   'do',
#   'not',
#   'need',
#   'that',
#   'its',
#   'not',
#   'going',
#   'to',
#   'fit',
#   'in',
#   'the',
#   'fridge',
#   'what',
#   'i',
#   'got',
#   'this',
#   'look',
#   'it',
#   'fits',
#   'ha',
#   'oh',
#   'man',
#   'we',
#   'can',
#   'make',
#   'a',
#   'big',
#   'omelet',
#   'or',
#   'a',
#   'quiche',
#   'or',
#   'big',
#   'sunny',
#   'side',
#   'ups',
#   'we',
#   'fought',
#   'a',
#   'giant',
#   'bird',
#   'were',
#   'only',
#   'here',
#   'for',
#   'a',
#   'second',
#   'weve',
#   'got',
#   'to',
#   'go',
#   'back',
#   'out',
#   'what',
#   'why',
#   'we',
#   'have',
#   'to',
#   'place',
#   'this',
#   'moon',
#   'goddess',
#   'statue',
#   'on',
#   'the',
#   'top',
#   'of',
#   'the',
#   'lunar',
#   'sea',
#   'spire',
#   'before',
#   'midnight',
#   'without',
#   'it',
#   'the',
#   'whole',
#   'place',
#   'will',
#   'fall',
#   'apart',
#   'oh',
#   'steven',
#   'you',
#   'should',
#   'have',
#   'seen',
#   'the',
#   'spire',
#   'in',
#   'its',
#   'heyday',
#   'it',
#   'was',
#   'an',
#   'oasis',
#   'for',
#   'gems',
#   'on',
#   'earth',
#   'its',
#   'abandoned',
#   'now',
#   'but',
#   'we',
#   'can',
#   'still',
#   'save',
#   'it',
#   'with',
#   'this',
#   'statue',
#   'wha',
#   'thats',
#   'perfect',
#   'what',
#   'why',
#   'because',
#   'i',
#   'can',
#   'help',
#   'carry',
#   'it',
#   'for',
#   'you',
#   'in',
#   'this',
#   'a',
#   'hamburger',
#   'its',
#   'a',
#   'novelty',
#   'backpack',
#   'shaped',
#   'like',
#   'a',
#   'cheeseburger',
#   'aww',
#   'i',
#   'blew',
#   'it',
#   'i',
#   'was',
#   'just',
#   'going',
#   'to',
#   'wear',
#   'it',
#   'one',
#   'day',
#   'and',
#   'you',
#   'guys',
#   'would',
#   'be',
#   'like',
#   'dang',
#   'steven',
#   'thats',
#   'so',
#   'cool',
#   'but',
#   'this',
#   'is',
#   'obviously',
#   'important',
#   'gem',
#   'business',
#   'yes',
#   'so',
#   'you',
#   'should',
#   'let',
#   'us',
#   'take',
#   'care',
#   'of',
#   'it',
#   'what',
#   'im',
#   'a',
#   'gem',
#   'but',
#   'youve',
#   'still',
#   'got',
#   'a',
#   'lot',
#   'to',
#   'learn',
#   'so',
#   'let',
#   'him',
#   'come',
#   'itll',
#   'be',
#   'educational',
#   'hmm',
#   'alright',
#   'you',
#   'can',
#   'carry',
#   'it',
#   'in',
#   'your',
#   'hamburger',
#   'hmm',
#   'check',
#   'this',
#   'out',
#   'everythings',
#   'a',
#   'pocket',
#   'even',
#   'the',
#   'cheese',
#   'is',
#   'a',
#   'pocket',
#   'i',
#   'could',
#   'fit',
#   'a',
#   'lot',
#   'more',
#   'stuff',
#   'in',
#   'here',
#   'give',
#   'me',
#   'a',
#   'minute',
#   'ill',
#   'pack',
#   'extra',
#   'supplies',
#   'ooh',
#   'kid',
#   'dont',
#   'shake',
#   'me',
#   'mr',
#   'queasy',
#   'ooh',
#   'i',
#   'got',
#   'a',
#   'medical',
#   'condition',
#   'youre',
#   'definitely',
#   'gonna',
#   'come',
#   'in',
#   'handy',
#   'steeeveeen',
#   'lets',
#   'gooo',
#   'coming',
#   'woah',
#   'steven',
#   'did',
#   'you',
#   'bring',
#   'your',
#   'whole',
#   'room',
#   'back',
#   'that',
#   'thang',
#   'up',
#   'lets',
#   'warp',
#   'suck',
#   'it',
#   'in',
#   'steven',
#   'do',
#   'you',
#   'remember',
#   'how',
#   'to',
#   'do',
#   'this',
#   'keep',
#   'your',
#   'head',
#   'in',
#   'come',
#   'on',
#   'whoa',
#   'the',
#   'sea',
#   'spire',
#   'it',
#   'wasnt',
#   'like',
#   'this',
#   'a',
#   'hundred',
#   'years',
#   'ago',
#   'im',
#   'sensing',
#   'structural',
#   'instability',
#   'oh',
#   'yeah',
#   'thats',
#   'never',
#   'good',
#   'gah',
#   'steven',
#   'what',
#   'the',
#   'ground',
#   'below',
#   'starts',
#   'to',
#   'break',
#   'off',
#   'pearl',
#   'manages',
#   'to',
#   'save',
#   'steven',
#   'just',
#   'in',
#   'time',
#   'as',
#   'the',
#   'ground',
#   'collapses',
#   'into',
#   'the',
#   'water',
#   'alright',
#   'hold',
#   'on',
#   'were',
#   'taking',
#   'steven',
#   'back',
#   'ooh',
#   'my',
#   'aching',
#   'stomach',
#   'oh',
#   'mr',
#   'queasy',
#   'its',
#   'killing',
#   'me',
#   'steven',
#   'this',
#   'place',
#   'is',
#   'your',
#   'heritage',
#   'i',
#   'want',
#   'you',
#   'to',
#   'stay',
#   'and',
#   'help',
#   'but',
#   'you',
#   'really',
#   'got',
#   'to',
#   'take',
#   'this',
#   'seriously',
#   'can',
#   'you',
#   'do',
#   'that',
#   'steven',
#   'you',
#   'got',
#   'it',
#   'dude',
#   'yessssss',
#   'enough',
#   'we',
#   'have',
#   'to',
#   'move',
#   'whats',
#   'the',
#   'holdup',
#   'we',
#   'can',
#   'clear',
#   'this',
#   'easily',
#   'no',
#   'the',
#   'magic',
#   'that',
#   'sustains',
#   'the',
#   'whirlpool',
#   'creates',
#   'a',
#   'vortex',
#   'that',
#   'will',
#   'pull',
#   'us',
#   'below',
#   'so',
#   'we',
#   'cant',
#   'jump',
#   'oh',
#   'wait',
#   'what',
#   'are',
#   'those',
#   'for',
#   'they',
#   'were',
#   'for',
#   'keeping',
#   'warm',
#   'but',
#   'check',
#   'it',
#   'out',
#   'steven',
#   'wait',
#   'hes',
#   'getting',
#   'sucked',
#   'down',
#   'steven',
#   'cheesssseburrrrgerrrr',
#   'steven',
#   'way',
#   'to',
#   'go',
#   'cmon',
#   'guys',
#   'steven',
#   'style',
#   'dont',
#   'ever',
#   'do',
#   'that',
#   'again',
#   'sorry',
#   'gets',
#   'patted',
#   'on',
#   'the',
#   'head',
#   'by',
#   'garnet',
#   'but',
#   'it',
#   'was',
#   'pretty',
#   'great',
#   'oh',
#   'no',
#   'no',
#   'no',
#   'this',
#   'is',
#   'even',
#   'worse',
#   'than',
#   'the',
#   'outside',
#   'ugh',
#   'thats',
#   'oh',
#   'oh',
#   'this',
#   'didnt',
#   'used',
#   'to',
#   'be',
#   'so',
#   'oh',
#   'and',
#   'the',
#   'water',
#   'damage',
#   'this',
#   'pillar',
#   'oh',
#   'and',
#   'this',
#   'had',
#   'a',
#   'head',
#   'oh',
#   'steven',
#   'once',
#   'the',
#   'statues',
#   'in',
#   'place',
#   'itll',
#   'restore',
#   'all',
#   'of',
#   'this',
#   'to',
#   'its',
#   'former',
#   'glory',
#   'aah',
#   'ah',
#   'aaah',
#   'what',
#   'was',
#   'that',
#   'goober',
#   'crystal',
#   'shrimp',
#   'you',
#   'guys',
#   'we',
#   'got',
#   'a',
#   'problem',
#   'its',
#   'an',
#   'infestation',
#   'and',
#   'we',
#   'have',
#   'to',
#   'pass',
#   'through',
#   'there',
#   'to',
#   'get',
#   'to',
#   'the',
#   'top',
#   'cant',
#   'you',
#   'just',
#   'squish',
#   'em',
#   'dont',
#   'touch',
#   'that',
#   'their',
#   'shards',
#   'are',
#   'deadly',
#   'we',
#   'need',
#   'to',
#   'clear',
#   'a',
#   'path',
#   'amethyst',
#   'if',
#   'you',
#   'go',
#   'around',
#   'to',
#   'the',
#   'side',
#   'and',
#   'disturb',
#   'them',
#   'with',
#   'a',
#   'spin',
#   'attack',
#   'and',
#   'garnet',
#   'if',
#   'you',
#   'move',
#   'to',
#   'the',
#   'ceiling',
#   'and',
#   'strike',
#   'this',
#   'exact',
#   'spot',
#   'then',
#   'i',
#   'can',
#   'advance',
#   'with',
#   'my',
#   'bagel',
#   'sandwich',
#   'brilliant',
#   'oh',
#   'hey',
#   'what',
#   'do',
#   'you',
#   'know',
#   'uh',
#   'uhh',
#   'how',
#   'did',
#   'you',
#   'know',
#   'that',
#   'would',
#   'work',
#   'well',
#   'if',
#   'i',
#   'were',
#   'a',
#   'shrimp',
#   'thats',
#   'what',
#   'i',
#   'would',
#   'do',
#   'you',
#   'are',
#   'a',
#   'shrimp',
#   'i',
#   'just',
#   'want',
#   'everyone',
#   'to',
#   'know',
#   'my',
#   'plan',
#   'would',
#   'have',
#   'also',
#   'worked',
#   'watch',
#   'out',
#   'what',
#   'are',
#   'we',
#   'gonna',
#   'do',
#   'what',
#   'me',
#   'what',
#   'have',
#   'you',
#   'got',
#   'cheeseburger',
#   'backpack',
#   'cheeseburger',
#   'backpack',
#   'steven',
#   'nervously',
#   'searches',
#   'inside',
#   'his',
#   'backpack',
#   'pearl',
#   'cmon',
#   'oh',
#   'alright',
#   'cheeseburger',
#   'backpack',
#   'cheeseburger',
#   'backpack',
#   'cheeseburger',
#   'backpack',
#   'a',
#   'raaaaft',
#   'wow',
#   'steven',
#   'thats',
#   'so',
#   'sensible',
#   'good',
#   'idea',
#   'anyway',
#   'steven',
#   'yeah',
#   'they',
#   'cant',
#   'all',
#   'be',
#   'winners',
#   'this',
#   'is',
#   'it',
#   'the',
#   'moon',
#   'goddess',
#   'pedestal',
#   'and',
#   'the',
#   'moon',
#   'is',
#   'almost',
#   'overhead',
#   'its',
#   'not',
#   'too',
#   'late',
#   'to',
#   'save',
#   'this',
#   'piece',
#   'of',
#   'history',
#   'steven',
#   'the',
#   'statue',
#   'uhh',
#   'i',
#   'uh',
#   'ah',
#   'uhh',
#   'whats',
#   'the',
#   'holdup',
#   'i',
#   'dont',
#   'have',
#   'it',
#   'what',
#   'i',
#   'must',
#   'have',
#   'left',
#   'it',
#   'on',
#   'the',
#   'bed',
#   'theres',
#   'theres',
#   'no',
#   'time',
#   'wait',
#   'i',
#   'have',
#   'an',
#   'idea',
#   'aah',
#   'could',
#   'that',
#   'work',
#   'oh',
#   'kid',
#   'dont',
#   'shake',
#   'me',
#   'everyone',
#   'keep',
#   'steady',
#   'amethyst',
#   'collapses',
#   'into',
#   'garnet',
#   'no',
#   'no',
#   'no',
#   'no',
#   'no',
#   'this',
#   'is',
#   'all',
#   'my',
#   'fault',
#   'i',
#   'broke',
#   'it',
#   'no',
#   'steven',
#   'the',
#   'spire',
#   'was',
#   'falling',
#   'apart',
#   'when',
#   'we',
#   'got',
#   'here',
#   'you',
#   'handled',
#   'everything',
#   'well',
#   'under',
#   'pressure',
#   'you',
#   'did',
#   'great',
#   'yeah',
#   'two',
#   'out',
#   'of',
#   'four',
#   'of',
#   'your',
#   'ideas',
#   'worked',
#   'thats',
#   'fifty',
#   'percent',
#   'yeah',
#   'i',
#   'guess',
#   'youre',
#   'right',
#   'they',
#   'cant',
#   'all',
#   'be',
#   'winners',
#   ...],
#  'Together Breakfast': ['everyones',
#   'out',
#   'guess',
#   'im',
#   'makin',
#   'us',
#   'breakfast',
#   'pearl',
#   'garnet',
#   'amethyst',
#   'is',
#   'anyone',
#   'home',
#   'hm',
#   'one',
#   'two',
#   'three',
#   'warp',
#   'in',
#   'i',
#   'guess',
#   'theyre',
#   'still',
#   'out',
#   'saving',
#   'the',
#   'world',
#   'look',
#   'at',
#   'you',
#   'you',
#   'are',
#   'out',
#   'of',
#   'control',
#   'pearl',
#   'garnet',
#   'its',
#   'done',
#   'that',
#   'things',
#   'too',
#   'good',
#   'for',
#   'me',
#   'to',
#   'eat',
#   'alone',
#   'its',
#   'a',
#   'together',
#   'breakfast',
#   'ah',
#   'garnet',
#   'perfect',
#   'check',
#   'it',
#   'out',
#   'its',
#   'not',
#   'exactly',
#   'healthy',
#   'but',
#   'its',
#   'in',
#   'a',
#   'stack',
#   'so',
#   'i',
#   'guess',
#   'you',
#   'could',
#   'say',
#   'its',
#   'a',
#   'balanced',
#   'breakfast',
#   'you',
#   'know',
#   'like',
#   'i',
#   'made',
#   'us',
#   'all',
#   'breakfast',
#   'i',
#   'thought',
#   'we',
#   'could',
#   'eat',
#   'together',
#   'like',
#   'like',
#   'best',
#   'buds',
#   'i',
#   'cant',
#   'stay',
#   'theres',
#   'business',
#   'to',
#   'attend',
#   'to',
#   'inside',
#   'the',
#   'temple',
#   'aw',
#   'business',
#   'like',
#   'what',
#   'i',
#   'have',
#   'to',
#   'burn',
#   'this',
#   'cool',
#   'ah',
#   'i',
#   'have',
#   'to',
#   'burn',
#   'this',
#   'too',
#   'no',
#   'my',
#   'apps',
#   'door',
#   'open',
#   'door',
#   'nothing',
#   'happens',
#   'aw',
#   'you',
#   'never',
#   'work',
#   'when',
#   'i',
#   'need',
#   'it',
#   'dumb',
#   'police',
#   'uhhh',
#   'youre',
#   'dumb',
#   'nooooooo',
#   'oh',
#   'man',
#   'i',
#   'totally',
#   'got',
#   'you',
#   'you',
#   'shouldve',
#   'seen',
#   'the',
#   'look',
#   'on',
#   'your',
#   'face',
#   'aw',
#   'i',
#   'knew',
#   'it',
#   'was',
#   'you',
#   'pfft',
#   'how',
#   'because',
#   'thats',
#   'a',
#   'water',
#   'gun',
#   'and',
#   'im',
#   'not',
#   'dumb',
#   'youve',
#   'got',
#   'something',
#   'on',
#   'your',
#   'shirt',
#   'hey',
#   'thats',
#   'my',
#   'door',
#   'oh',
#   'amethyst',
#   'there',
#   'you',
#   'are',
#   'care',
#   'to',
#   'explain',
#   'what',
#   'one',
#   'of',
#   'my',
#   'swords',
#   'was',
#   'doing',
#   'in',
#   'your',
#   'room',
#   'having',
#   'a',
#   'sword',
#   'party',
#   'oh',
#   'please',
#   'you',
#   'took',
#   'it',
#   'i',
#   'did',
#   'not',
#   'its',
#   'fine',
#   'its',
#   'in',
#   'the',
#   'past',
#   'i',
#   'forgive',
#   'you',
#   'also',
#   'i',
#   'cleaned',
#   'up',
#   'your',
#   'awful',
#   'awful',
#   'mess',
#   'youre',
#   'welcome',
#   'you',
#   'did',
#   'what',
#   'i',
#   'have',
#   'a',
#   'system',
#   'amethyst',
#   'wait',
#   'whats',
#   'the',
#   'matter',
#   'steven',
#   'i',
#   'wanted',
#   'us',
#   'all',
#   'to',
#   'have',
#   'breakfast',
#   'together',
#   'so',
#   'i',
#   'made',
#   'together',
#   'breakfast',
#   'but',
#   'everyone',
#   'keeps',
#   'leaving',
#   'ah',
#   'thats',
#   'nice',
#   'oh',
#   'no',
#   'not',
#   'you',
#   'too',
#   'i',
#   'cant',
#   'let',
#   'this',
#   'become',
#   'together',
#   'brunch',
#   'hmm',
#   'there',
#   'we',
#   'go',
#   'ahh',
#   'hey',
#   'peaaaarl',
#   'steven',
#   'what',
#   'are',
#   'you',
#   'doing',
#   'in',
#   'here',
#   'you',
#   'know',
#   'its',
#   'dangerous',
#   'for',
#   'you',
#   'inside',
#   'the',
#   'temple',
#   'were',
#   'going',
#   'to',
#   'have',
#   'a',
#   'nice',
#   'together',
#   'breakfast',
#   'even',
#   'if',
#   'i',
#   'have',
#   'to',
#   'get',
#   'my',
#   'shoes',
#   'wet',
#   'what',
#   'get',
#   'out',
#   'of',
#   'there',
#   'ill',
#   'swim',
#   'it',
#   'over',
#   'to',
#   'you',
#   'see',
#   'doggy',
#   'paddle',
#   'forward',
#   'oh',
#   'gosh',
#   'wait',
#   'doggy',
#   'paddle',
#   'reverse',
#   'reverse',
#   'steven',
#   'what',
#   'the',
#   'woah',
#   'keep',
#   'it',
#   'together',
#   'breakfast',
#   'keep',
#   'it',
#   'together',
#   'breakfast',
#   'better',
#   'amethyst',
#   'oh',
#   'hey',
#   'steven',
#   'did',
#   'you',
#   'come',
#   'down',
#   'the',
#   'waterfall',
#   'pearl',
#   'gets',
#   'so',
#   'mad',
#   'that',
#   'i',
#   'have',
#   'her',
#   'junk',
#   'but',
#   'its',
#   'always',
#   'falling',
#   'down',
#   'here',
#   'junk',
#   'like',
#   'what',
#   'junk',
#   'like',
#   'you',
#   'imma',
#   'throw',
#   'you',
#   'in',
#   'the',
#   'junk',
#   'pile',
#   'isnt',
#   'it',
#   'awful',
#   'pearl',
#   'organized',
#   'everything',
#   'still',
#   'looks',
#   'messy',
#   'to',
#   'me',
#   'aw',
#   'thanks',
#   'i',
#   'try',
#   'boom',
#   'oh',
#   'whats',
#   'that',
#   'steven',
#   'its',
#   'a',
#   'together',
#   'breakfast',
#   'alright',
#   'snacks',
#   'no',
#   'its',
#   'for',
#   'everyone',
#   'to',
#   'eat',
#   'together',
#   'thats',
#   'the',
#   'essence',
#   'of',
#   'together',
#   'breakfast',
#   'oh',
#   'gimme',
#   'gimme',
#   'we',
#   'have',
#   'to',
#   'eat',
#   'it',
#   'together',
#   'through',
#   'the',
#   'twisting',
#   'corridor',
#   'which',
#   'turns',
#   'him',
#   'upside',
#   'down',
#   'huh',
#   'the',
#   'together',
#   'breakfast',
#   'begins',
#   'to',
#   'fall',
#   'due',
#   'to',
#   'gravity',
#   'woah',
#   'you',
#   'cant',
#   'outrun',
#   'me',
#   'we',
#   'both',
#   'have',
#   'short',
#   'legs',
#   'steven',
#   'im',
#   'hungry',
#   'just',
#   'hold',
#   'on',
#   'an',
#   'exit',
#   'woo',
#   'skills',
#   'get',
#   'back',
#   'here',
#   'youre',
#   'completely',
#   'missing',
#   'the',
#   'point',
#   'of',
#   'this',
#   'hey',
#   'wait',
#   'a',
#   'second',
#   'steven',
#   'there',
#   'you',
#   'are',
#   'pearl',
#   'sweet',
#   'two',
#   'out',
#   'of',
#   'three',
#   'oh',
#   'oh',
#   'steven',
#   'be',
#   'careful',
#   'why',
#   'wha',
#   'whoa',
#   'you',
#   'really',
#   'shouldnt',
#   'be',
#   'in',
#   'here',
#   'this',
#   'is',
#   'the',
#   'crystal',
#   'heart',
#   'oh',
#   'its',
#   'connected',
#   'to',
#   'the',
#   'most',
#   'dangerous',
#   'areas',
#   'of',
#   'the',
#   'temple',
#   'hold',
#   'on',
#   'tight',
#   'and',
#   'dont',
#   'look',
#   'down',
#   'aaah',
#   'no',
#   'oh',
#   'hey',
#   'this',
#   'isnt',
#   'so',
#   'bad',
#   'ah',
#   'nevermind',
#   'aw',
#   'steven',
#   'were',
#   'getting',
#   'you',
#   'out',
#   'of',
#   'here',
#   'come',
#   'on',
#   'ah',
#   'this',
#   'is',
#   'great',
#   'were',
#   'all',
#   'together',
#   'we',
#   'can',
#   'finally',
#   'eat',
#   'pearl',
#   'and',
#   'amethyst',
#   'run',
#   'towards',
#   'garnet',
#   'i',
#   'mean',
#   'we',
#   'dont',
#   'have',
#   'any',
#   'forks',
#   'but',
#   'we',
#   'can',
#   'use',
#   'our',
#   'hands',
#   'im',
#   'not',
#   'gonna',
#   'judge',
#   'steven',
#   'go',
#   'okay',
#   'want',
#   'to',
#   'meet',
#   'in',
#   'the',
#   'kitchen',
#   'its',
#   'trying',
#   'to',
#   'escape',
#   'force',
#   'it',
#   'back',
#   'steven',
#   'ugh',
#   'the',
#   'breakfast',
#   'begins',
#   'to',
#   'move',
#   'on',
#   'its',
#   'own',
#   'together',
#   'breakfast',
#   'its',
#   'taken',
#   'refuge',
#   'in',
#   'organic',
#   'matter',
#   'the',
#   'monster',
#   'attacks',
#   'pearl',
#   'and',
#   'sticks',
#   'her',
#   'to',
#   'the',
#   'wall',
#   'with',
#   'a',
#   'mix',
#   'of',
#   'whipped',
#   'cream',
#   'and',
#   'syrup',
#   'now',
#   'it',
#   'has',
#   'all',
#   'the',
#   'power',
#   'of',
#   'a',
#   'breakfast',
#   'we',
#   'have',
#   'to',
#   'destroy',
#   'it',
#   'aah',
#   'its',
#   'horrible',
#   'i',
#   'didnt',
#   'want',
#   'this',
#   'i',
#   'just',
#   'wanted',
#   'to',
#   'eat',
#   'together',
#   'like',
#   'like',
#   'best',
#   'buds',
#   'steven',
#   'youve',
#   'got',
#   'to',
#   'get',
#   'away',
#   'but',
#   'my',
#   'breakfast',
#   'thats',
#   'enough',
#   'i',
#   'dont',
#   'care',
#   'if',
#   'you',
#   'are',
#   'the',
#   'most',
#   'important',
#   'meal',
#   'of',
#   'the',
#   'day',
#   'i',
#   'made',
#   'you',
#   'to',
#   'bring',
#   'us',
#   'together',
#   'not',
#   'to',
#   'tear',
#   'us',
#   'apart',
#   'im',
#   'sorry',
#   'guys',
#   'i',
#   'guess',
#   'i',
#   'dreamed',
#   'too',
#   'big',
#   'it',
#   'looks',
#   'great',
#   'its',
#   'even',
#   'more',
#   'together',
#   'and',
#   'even',
#   'more',
#   'breakfast',
#   'i',
#   'dont',
#   'think',
#   'i',
#   'can',
#   'eat',
#   'this',
#   'lets',
#   'order',
#   'a',
#   'pizza',
#   'steven',
#   'and',
#   'pearl',
#   'agree',
#   'it',
#   'did',
#   'try',
#   'to',
#   'kill',
#   'us'],
#  'Frybo': ['where',
#   'are',
#   'you',
#   'tsk',
#   'tsk',
#   'tsk',
#   'youre',
#   'a',
#   'mess',
#   'steven',
#   'i',
#   'know',
#   'i',
#   'had',
#   'eight',
#   'hey',
#   'steven',
#   'have',
#   'you',
#   'seen',
#   'a',
#   'gem',
#   'shard',
#   'anywhere',
#   'its',
#   'very',
#   'important',
#   'no',
#   'have',
#   'you',
#   'seen',
#   'my',
#   'pants',
#   'theyre',
#   'also',
#   'very',
#   'important',
#   'im',
#   'serious',
#   'steven',
#   'these',
#   'shards',
#   'have',
#   'a',
#   'powerful',
#   'partial',
#   'consciousness',
#   'that',
#   'has',
#   'been',
#   'harnessed',
#   'by',
#   'gems',
#   'throughout',
#   'history',
#   'in',
#   'order',
#   'to',
#   'create',
#   'they',
#   'werent',
#   'in',
#   'the',
#   'kitchen',
#   'either',
#   'under',
#   'the',
#   'bed',
#   'no',
#   'wait',
#   'i',
#   'looked',
#   'there',
#   'too',
#   'and',
#   'then',
#   'pearl',
#   'walked',
#   'in',
#   'semisentient',
#   'drone',
#   'soldiers',
#   'with',
#   'the',
#   'capacity',
#   'to',
#   'follow',
#   'basic',
#   'orders',
#   'gems',
#   'once',
#   'created',
#   'an',
#   'army',
#   'of',
#   'these',
#   'drones',
#   'but',
#   'found',
#   'their',
#   'obedience',
#   'waned',
#   'as',
#   'the',
#   'shards',
#   'overdeveloped',
#   'inside',
#   'their',
#   'uniforms',
#   'and',
#   'turned',
#   'on',
#   'their',
#   'commanders',
#   'you',
#   'see',
#   'any',
#   'shard',
#   'imprinted',
#   'by',
#   'any',
#   'sort',
#   'of',
#   'container',
#   'pearl',
#   'oh',
#   'jeez',
#   'shes',
#   'really',
#   'explaining',
#   'something',
#   'i',
#   'cant',
#   'just',
#   'start',
#   'listening',
#   'now',
#   'id',
#   'be',
#   'lost',
#   'just',
#   'like',
#   'my',
#   'pants',
#   'could',
#   'become',
#   'a',
#   'monster',
#   'thats',
#   'why',
#   'its',
#   'very',
#   'very',
#   'important',
#   'its',
#   'kept',
#   'away',
#   'from',
#   'any',
#   'kind',
#   'of',
#   'garment',
#   'if',
#   'you',
#   'see',
#   'it',
#   'bring',
#   'it',
#   'to',
#   'me',
#   'right',
#   'away',
#   'im',
#   'going',
#   'to',
#   'check',
#   'in',
#   'town',
#   'for',
#   'my',
#   'pants',
#   'i',
#   'guess',
#   'ill',
#   'keep',
#   'looking',
#   'here',
#   'thats',
#   'unusual',
#   'come',
#   'on',
#   'we',
#   'used',
#   'to',
#   'be',
#   'friends',
#   'we',
#   'used',
#   'to',
#   'go',
#   'everywhere',
#   'together',
#   'gotcha',
#   'now',
#   'pants',
#   'i',
#   'wear',
#   'the',
#   'pants',
#   'in',
#   'this',
#   'relationship',
#   'whats',
#   'gotten',
#   'into',
#   'you',
#   'hmm',
#   'its',
#   'a',
#   'thingie',
#   'is',
#   'this',
#   'pearls',
#   'shard',
#   'thingy',
#   'the',
#   'shard',
#   'glows',
#   'and',
#   'tugs',
#   'on',
#   'stevens',
#   'shirt',
#   'which',
#   'he',
#   'quickly',
#   'pulls',
#   'away',
#   'he',
#   'then',
#   'grabs',
#   'a',
#   'sock',
#   'nearby',
#   'and',
#   'puts',
#   'the',
#   'shard',
#   'inside',
#   'ha',
#   'now',
#   'whos',
#   'smart',
#   'the',
#   'sock',
#   'animates',
#   'and',
#   'repeatedly',
#   'smacks',
#   'him',
#   'in',
#   'the',
#   'face',
#   'ow',
#   'ow',
#   'ow',
#   'ow',
#   'ow',
#   'stop',
#   'the',
#   'sock',
#   'compels',
#   'to',
#   'his',
#   'command',
#   'oh',
#   'thanks',
#   'i',
#   'gotta',
#   'get',
#   'you',
#   'to',
#   'pearl',
#   'hey',
#   'pearl',
#   'pearl',
#   'she',
#   'must',
#   'still',
#   'be',
#   'looking',
#   'for',
#   'my',
#   'pants',
#   'aah',
#   'please',
#   'help',
#   'me',
#   'aah',
#   'no',
#   'get',
#   'them',
#   'away',
#   'please',
#   'aah',
#   'im',
#   'not',
#   'fries',
#   'gah',
#   'wheres',
#   'your',
#   'face',
#   'frybo',
#   'being',
#   'part',
#   'of',
#   'the',
#   'fryman',
#   'family',
#   'means',
#   'you',
#   'gotta',
#   'sell',
#   'fries',
#   'and',
#   'be',
#   'my',
#   'son',
#   'which',
#   'you',
#   'are',
#   'peedee',
#   'sighs',
#   'so',
#   'youre',
#   'already',
#   'halfway',
#   'there',
#   'keep',
#   'at',
#   'it',
#   'frybo',
#   'im',
#   'pee',
#   'fryman',
#   'closes',
#   'door',
#   'dee',
#   'hi',
#   'peedee',
#   'when',
#   'i',
#   'told',
#   'my',
#   'dad',
#   'i',
#   'wanted',
#   'to',
#   'be',
#   'part',
#   'of',
#   'the',
#   'fryman',
#   'family',
#   'business',
#   'i',
#   'didnt',
#   'think',
#   'it',
#   'meant',
#   'being',
#   'stuck',
#   'in',
#   'a',
#   'sweaty',
#   'old',
#   'costume',
#   'things',
#   'used',
#   'to',
#   'be',
#   'different',
#   'steven',
#   'nothing',
#   'to',
#   'worry',
#   'about',
#   'back',
#   'then',
#   'except',
#   'making',
#   'myself',
#   'dizzy',
#   'on',
#   'the',
#   'old',
#   'seahorse',
#   'ride',
#   'at',
#   'funland',
#   'oh',
#   'frybo',
#   'youre',
#   'hilarious',
#   'i',
#   'wish',
#   'there',
#   'was',
#   'a',
#   'way',
#   'for',
#   'this',
#   'costume',
#   'to',
#   'do',
#   'its',
#   'job',
#   'without',
#   'me',
#   'in',
#   'it',
#   'maybe',
#   'it',
#   'can',
#   'peedee',
#   'maybe',
#   'it',
#   'can',
#   'oooooh',
#   'aah',
#   'waahhh',
#   'wait',
#   'i',
#   'have',
#   'another',
#   'idea',
#   'woah',
#   'frybo',
#   'rolls',
#   'around',
#   'aimlessly',
#   'stop',
#   'frybo',
#   'compels',
#   'unbelievable',
#   'get',
#   'up',
#   'frybo',
#   'positions',
#   'itself',
#   'upright',
#   'do',
#   'a',
#   'little',
#   'dance',
#   'woahho',
#   'all',
#   'right',
#   'its',
#   'about',
#   'ti',
#   'i',
#   'mean',
#   'good',
#   'job',
#   'buddy',
#   'thats',
#   'what',
#   'im',
#   'talking',
#   'about',
#   'frybo',
#   'ha',
#   'ha',
#   'keep',
#   'it',
#   'up',
#   'free',
#   'im',
#   'free',
#   'youve',
#   'got',
#   'the',
#   'job',
#   'frybo',
#   'lets',
#   'shake',
#   'on',
#   'it',
#   'hes',
#   'got',
#   'jokes',
#   'ok',
#   'no',
#   'more',
#   'shaking',
#   'put',
#   'me',
#   'down',
#   'frybo',
#   'drops',
#   'him',
#   'on',
#   'the',
#   'ground',
#   'just',
#   'go',
#   'make',
#   'people',
#   'eat',
#   'fries',
#   'frybo',
#   'runs',
#   'off',
#   'and',
#   'peedee',
#   'rejoices',
#   'lets',
#   'go',
#   'be',
#   'kids',
#   'this',
#   'seahorse',
#   'used',
#   'to',
#   'make',
#   'me',
#   'so',
#   'happy',
#   'now',
#   'its',
#   'just',
#   'giving',
#   'me',
#   'whiplash',
#   'i',
#   'feel',
#   'like',
#   'theres',
#   'just',
#   'no',
#   'point',
#   'to',
#   'it',
#   'you',
#   'know',
#   'what',
#   'i',
#   'mean',
#   'i',
#   'just',
#   'feel',
#   'tingly',
#   'youll',
#   'understand',
#   'when',
#   'you',
#   'have',
#   'a',
#   'job',
#   'his',
#   'ride',
#   'comes',
#   'to',
#   'a',
#   'stop',
#   'i',
#   'do',
#   'have',
#   'a',
#   'job',
#   'i',
#   'protect',
#   'humanity',
#   'from',
#   'magic',
#   'and',
#   'monsters',
#   'and',
#   'stuff',
#   'i',
#   'mean',
#   'a',
#   'real',
#   'job',
#   'that',
#   'you',
#   'get',
#   'paid',
#   'for',
#   'im',
#   'paid',
#   'in',
#   'the',
#   'smiles',
#   'across',
#   'the',
#   'towns',
#   'faces',
#   'i',
#   'dont',
#   'see',
#   'anyone',
#   'smiling',
#   'you',
#   'pick',
#   'up',
#   'a',
#   'job',
#   'to',
#   'buy',
#   'a',
#   'house',
#   'or',
#   'raise',
#   'kids',
#   'or',
#   'to',
#   'impress',
#   'your',
#   'dad',
#   'you',
#   'work',
#   'away',
#   'your',
#   'life',
#   'and',
#   'what',
#   'does',
#   'it',
#   'get',
#   'you',
#   'smiles',
#   'on',
#   'faces',
#   'no',
#   'you',
#   'get',
#   'cash',
#   'cash',
#   'that',
#   'cant',
#   'buy',
#   'back',
#   'what',
#   'the',
#   'job',
#   'takes',
#   'not',
#   'if',
#   'you',
#   'rode',
#   'every',
#   'seahorse',
#   'in',
#   'the',
#   'world',
#   'woah',
#   'wanna',
#   'try',
#   'the',
#   'jellyfish',
#   'that',
#   'came',
#   'from',
#   'the',
#   'fry',
#   'shop',
#   'we',
#   'didnt',
#   'tell',
#   'him',
#   'to',
#   'do',
#   'that',
#   'did',
#   'we',
#   'tell',
#   'him',
#   'to',
#   'do',
#   'that',
#   'a',
#   'table',
#   'smashes',
#   'through',
#   'the',
#   'counter',
#   'windows',
#   'which',
#   'both',
#   'peedee',
#   'and',
#   'steven',
#   'duck',
#   'and',
#   'dodge',
#   'in',
#   'time',
#   'they',
#   'then',
#   'look',
#   'inside',
#   'the',
#   'building',
#   'please',
#   'no',
#   'more',
#   'fries',
#   'frybo',
#   'repeatedly',
#   'shoves',
#   'his',
#   'mouth',
#   'full',
#   'of',
#   'fries',
#   'frybo',
#   'stop',
#   'i',
#   'dont',
#   'even',
#   'like',
#   'fries',
#   'why',
#   'isnt',
#   'he',
#   'listening',
#   'i',
#   'dont',
#   'know',
#   'peedee',
#   'wheres',
#   'all',
#   'this',
#   'coming',
#   'from',
#   'frybo',
#   'ensnares',
#   'him',
#   'with',
#   'a',
#   'tendril',
#   'peedee',
#   'peeped',
#   'over',
#   'the',
#   'counter',
#   'ah',
#   'i',
#   'get',
#   'it',
#   'i',
#   'pushed',
#   'you',
#   'too',
#   'hard',
#   'i',
#   'thought',
#   'you',
#   'wanted',
#   'to',
#   'be',
#   'as',
#   'good',
#   'a',
#   'fryman',
#   'as',
#   'you',
#   'could',
#   'be',
#   'youre',
#   'a',
#   'tough',
#   'kid',
#   'for',
#   'putting',
#   'up',
#   'with',
#   'it',
#   'as',
#   'long',
#   'as',
#   'you',
#   'did',
#   'the',
#   'truth',
#   'is',
#   'youre',
#   'a',
#   'valued',
#   'member',
#   'of',
#   'fryman',
#   'brothers',
#   'incorporated',
#   'and',
#   'all',
#   'its',
#   'affiliates',
#   'daaaddddd',
#   'no',
#   'hell',
#   'mash',
#   'your',
#   'potatoes',
#   'tries',
#   'to',
#   'climb',
#   'over',
#   'the',
#   'counter',
#   'what',
#   'are',
#   'you',
#   'going',
#   'to',
#   'do',
#   'my',
#   'job',
#   'steven',
#   'did',
#   'you',
#   'put',
#   'my',
#   'missing',
#   'shard',
#   'in',
#   'that',
#   'fry',
#   'costume',
#   'yes',
#   'didnt',
#   'you',
#   'hear',
#   'what',
#   'i',
#   'said',
#   'about',
#   'the',
#   'living',
#   'armor',
#   'and',
#   'infantries',
#   'and',
#   'many',
#   'many',
#   'deaths',
#   'no',
#   'oh',
#   'steven',
#   'pearl',
#   'ugh',
#   'the',
#   'ketchup',
#   'its',
#   'everywhere',
#   'i',
#   'cant',
#   'see',
#   'shards',
#   'need',
#   'wah',
#   'steven',
#   'daaaddddd',
#   'go',
#   'away',
#   'peedee',
#   'you',
#   'are',
#   'awful',
#   'i',
#   'hate',
#   'you',
#   'ive',
#   'always',
#   'hated',
#   'you',
#   'wait',
#   'youve',
#   'always',
#   'hated',
#   'frybo',
#   'steven',
#   'where',
#   'your',
#   'move',
#   'frybo',
#   'attack',
#   'i',
#   'didnt',
#   'want',
#   'to',
#   'do',
#   'this',
#   'but',
#   'you',
#   'leave',
#   'me',
#   'no',
#   'choice',
#   'underwear',
#   'go',
#   'steven',
#   'are',
#   'you',
#   'alright',
#   'fine',
#   'im',
#   'okay',
#   'as',
#   'soon',
#   'as',
#   'i',
#   'bared',
#   'my',
#   'butt',
#   'i',
#   'knew',
#   'hed',
#   'crack',
#   'you',
#   'were',
#   'great',
#   'frybo',
#   'the',
#   'kids',
#   'today',
#   'just',
#   'didnt',
#   'understand',
#   'now',
#   'they',
#   'never',
#   'will',
#   'werent',
#   'people',
#   'scared',
#   'of',
#   'it',
#   'before',
#   'he',
#   'attacked',
#   'them',
#   'steven',
#   'shushes',
#   'her',
#   'its',
#   'time',
#   'to',
#   'send',
#   'him',
#   'off',
#   'he',
#   'takes',
#   'out',
#   'a',
#   'lighter',
#   'and',
#   'sets',
#   'frybo',
#   'on',
#   'fire',
#   'pearl',
#   'using',
#   'the',
#   'end',
#   'of',
#   'her',
#   'spear',
#   'pushes',
#   'it',
#   'out',
#   'to',
#   'sea',
#   'as',
#   'greasy',
#   'in',
#   'death',
#   'as',
#   'he',
#   'was',
#   'in',
#   'life',
#   'dad',
#   'uhm',
#   'ill',
#   'are',
#   'you',
#   'going',
#   'to',
#   'get',
#   'another',
#   'costume',
#   'i',
#   'dont',
#   'need',
#   'another',
#   'frybo',
#   'i',
#   ...],
#  'Cat Fingers': ['almost',
#   'done',
#   'steven',
#   'get',
#   'the',
#   'hubcaps',
#   'hubbing',
#   'it',
#   'up',
#   'hub',
#   'it',
#   'good',
#   'this',
#   'is',
#   'a',
#   'highprofile',
#   'job',
#   'you',
#   'mean',
#   'cause',
#   'its',
#   'the',
#   'mayors',
#   'electionmobile',
#   'if',
#   'we',
#   'do',
#   'this',
#   'right',
#   'we',
#   'might',
#   'get',
#   'political',
#   'favors',
#   'im',
#   'not',
#   'sure',
#   'what',
#   'that',
#   'is',
# ...
#   'show',
#   'up',
#   'for',
#   'a',
#   'visit',
#   'what',
#   'is',
#   'that',
#   'thing',
#   'that',
#   'thing',
#   'is',
#   'steven',
#   'what',
#   'impossible',
#   'is',
#   'he',
#   'corrupted',
#   'but',
#   'how',
#   'never',
#   'mind',
#   'that',
#   'we',
#   'have',
#   'to',
#   'change',
#   'him',
#   'back',
#   'leave',
#   'it',
#   'to',
#   'me',
#   'with',
#   'my',
#   'new',
#   'power',
#   'i',
#   'should',
#   'be',
#   'able',
#   'to',
#   'alter',
#   'his',
#   'physical',
#   'form',
#   'hes',
#   'resisting',
#   'maybe',
#   'he',
#   'needs',
#   'to',
#   'feel',
#   'better',
#   'first',
#   'i',
#   'can',
#   'help',
#   'with',
#   'that',
#   'look',
#   'out',
#   'wow',
#   'your',
#   'new',
#   'power',
#   'didnt',
#   'work',
#   'either',
#   'enough',
#   'i',
#   'know',
#   'exactly',
#   'how',
#   'to',
#   'help',
#   'if',
#   'i',
#   'connect',
#   'with',
#   'him',
#   'and',
#   'he',
#   'speaks',
#   'through',
#   'me',
#   'maybe',
#   'well',
#   'understand',
#   'what',
#   'hes',
#   'going',
#   'through',
#   'now',
#   'then',
#   'do',
#   'you',
#   'hear',
#   'me',
#   'steven',
#   'just',
#   'relax',
#   'and',
#   'let',
#   'me',
#   'in',
#   'wait',
#   'ahh',
#   'white',
#   'what',
#   'happened',
#   'oh',
#   'thats',
#   'not',
#   'steven',
#   'anymore',
#   'ii',
#   'cant',
#   'hold',
#   'him',
#   'much',
#   'longer',
#   'guys',
#   'look',
#   'the',
#   'cluster',
#   'is',
#   'trying',
#   'to',
#   'hold',
#   'steven',
#   'back',
#   'i',
#   'cant',
#   'believe',
#   'it',
#   'hes',
#   'even',
#   'stronger',
#   'than',
#   'the',
#   'cluster',
#   'dont',
#   'let',
#   'your',
#   'guard',
#   'down',
#   'he',
#   'could',
#   'break',
#   'free',
#   'at',
#   'any',
#   'moment',
#   'deep',
#   'inside',
#   'thismonster',
#   'steven',
#   'must',
#   'be',
#   'in',
#   'there',
#   'so',
#   'angry',
#   'i',
#   'knew',
#   'something',
#   'was',
#   'goin',
#   'on',
#   'i',
#   'uh',
#   'why',
#   'didnt',
#   'i',
#   'do',
#   'something',
#   'if',
#   'we',
#   'dont',
#   'get',
#   'through',
#   'to',
#   'him',
#   'hell',
#   'stay',
#   'like',
#   'this',
#   'forever',
#   'dude',
#   'you',
#   'should',
#   'get',
#   'outta',
#   'here',
#   'before',
#   'you',
#   'get',
#   'hurt',
#   'no',
#   'every',
#   'time',
#   'gem',
#   'stuff',
#   'happens',
#   'i',
#   'run',
#   'the',
#   'other',
#   'way',
#   'this',
#   'is',
#   'my',
#   'son',
#   'and',
#   'hes',
#   'right',
#   'to',
#   'be',
#   'angry',
#   'because',
#   'i',
#   'didnt',
#   'protect',
#   'him',
#   'you',
#   'didnt',
#   'protect',
#   'him',
#   'from',
#   'us',
#   'hes',
#   'like',
#   'this',
#   'because',
#   'of',
#   'us',
#   'were',
#   'the',
#   'source',
#   'of',
#   'stevens',
#   'suffering',
#   'this',
#   'is',
#   'my',
#   'fault',
#   'spinel',
#   'dont',
#   'be',
#   'silly',
#   'everyone',
#   'knows',
#   'that',
#   'all',
#   'of',
#   'this',
#   'is',
#   'because',
#   'of',
#   'me',
#   'no',
#   'its',
#   'because',
#   'of',
#   'me',
#   'i',
#   'tried',
#   'to',
#   'wipe',
#   'his',
#   'friends',
#   'memories',
#   'so',
#   'he',
#   'could',
#   'die',
#   'alone',
#   'on',
#   'a',
#   'barren',
#   'world',
#   'but',
#   'that',
#   'was',
#   'because',
#   'you',
#   'were',
#   'angry',
#   'with',
#   'pink',
#   'and',
#   'if',
#   'pink',
#   'hurt',
#   'you',
#   'it',
#   'was',
#   'because',
#   'i',
#   'hurt',
#   'her',
#   'like',
#   'i',
#   'hurt',
#   'yellow',
#   'and',
#   'blue',
#   'and',
#   'steven',
#   'and',
#   'everyone',
#   'in',
#   'the',
#   'entire',
#   'universe',
#   'this',
#   'is',
#   'all',
#   'my',
#   'fault',
#   'yes',
#   'it',
#   'is',
#   'yes',
#   'you',
#   'hurt',
#   'him',
#   'but',
#   'this',
#   'isnt',
#   'the',
#   'time',
#   'to',
#   'make',
#   'this',
#   'all',
#   'about',
#   'you',
#   'that',
#   'is',
#   'not',
#   'helping',
#   'maybe',
#   'steven',
#   'would',
#   'care',
#   'how',
#   'sad',
#   'you',
#   'are',
#   'because',
#   'he',
#   'always',
#   'puts',
#   'everyone',
#   'elses',
#   'feelings',
#   'first',
#   'but',
#   'he',
#   'cant',
#   'do',
#   'that',
#   'for',
#   'you',
#   'right',
#   'now',
#   'because',
#   'he',
#   'needs',
#   'us',
#   'this',
#   'time',
#   'we',
#   'all',
#   'had',
#   'steven',
#   'when',
#   'we',
#   'needed',
#   'him',
#   'but',
#   'the',
#   'only',
#   'person',
#   'whos',
#   'never',
#   'had',
#   'steven',
#   'is',
#   'steven',
#   'hes',
#   'always',
#   'been',
#   'there',
#   'for',
#   'us',
#   'so',
#   'how',
#   'can',
#   'we',
#   'be',
#   'there',
#   'for',
#   'him',
#   'now',
#   'i',
#   'know',
#   'how',
#   'okay',
#   'no',
#   'time',
#   'to',
#   'waste',
#   'yellow',
#   'make',
#   'me',
#   'as',
#   'big',
#   'as',
#   'him',
#   'right',
#   'blue',
#   'lift',
#   'everyone',
#   'up',
#   'of',
#   'course',
#   'everyone',
#   'get',
#   'in',
#   'line',
#   'you',
#   'got',
#   'it',
#   'its',
#   'time',
#   'to',
#   'show',
#   'stevensome',
#   'love',
#   'sorry',
#   'buddy',
#   'i',
#   'need',
#   'you',
#   'to',
#   'stay',
#   'here',
#   'steven',
#   'steven',
#   'steven',
#   'steven',
#   'steven',
#   'steven',
#   'when',
#   'i',
#   'fell',
#   'apart',
#   'you',
#   'were',
#   'there',
#   'for',
#   'me',
#   'i',
#   'want',
#   'to',
#   'be',
#   'there',
#   'for',
#   'you',
#   'now',
#   'im',
#   'here',
#   'steven',
#   'im',
#   'here',
#   'this',
#   'is',
#   'working',
#   'you',
#   'hear',
#   'us',
#   'steven',
#   'im',
#   'here',
#   'schtuball',
#   'whatever',
#   'you',
#   'need',
#   'ill',
#   'make',
#   'it',
#   'happen',
#   'you',
#   'hear',
#   'me',
#   'steven',
#   'you',
#   'never',
#   'gave',
#   'up',
#   'on',
#   'me',
#   'for',
#   'some',
#   'reason',
#   'i',
#   'dont',
#   'understand',
#   'ill',
#   'do',
#   'the',
#   'same',
#   'for',
#   'you',
#   'i',
#   'know',
#   'you',
#   'feel',
#   'bad',
#   'believe',
#   'me',
#   'i',
#   'get',
#   'it',
#   'sometimes',
#   'it',
#   'feels',
#   'like',
#   'youre',
#   'never',
#   'gonna',
#   'like',
#   'yourself',
#   'but',
#   'its',
#   'possible',
#   'man',
#   'steven',
#   'i',
#   'know',
#   'how',
#   'awful',
#   'it',
#   'feels',
#   'to',
#   'keep',
#   'a',
#   'part',
#   'of',
#   'yourself',
#   'secret',
#   'you',
#   'shouldnt',
#   'have',
#   'to',
#   'hide',
#   'anything',
#   'from',
#   'me',
#   'steven',
#   'you',
#   'must',
#   'have',
#   'been',
#   'so',
#   'afraid',
#   'to',
#   'show',
#   'us',
#   'this',
#   'side',
#   'of',
#   'yourself',
#   'but',
#   'were',
#   'not',
#   'going',
#   'anywhere',
#   'were',
#   'all',
#   'gonna',
#   'take',
#   'care',
#   'of',
#   'you',
#   'the',
#   'same',
#   'way',
#   'you',
#   'take',
#   'care',
#   'of',
#   'us',
#   'you',
#   'know',
#   'what',
#   'i',
#   'dont',
#   'have',
#   'your',
#   'powers',
#   'but',
#   'huh',
#   'wha',
#   'i',
#   'd',
#   'did',
#   'i',
#   'im',
#   'lion',
#   'lion'],
#  'The Future': ['lets',
#   'exercise',
#   'cha',
#   'one',
#   'two',
#   'two',
#   'two',
#   'three',
#   'two',
#   'four',
#   'two',
#   'good',
#   'morning',
#   'steven',
#   'one',
#   'last',
#   'routine',
#   'before',
#   'hitting',
#   'the',
#   'road',
#   'yeah',
#   'ill',
#   'be',
#   'sitting',
#   'for',
#   'a',
#   'while',
#   'ill',
#   'be',
#   'in',
#   'charm',
#   'city',
#   'in',
#   'time',
#   'for',
#   'shep',
#   'and',
#   'sadies',
#   'concert',
#   'ill',
#   'meet',
#   'up',
#   'with',
#   'you',
#   'and',
#   'lion',
#   'on',
#   'providence',
#   'island',
#   'when',
#   'youre',
#   'touring',
#   'schools',
#   'and',
#   'then',
#   'ill',
#   'catch',
#   'up',
#   'with',
#   'lars',
#   'for',
#   'our',
#   'weekly',
#   'space',
#   'hangout',
#   'ill',
#   'add',
#   'that',
#   'to',
#   'your',
#   'boogle',
#   'maps',
#   'doc',
#   'so',
#   'how',
#   'did',
#   'everyone',
#   'take',
#   'the',
#   'news',
#   'i',
#   'basically',
#   'told',
#   'everyone',
#   'in',
#   'beach',
#   'city',
#   'plus',
#   'my',
#   'dad',
#   'but',
#   'i',
#   'havent',
#   'told',
#   'the',
#   'gems',
#   'yet',
#   'you',
#   'gotta',
#   'tell',
#   'them',
#   'ii',
#   'know',
#   'i',
#   'just',
#   'have',
#   'no',
#   'idea',
#   'how',
#   'theyre',
#   'going',
#   'to',
#   'take',
#   'it',
#   'theyve',
#   'been',
#   'so',
#   'protective',
#   'of',
#   'me',
#   'these',
#   'last',
#   'few',
#   'months',
#   'since',
#   'my',
#   'meltdown',
#   'i',
#   'wonder',
#   'if',
#   'theres',
#   'a',
#   'way',
#   'i',
#   'can',
#   'let',
#   'them',
#   'down',
#   'easy',
#   'oh',
#   'steven',
#   'were',
#   'you',
#   'waiting',
#   'for',
#   'us',
#   'i',
#   'sure',
#   'was',
#   'whoa',
#   'cookie',
#   'cat',
#   'i',
#   'thought',
#   'they',
#   'stopped',
#   'making',
#   'them',
#   'they',
#   'did',
#   'so',
#   'i',
#   'made',
#   'my',
#   'own',
#   'you',
#   'can',
#   'kinda',
#   'tell',
#   'theyre',
#   'delicious',
#   'mmmmmm',
#   'scrumptious',
#   'remember',
#   'when',
#   'you',
#   'used',
#   'to',
#   'sing',
#   'that',
#   'song',
#   'for',
#   'us',
#   'if',
#   'i',
#   'may',
#   'oohhhhh',
#   'hes',
#   'a',
#   'frozen',
#   'treat',
#   'with',
#   'an',
#   'all',
#   'new',
#   'taste',
#   'cause',
#   'he',
#   'came',
#   'to',
#   'this',
#   'planet',
#   'from',
#   'outer',
#   'space',
#   'a',
#   'refugee',
#   'of',
#   'an',
#   'interstellar',
#   'war',
#   'but',
#   'now',
#   'hes',
#   'at',
#   'your',
#   'local',
#   'grocery',
#   'store',
#   'cookie',
#   'cat',
#   'hes',
#   'a',
#   'pet',
#   'for',
#   'your',
#   'tummy',
#   'cookie',
#   'cat',
#   'hes',
#   'superduper',
#   'yummy',
#   'cookie',
#   'cat',
#   'he',
#   'left',
#   'his',
#   'family',
#   'behind',
#   'thats',
#   'right',
#   'he',
#   'did',
#   'leave',
#   'his',
#   'family',
#   'behind',
#   'thats',
#   'not',
#   'how',
#   'it',
#   'goes',
#   'i',
#   'think',
#   'maybe',
#   'cookie',
#   'cat',
#   'had',
#   'run',
#   'out',
#   'of',
#   'ways',
#   'to',
#   'grow',
#   'on',
#   'his',
#   'home',
#   'planet',
#   'and',
#   'even',
#   'though',
#   'it',
#   'mustve',
#   'been',
#   'hard',
#   'and',
#   'he',
#   'loved',
#   'his',
#   'family',
#   'so',
#   'so',
#   'much',
#   'maybe',
#   'he',
#   'had',
#   'to',
#   'leave',
#   'to',
#   'keep',
#   'moving',
#   'forward',
#   'were',
#   'still',
#   'talking',
#   'about',
#   'ice',
#   'cream',
#   'right',
#   'everyone',
#   'ive',
#   'decided',
#   'to',
#   'move',
#   'out',
#   'dont',
#   'worry',
#   'about',
#   'me',
#   'i',
#   'have',
#   'a',
#   'very',
#   'comprehensive',
#   'plan',
#   'to',
#   'visit',
#   'all',
#   'states',
#   'before',
#   'i',
#   'decide',
#   'where',
#   'to',
#   'settle',
#   'down',
#   'and',
#   'i',
#   'can',
#   'still',
#   'video',
#   'chat',
#   'my',
#   'new',
#   'therapist',
#   'while',
#   'im',
#   'on',
#   'the',
#   'road',
#   'do',
#   'not',
#   'try',
#   'to',
#   'talk',
#   'me',
#   'out',
#   'of',
#   'this',
#   'when',
#   'are',
#   'you',
#   'leaving',
#   'uh',
#   'tomorrow',
#   'oh',
#   'so',
#   'soon',
#   'well',
#   'all',
#   'human',
#   'adolescents',
#   'need',
#   'to',
#   'seize',
#   'their',
#   'independence',
#   'eventually',
#   'im',
#   'so',
#   'happy',
#   'for',
#   'you',
#   'yeah',
#   'bud',
#   'ill',
#   'miss',
#   'ya',
#   'peace',
#   'you',
#   'guys',
#   'know',
#   'i',
#   'may',
#   'never',
#   'come',
#   'back',
#   'right',
#   'we',
#   'know',
#   'steven',
#   'this',
#   'will',
#   'be',
#   'an',
#   'exciting',
#   'new',
#   'chapter',
#   'in',
#   'your',
#   'life',
#   'that',
#   'went',
#   'well',
#   'right',
#   'you',
#   'what',
#   'whats',
#   'the',
#   'problem',
#   'steven',
#   'are',
#   'you',
#   'mad',
#   'at',
#   'me',
#   'of',
#   'course',
#   'im',
#   'not',
#   'mad',
#   'at',
#   'you',
#   'then',
#   'dont',
#   'leave',
#   'oh',
#   'no',
#   'am',
#   'i',
#   'smothering',
#   'you',
#   'backs',
#   'away',
#   'i',
#   'get',
#   'it',
#   'i',
#   'get',
#   'it',
#   'bismuth',
#   'how',
#   'about',
#   'i',
#   'build',
#   'you',
#   'a',
#   'nice',
#   'vacation',
#   'house',
#   'just',
#   'outside',
#   'of',
#   'little',
#   'homeworld',
#   'listen',
#   'to',
#   'me',
#   'steven',
#   'you',
#   'cant',
#   'run',
#   'away',
#   'from',
#   'yourself',
#   'wherever',
#   'you',
#   'go',
#   'youll',
#   'be',
#   'there',
#   'trust',
#   'me',
#   'i',
#   'know',
#   'peridot',
#   'come',
#   'on',
#   'its',
#   'okay',
#   'where',
#   'am',
#   'i',
#   'going',
#   'to',
#   'find',
#   'another',
#   'steven',
#   'as',
#   'good',
#   'as',
#   'you',
#   'huh',
#   'i',
#   'like',
#   'this',
#   'one',
#   'so',
#   'much',
#   'here',
#   'i',
#   'want',
#   'you',
#   'to',
#   'have',
#   'this',
#   'my',
#   'very',
#   'own',
#   'steven',
#   'shirt',
#   'be',
#   'the',
#   'steven',
#   'you',
#   'want',
#   'to',
#   'see',
#   'in',
#   'the',
#   'world',
#   'lapis',
#   'this',
#   'is',
#   'for',
#   'you',
#   'what',
#   'the',
#   'pieces',
#   'crayons',
#   'oil',
#   'pastels',
#   'it',
#   'even',
#   'has',
#   'watercolors',
#   'do',
#   'you',
#   'like',
#   'it',
#   'i',
#   'love',
#   'it',
#   'stay',
#   'back',
#   'steven',
#   'bismuth',
#   'i',
#   'cant',
#   'think',
#   'of',
#   'anyone',
#   'whos',
#   'more',
#   'of',
#   'a',
#   'crystal',
#   'gem',
#   'than',
#   'you',
#   'so',
#   'please',
#   'take',
#   'this',
#   'the',
#   'original',
#   'crystal',
#   'gem',
#   'flag',
#   'oh',
#   'steven',
#   'if',
#   'it',
#   'wasnt',
#   'for',
#   'you',
#   'none',
#   'of',
#   'us',
#   'would',
#   'be',
#   'who',
#   'we',
#   'are',
#   'today',
#   'you',
#   'make',
#   'me',
#   'so',
#   'proud',
#   'to',
#   'be',
#   'a',
#   'crystal',
#   'gem',
#   'why',
#   'did',
#   'you',
#   'have',
#   'to',
#   'put',
#   'it',
#   'so',
#   'well',
#   'bismuth',
#   'im',
#   'gonna',
#   'use',
#   'my',
#   'tears',
#   'to',
#   'make',
#   'a',
#   'watercolor',
#   'painting',
#   'of',
#   'you',
#   'peridot',
#   'lapis',
#   'bismuth',
#   'i',
#   'love',
#   'you',
#   'we',
#   'love',
#   'you',
#   'too',
#   'steven',
#   'heard',
#   'youre',
#   'leaving',
#   'im',
#   'coming',
#   'with',
#   'you',
#   'jasper',
#   'im',
#   'going',
#   'alone',
#   'then',
#   'who',
#   'will',
#   'protect',
#   'you',
#   'i',
#   'can',
#   'protect',
#   'myself',
#   'i',
#   'know',
#   'farewell',
#   'my',
#   'diamond',
#   'whoa',
#   'even',
#   'jaspers',
#   'more',
#   'upset',
#   'than',
#   'my',
#   'own',
#   'family',
#   'maybe',
#   'i',
#   'need',
#   'a',
#   'round',
#   'two',
#   'oh',
#   'amethyst',
#   'huh',
#   'i',
#   'have',
#   'a',
#   'gift',
#   'for',
#   'you',
#   'is',
#   'it',
#   'food',
#   'no',
#   'its',
#   'what',
#   'the',
#   'its',
#   'my',
#   'old',
#   'video',
#   'game',
#   'systems',
#   'aw',
#   'dude',
#   'you',
#   'better',
#   'kiss',
#   'your',
#   'high',
#   'scores',
#   'goodbye',
#   'what',
#   'and',
#   'say',
#   'goodbye',
#   'to',
#   'your',
#   'save',
#   'files',
#   'too',
#   'oh',
#   'ive',
#   'been',
#   'waiting',
#   'forever',
#   'to',
#   'play',
#   'through',
#   'golf',
#   'quest',
#   'mini',
#   'on',
#   'my',
#   'own',
#   'why',
#   'the',
#   'heck',
#   'would',
#   'you',
#   'own',
#   'a',
#   'game',
#   'with',
#   'only',
#   'one',
#   'save',
#   'slot',
#   'anyway',
#   'uhhh',
#   'hello',
#   'pearl',
#   'oh',
#   'hi',
#   'steven',
#   'do',
#   'you',
#   'need',
#   'help',
#   'packing',
#   'no',
#   'its',
#   'just',
#   'im',
#   'leaving',
#   'you',
#   'with',
#   'my',
#   'ukulele',
#   'steven',
#   'thats',
#   'very',
#   'thoughtful',
#   'of',
#   'you',
#   'pearl',
#   'its',
#   'okay',
#   'to',
#   'be',
#   'sad',
#   'that',
#   'im',
#   'leaving',
#   'but',
#   'steven',
#   'its',
#   'a',
#   'good',
#   'thing',
#   'that',
#   'youre',
#   'going',
#   'to',
#   'get',
#   'out',
#   'there',
#   'and',
#   'explore',
#   'the',
#   'world',
#   'its',
#   'not',
#   'something',
#   'to',
#   'be',
#   'sad',
#   'over',
#   'yeah',
#   'youre',
#   'right',
#   'alright',
#   'have',
#   'fun',
#   'garnet',
#   'well',
#   'bust',
#   'my',
#   'britches',
#   'its',
#   'steven',
#   'universe',
#   'im',
#   'here',
#   'to',
#   'give',
#   'you',
#   'a',
#   'very',
#   'important',
#   'and',
#   'sentimental',
#   'gift',
#   'because',
#   'im',
#   'leaving',
#   'getting',
#   'to',
#   'plan',
#   'ruby',
#   'and',
#   'sapphires',
#   'wedding',
#   'was',
#   'so',
#   'amazing',
#   'and',
#   'i',
#   'hope',
#   'that',
#   'one',
#   'day',
#   'you',
#   'can',
#   'help',
#   'me',
#   'plan',
#   'my',
#   'own',
#   'thanks',
#   'ill',
#   'take',
#   'good',
#   'care',
#   'of',
#   'it',
#   'okay',
#   'garnet',
#   'level',
#   'with',
#   'me',
#   'here',
#   'you',
#   'used',
#   'your',
#   'future',
#   'vision',
#   'saw',
#   'that',
#   'everything',
#   'would',
#   'be',
#   'fine',
#   'and',
#   'told',
#   'the',
#   'gems',
#   'not',
#   'to',
#   'worry',
#   'about',
#   'me',
#   'thats',
#   'it',
#   'right',
#   'steven',
#   'i',
#   'dont',
#   'need',
#   'future',
#   'vision',
#   'to',
#   'know',
#   'that',
#   'youre',
#   'gonna',
#   'be',
#   'fine',
#   'besides',
#   'part',
#   'of',
#   'the',
#   'fun',
#   'of',
#   'leaving',
#   'is',
#   'figuring',
#   'it',
#   'out',
#   'on',
#   'your',
#   'own',
#   'you',
#   'alright',
#   'schtuball',
#   'yeah',
#   'its',
#   'just',
#   'just',
#   'what',
#   'well',
#   'i',
#   'told',
#   'the',
#   'gems',
#   'im',
#   'leaving',
#   'but',
#   'i',
#   'dont',
#   'think',
#   'theyre',
#   'even',
#   'sad',
#   'about',
#   'it',
#   'isnt',
#   'that',
#   'a',
#   'good',
#   'thing',
#   'i',
#   'guess',
#   'i',
#   'wanted',
#   'them',
#   'to',
#   'be',
#   'at',
#   'least',
#   'a',
#   'little',
#   'upset',
#   'is',
#   'that',
#   'petty',
#   'youre',
#   'allowed',
#   'to',
#   'have',
#   'feelings',
#   'even',
#   'petty',
#   'ones',
#   'they',
#   'love',
#   'you',
#   'kiddo',
#   'theyre',
#   'probably',
#   'just',
#   'trying',
#   'to',
#   'be',
#   'supportive',
#   'thanks',
#   'dad',
#   'oh',
#   'i',
#   'still',
#   'have',
#   'to',
#   'give',
#   'you',
#   'your',
#   'gift',
#   'its',
#   'all',
#   'yours',
#   'i',
#   'want',
#   'you',
#   'to',
#   'move',
#   'in',
#   'huh',
#   'dont',
#   'you',
#   'think',
#   'its',
#   'a',
#   'little',
#   ...]}

# %%
most_salient = {}
most_salient = find_most_salient(by_episode_corpus, 3)

# %%
most_salient
# Out:
# {'Gem Glow': ['duper', 'gurgens', 'petals'],
#  'Laser Light Cannon': ['su', 'rotates', 'infect'],
#  'Cheeseburger Backpack': ['cheeseburger', 'shrimp', 'hamburger'],
#  'Together Breakfast': ['doggy', 'balanced', 'apps'],
#  'Frybo': ['frybo', 'sock', 'seahorse'],
#  'Cat Fingers': ['arp', 'sloop', 'womp'],
#  'Bubble Buddies': ['trawler', 'harpoon', 'woooh'],
#  'Serious Steven': ['teacups', 'butterflies', 'swarm'],
#  'Tiger Millionaire': ['boos', 'loch', 'ness'],
#  "Steven's Lion": ['column', 'pregnant', 'wwater'],
#  'Arcade Mania': ['mania', 'mutt', 'loses'],
#  'Giant Woman': ['opal', 'goat', 'squawking'],
#  'So Many Birthdays': ['aging', 'burrito', 'piñata'],
#  'Lars and the Cool Kids': ['moss', 'planted', 'lala'],
#  'Onion Trade': ['ranger', 'dave', 'replicator'],
#  'Steven the Sword Fighter': ['parry', 'thrust', 'grr'],
#  'Lion 2: The Movie': ['helicopters', 'missile', 'forehand'],
#  'Beach Party': ['pufferfish', 'outfits', 'cheatin'],
#  "Rose's Room": ['colonel', 'kernels', 'minigolf'],
#  'Coach Steven': ['workout', 'buff', 'bursts'],
#  'Joking Victim': ['actorrb', 'singer', 'gary'],
#  'Steven and the Stevens': ['fat', 'tootin', 'adorbable'],
#  'Monster Buddies': ['acid', 'yum', 'nephrite'],
#  'An Indirect Kiss': ['fountain', 'mayybee', 'horsing'],
#  'Mirror Gem': ['wo', 'ssssteven', 'culture'],
#  'Ocean Gem': ['bury', 'grounding', 'wwwha'],
#  'House Guest': ['duct', 'synthetic', 'zoop'],
#  'Space Race': ['bail', 'mach', 'uuu'],
#  'Secret Team': ['puddles', 'maaa', 'oooooohhhh'],
#  'Island Adventure': ['swam', 'steeeeve', 'waaaaahh'],
#  'Keep Beach City Weird': ['clearance', 'coincidence', 'facts'],
#  'Fusion Cuisine': ['nuclear', 'midseason', 'prefinale'],
#  "Garnet's Universe": ['ringo', 'foxman', 'hoppy'],
#  'Watermelon Steven': ['melon', 'watermelons', 'watermelon'],
#  'Lion 3: Straight to Video': ['lunches', 'hmmmmhmmmm', 'fullest'],
#  'Warp Tour': ['fossa', 'macaroni', 'bingbong'],
#  'Alone Together': ['merges', 'danced', 'itbut'],
#  'The Test': ['bing', 'citchen', 'calamity'],
#  'Future Vision': ['choke', 'pickle', 'ceremonies'],
#  'On the Run': ['raccoon', 'bindle', 'kabloosh'],
#  'Horror Club': ['clubhouse', 'cg', 'notch'],
#  'Winter Forecast': ['carabeena', 'marrow', 'snowed'],
#  'Maximum Capacity': ['fireworks', 'hawaii', 'spirally'],
#  'Marble Madness': ['plinkman', 'lisas', 'oneeyed'],
#  "Rose's Scabbard": ['scabbard', 'clockwise', 'weapony'],
#  'Open Book': ['turkey', 'infinity', 'fin'],
#  'Shirt Club': ['wom', 'bench', 'sighted'],
#  'Story for Steven': ['comet', 'amigo', 'lays'],
#  'The Message': ['microphone', 'plugged', 'daddyo'],
#  'Political Power': ['sisters', 'sundown', 'outage'],
#  'The Return': ['patronize', 'politician', 'luggage'],
#  'Jail Break': ['ooooof', 'looooove', 'loooove'],
#  'Full Disclosure': ['woooooh', 'brood', 'crocodile'],
#  'Joy Ride': ['squares', 'calluses', 'deejay'],
#  'Say Uncle': ['grandpa', 'uncle', 'gus'],
#  'Love Letters': ['camellia', 'rejection', 'jamies'],
#  'Reformed': ['slinker', 'quiz', 'regeneration'],
#  'Sworn to the Sword': ['knight', 'peach', 'plum'],
#  'Rising Tides, Crashing Skies': ['slideshow', 'reenactment', 'handcraft'],
#  'Keeping It Together': ['fold', 'civilified', 'laundary'],
#  'We Need to Talk': ['youwhat', 'dowhat', 'orchestra'],
#  'Chille Tid': ['pierogi', 'ticking', 'theirs'],
#  'Cry for Help': ['pear', 'victories', 'frequencies'],
#  'Keystone Motel': ['diner', 'brushes', 'motels'],
#  'Onion Friend': ['gals', 'karen', 'timed'],
#  'Historical Friction': ['william', 'dunce', 'ruggedly'],
#  'Friend Ship': ['expiration', 'cruddy', 'waaaah'],
#  'Nightmare Hospital': ['ethhh', 'ethhhh', 'abacus'],
#  "Sadie's Song": ['softball', 'dummy', 'stepping'],
#  'Catch and Release': ['slaps', 'flicks', 'pebble'],
#  'When It Rains': ['granola', 'attachments', 'interrogation'],
#  'Back to the Barn': ['technician', 'praise', 'conceded'],
#  'Too Far': ['tungsten', 'exhibited', 'muddy'],
#  'The Answer': ['omg', 'thwarted', 'aristocratic'],
#  "Steven's Birthday": ['adolescent', 'defibrillator', 'infant'],
#  "It Could've Been Great": ['birth', 'domisoti', 'domisodo'],
#  'Message Received': ['questioning', 'brokendown', 'youabout'],
#  'Log Date 7 15 2': ['pierre', 'chicken', 'madness'],
#  'Super Watermelon Island': ['outnumbered', 'emergence', 'tremors'],
#  'Gem Drill': ['ngah', 'peridotite', 'increasing'],
#  'Same Old World': ['jersey', 'layers', 'wapamo'],
#  'Barn Mates': ['sincere', 'compact', 'ceilings'],
#  'Hit the Diamond': ['hiya', 'includes', 'huuugs'],
#  'Steven Floats': ['starving', 'nnnnn', 'velocity'],
#  'Drop Beat Dad': ['roadie', 'guacola', 'roadies'],
#  'Mr. Greg': ['cost', 'burgers', 'palling'],
#  'Too Short to Ride': ['shorty', 'rectangle', 'worldwide'],
#  'The New Lars': ['laramie', 'forests', 'sloth'],
#  'Beach City Drift': ['supremo', 'vroom', 'kevin'],
#  'Restaurant Wars': ['mozzarella', 'offmenu', 'treaty'],
#  "Kiki's Pizza Delivery Service": ['cheddar', 'blasting', 'initials'],
#  'Monster Reunion': ['saluting', 'teartear', 'stecup'],
#  'Alone at Sea': ['pole', 'caviar', 'correction'],
#  'Greg the Babysitter': ['chahahange', 'fulltime', 'admiring'],
#  'Gem Hunt': ['tracks', 'survival', 'smileee'],
#  'Crack the Whip': ['oooooooooon', 'irresponsible', 'ygot'],
#  'Steven vs. Amethyst': ['pouch', 'bmrng', 'versus'],
#  'Bismuth': ['elites', 'recall', 'rituals'],
#  'Beta': ['wapoosh', 'wshh', 'meepmorp'],
#  'Earthlings': ['disgraceful', 'resorted', 'recruiting'],
#  'Back to the Moon': ['leggy', 'prisoners', 'germs'],
#  'Bubbled': ['platoon', 'airlock', 'grump'],
#  'Kindergarten Kid': ['periplans', 'periplan', 'stasis'],
#  'Know Your Fusion': ['segment', 'jorge', 'callback'],
#  "Buddy's Book": ['boooooks', 'raccoons', 'heatvision'],
#  'Mindful Education': ['flexibility', 'harmed', 'swarming'],
#  'Future Boy Zoltron': ['zoltron', 'fortune', 'frowney'],
#  'Last One Out of Beach City': ['krol', 'suburbs', 'socializing'],
#  'Onion Gang': ['garbanzo', 'pinto', 'pot'],
#  'Gem Harvest': ['deb', 'vegetable', 'demayos'],
#  'Three Gems and a Baby': ['sled', 'buttoned', 'carabiner'],
#  "Steven's Dream": ['highness', 'abducting', 'comic'],
#  'Adventures in Light Distortion': ['preferences', 'seventy', 'steveo'],
#  'Gem Heist': ['esteban', 'muscle', 'merciful'],
#  'The Zoo': ['gareg', 'choosened', 'chained'],
#  'That Will Be All': ['haa', 'foresaw', 'cutxm'],
#  'The New Crystal Gems': ['temps', 'faroff', 'continuum'],
#  'Storm in the Room': ['noun', 'multihulled', 'watercraft'],
#  'Rocknaldo': ['bloodstone', 'threatens', 'blah'],
#  'Tiger Philanthropist': ['philanthropist', 'tiger', 'loan'],
#  'Room for Ruby': ['navy', 'navel', 'tricking'],
#  'Lion 4: Alternate Ending': ['nora', 'asia', 'bitty'],
#  'Doug Out': ['loitering', 'flashlight', 'stakeout'],
#  'The Good Lars': ['potluck', 'debut', 'ube'],
#  'Are You My Dad?': ['khakis', 'vending', 'packages'],
#  'I Am My Mom': ['wwas', 'dullards', 'rogue'],
#  'Stuck Together': ['handed', 'shatterings', 'rosie'],
#  'The Trial': ['guilty', 'unluckiest', 'brief'],
#  'Off Colors': ['prediction', 'dinosaurs', 'baklava'],
#  "Lars' Head": ['zombie', 'lizards', 'freely'],
#  'Dewey Wins[22]': ['blamed', 'suffers', 'billiam'],
#  'Gemcation': ['hoses', 'glum', 'lag'],
#  'Raising the Barn': ['pumpkin', 'rewatch', 'piling'],
#  'Back to the Kindergarten': ['xj', 'thumb', 'uugghhh'],
#  'Sadie Killer': ['seafood', 'doodoo', 'lurch'],
#  'Kevin Party': ['derrick', 'sabina', 'scarf'],
#  'Lars of the Stars': ['imperial', 'hyperspeed', 'quads'],
#  'Jungle Moon': ['intercept', 'downer', 'aanyone'],
#  'Your Mother and Mine': ['appreciation', 'fondness', 'annihilated'],
#  'The Big Show': ['venue', 'fog', 'whoaohoh'],
#  'Pool Hopping': ['improbable', 'realities', 'improbability'],
#  'Letters to Lars': ['plumber', 'rations', 'lookout'],
#  "Can't Go Back[24]": ['spying', 'banging', 'steeveeeeen'],
#  'A Single Pale Rose[24]': ['sigh', 'wallpaper', 'som'],
#  "Now We're Only Falling Apart": ['creating', 'questioned', 'dia'],
#  "What's Your Problem?": ['babysit', 'ruuuby', 'seashell'],
#  'The Question': ['rider', 'comics', 'papow'],
#  'Made of Honor': ['dolphins', 'cow', 'sweetums'],
#  'Reunited': ['foe', 'mattering', 'upsetting'],
#  'Legs From Here to Homeworld': ['cabochon', 'heed', 'avenged'],
#  'Familiar': ['extraction', 'lasagna', 'nosey'],
#  'Together Alone': ['therefore', 'confetti', 'forbidden'],
#  'Escapism': ['grabbed', 'hhang', 'jail'],
#  'Change Your Mind': ['miiiiiiind', 'impurities', 'bully'],
#  'Steven Universe: The Movie': ['happily', 'disobedient', 'driiift'],
#  'Little Homeschool': ['welcomeback', 'english', 'glyph'],
#  'Guidance': ['bixbite', 'mentorship', 'ghem'],
#  'Rose Buds': ['siblings', 'carrot', 'discs'],
#  'Volleyball': ['nickname', 'reef', 'trivial'],
#  'Bluebird': ['bluebird', 'bluebirds', 'mydad'],
#  'A Very Special Episode': ['blackbird', 'geminar', 'smoothing'],
#  'Snow Day': ['docket', 'eggssential', 'nutrients'],
#  'Why So Blue?': ['terraform', 'terraforming', 'sensations'],
#  'Little Graduation': ['graduates', 'pockets', 'evolve'],
#  'Prickly Pair': ['cactus', 'steeeven', 'sprouted'],
#  'In Dreams': ['rodrigo', 'stefan', 'jasmine'],
#  'Bismuth Casual': ['skate', 'cams', 'camshafts'],
#  'Together Forever': ['multiplied', 'badge', 'jayhawk'],
#  'Growing Pains': ['tours', 'gp', 'skeleton'],
#  'Mr. Universe': ['meatloaf', 'trucks', 'chaperones'],
#  'Fragments': ['nngghh', 'outburst', 'dissipates'],
#  'Homeworld Bound': ['pleases', 'stooge', 'storied'],
#  "Everything's Fine": ['improve', 'fraud', 'nonnnno'],
#  'I Am My Monster': ['arehuh', 'dive', 'clobber'],
#  'The Future': ['providence', 'hangout', 'boogle']}

# %%
# Analyzing most salient by episode alone doesn't seem to make much sense.
by_speaker_corpus = build_corpus(valid_transcripts, 'speaker', 'list_of_tokens')

# %%
most_salient_speaker = {}
most_salient_speaker = find_most_salient(by_speaker_corpus, 10)
most_salient_speaker
# Out:
# {'Steven': ['wo',
#   'bing',
#   'ninja',
#   'stack',
#   'quiz',
#   'miiiiiiind',
#   'duper',
#   'gurgens',
#   'gun',
#   'sock'],
#  'Lars': ['napalm',
#   'bozo',
#   'superweird',
#   'thisweird',
#   'ditch',
#   'ahaao',
#   'lit',
#   'possess',
#   'wormhole',
#   'deserved'],
#  'Sadie': ['shifts',
#   'deadend',
#   'minimum',
#   'wage',
#   'whoaohoh',
#   'gggghost',
#   'alaska',
#   'biodegradable',
#   'potluuuck',
#   'poootluuuck'],
#  'Amethyst': ['wshh',
#   'ghem',
#   'ultra',
#   'betty',
#   'boringer',
#   'bleating',
#   'distress',
#   'commenting',
#   'posture',
#   'sync'],
#  'Pearl': ['lala',
#   'synthetic',
#   'fossa',
#   'outbursts',
#   'hardens',
#   'playfully',
#   'heehuh',
#   'reeks',
#   'alloy',
#   'tad'],
#  'Garnet': ['determined',
#   'panels',
#   'trigger',
#   'gunshow',
#   'giggling',
#   'anticipation',
#   'revive',
#   'spoiled',
#   'appetite',
#   'avenge'],
#  'Garnet, Pearl & Amethyst': ['steven', 'no'],
#  'Mr. Fryman': ['frybo',
#   'valued',
#   'ketchup',
#   'woahho',
#   'ti',
#   'ensnares',
#   'tendril',
#   'peeped',
#   'affiliates',
#   'lighter'],
#  'Steven & Amethyst': ['pew',
#   'matter',
#   'side',
#   'bits',
#   'hup',
#   'aaah',
#   'worst',
#   'exist',
#   'finish',
#   'by'],
#  'Greg': ['highness',
#   'trucks',
#   'highprofile',
#   'whup',
#   'tomoroo',
#   'woohohooo',
#   'woooaaahh',
#   'abducting',
#   'comic',
#   'toes'],
#  'Pearl, Amethyst, and Garnet': ['woah'],
#  'Jamie': ['funded',
#   'rehearsal',
#   'faults',
#   'gritty',
#   'passionate',
#   'props',
#   'deweyll',
#   'remaining',
#   'gentleboardies',
#   'rejection'],
#  'Mr. Queasy': ['aching',
#   'ooh',
#   'shake',
#   'stomach',
#   'killing',
#   'medical',
#   'condition',
#   'kid',
#   'me',
#   'dont'],
#  'Garnet, Amethyst & Pearl': ['malachite',
#   'surprise',
#   'cute',
#   'hes',
#   'do',
#   'sorry',
#   'steven',
#   'it',
#   'were',
#   'so'],
#  'Pearl & Amethyst': ['cheeseburger',
#   'backpack',
#   'oow',
#   'funky',
#   'flow',
#   'sapphire',
#   'ruby',
#   'ah',
#   'garnet',
#   'wait'],
#  'Amethyst & Garnet': ['wow'],
#  'Dumb Police': ['dumb', 'police', 'uhhh', 'youre'],
#  'Gems': ['woaaah',
#   'uggh',
#   'hiiim',
#   'whooa',
#   'happily',
#   'augh',
#   'finish',
#   'after',
#   'ever',
#   'steven'],
#  'Peedee': ['seahorse',
#   'cash',
#   'daaaddddd',
#   'dee',
#   'sweaty',
#   'positions',
#   'upright',
#   'rejoices',
#   'whiplash',
#   'smashes'],
#  'Mr. Smiley': ['champions',
#   'starfish',
#   'sharkomanias',
#   'anticlimatic',
#   'grace',
#   'depression',
#   'wallstreet',
#   'identityconcealing',
#   'shawl',
#   'solo'],
#  'The Frymans': ['steven'],
#  'Mayor Dewey': ['gary',
#   'printer',
#   'outage',
#   'exterminator',
#   'position',
#   'sprays',
#   'reelect',
#   'aid',
#   'unveil',
#   'county'],
#  'Steven and Greg': ['woah'],
#  'Cat Finger': ['rreow', 'reaw', 'row', 'meow'],
#  'Sadie and Lars': ['whaaat'],
#  'Cat Fingers': ['rraaooow'],
#  'Peedee and Mr. Fryman': ['whoa'],
#  'Ronaldo': ['threatens',
#   'pregnant',
#   'facts',
#   'anime',
#   'wakey',
#   'blogging',
#   'poltergeist',
#   'haunts',
#   'handcraft',
#   'jane'],
#  'Connie': ['infinity',
#   'unyielding',
#   'trembling',
#   'murmuring',
#   'optometrist',
#   'leading',
#   'subverting',
#   'tropes',
#   'selfaware',
#   'pastiche'],
#  'Chunk Truck': ['potholes',
#   'briefcase',
#   'smacking',
#   'chin',
#   'ahuh',
#   'chunk',
#   'millionaire',
#   'opens',
#   'tiger',
#   'truck'],
#  'Random Man': ['men', 'monsters', 'dare', 'hurt', 'those', 'dont', 'you'],
#  'Kiki': ['pun',
#   'hamburgers',
#   'quirky',
#   'tolerate',
#   'suitcase',
#   'sams',
#   'buffet',
#   'boardwalks',
#   'economy',
#   'teamed'],
#  'Road Killer': ['vroomvroom',
#   'horrible',
#   'fantastic',
#   'kill',
#   'road',
#   'youre',
#   'the'],
#  'Teens of Rage': ['chump', 'rage', 'teens', 'come', 'on', 'of'],
#  'Punch Buddy': ['wife',
#   'shot',
#   'punch',
#   'somebody',
#   'kid',
#   'best',
#   'please',
#   'give',
#   'sorry',
#   'tell'],
#  'Meat Beat Mania': ['loses',
#   'meat',
#   'player',
#   'meats',
#   'tenderize',
#   'competes',
#   'barbecue',
#   'ribs',
#   'thrill',
#   'toasted'],
#  'Opal': ['independent',
#   'low',
#   'together',
#   'turn',
#   'wanna',
#   'try',
#   'stay',
#   'into',
#   'see',
#   'if'],
#  'Whacker Man': ['whackin',
#   'whacked',
#   'bops',
#   'mallet',
#   'chuckles',
#   'nervously',
#   'figure',
#   'gonna',
#   'time',
#   'get'],
#  'Amethyst & Pearl': ['huuuuuh',
#   'yaaaaaah',
#   'whaaat',
#   'nearest',
#   'pad',
#   'warp',
#   'em',
#   'garnet',
#   'yeah',
#   'get'],
#  'Jenny': ['frenchfried',
#   'doggydoo',
#   'buckled',
#   'daad',
#   'giiiirl',
#   'shiiiiirt',
#   'puhlease',
#   'selfie',
#   'stickers',
#   'whaaaaaa'],
#  'Buck': ['doodoo',
#   'dozen',
#   'festival',
#   'provocative',
#   'sheepishly',
#   'specifics',
#   'caprese',
#   'swag',
#   'maker',
#   'commemoration'],
#  'Sour Cream': ['germans',
#   'deejaying',
#   'fishermen',
#   'mamama',
#   'arguing',
#   'toi',
#   'legit',
#   'realtalks',
#   'hyped',
#   'smelly'],
#  'Jenny, Sour Cream & Buck': ['super', 'lars', 'woah', 'cool', 'yeah', 'oh'],
#  'Jenny & Buck': ['sour', 'raving', 'cream', 'starts', 'go'],
#  'G.U.Y.S. Machine': ['dave',
#   'guy',
#   'machine',
#   'lucky',
#   'try',
#   'another',
#   'guys',
#   'please',
#   'again',
#   'time'],
#  'Lonely Blade': ['parry',
#   'cursing',
#   'thrust',
#   'grr',
#   'challenger',
#   'duel',
#   'techniques',
#   'initiated',
#   'str',
#   'walrus'],
#  'Samurai President': ['shadow',
#   'president',
#   'samurai',
#   'piercing',
#   'screams',
#   'defeat',
#   'government',
#   'thousand',
#   'think',
#   'of'],
#  'Holo-Pearl': ['parry',
#   'thrust',
#   'challenger',
#   'duel',
#   'initiated',
#   'engage',
#   'detected',
#   'accepted',
#   'combat',
#   'commencing'],
#  'Garnet & Amethyst': ['steven'],
#  "Lonely Blade's Brother": ['technique',
#   'brother',
#   'impressive',
#   'enough',
#   'wont',
#   'your',
#   'yes',
#   'is',
#   'but',
#   'be'],
#  'Movie Narrator': ['helicopters',
#   'destroys',
#   'sprouts',
#   'propellers',
#   'february',
#   'missile',
#   'forehand',
#   'backhand',
#   'fur',
#   'franchise'],
#  'Steven & Connie': ['aahh',
#   'cheeeese',
#   'clink',
#   'ewww',
#   'hyaaaa',
#   'spikey',
#   'haaaaaah',
#   'buddwick',
#   'maam',
#   'axes'],
#  'Ticket Booth Lady': ['rewards',
#   'card',
#   'hello',
#   'um',
#   'whoa',
#   'uh',
#   'have',
#   'do',
#   'a',
#   'you'],
#  'Kofi': ['bagel',
#   'engaged',
#   'contest',
#   'mooom',
#   'jennifer',
#   'chickens',
#   'hospitality',
#   'unbanned',
#   'marinara',
#   'sauce'],
#  'Nanefua': ['suffers',
#   'billiam',
#   'aaaahh',
#   'bleeeeeh',
#   'cellphones',
#   'diets',
#   'heated',
#   'veeery',
#   'peculiar',
#   'sonic'],
#  'Jenny & Kiki': ['hey', 'steven'],
#  'Amethyst & Jenny': ['woaaaaah'],
#  'Ace': ['flog',
#   'june',
#   'par',
#   'disappeared',
#   'project',
#   'golf',
#   'backwards',
#   'date',
#   'saving',
#   'course'],
#  'Pearl, Amethyst, & Garnet': ['steven'],
#  "Ace's Father": ['cryostation',
#   'decades',
#   'father',
#   'free',
#   'finally',
#   'after',
#   'im',
#   'its',
#   'your',
#   'me'],
#  'Sadie & Lars': ['mmmhmm',
#   'bye',
#   'donuts',
#   'ok',
#   'donut',
#   'kinda',
#   'hello',
#   'nice',
#   'very',
#   'love'],
#  'Tiny Floating Whale': ['want', 'do', 'steven', 'what', 'you'],
#  'Sugilite': ['hahahahaha',
#   'bored',
#   'split',
#   'junk',
#   'forgot',
#   'baby',
#   'sick',
#   'feels',
#   'plan',
#   'behind'],
#  'Greg & Lars': ['what'],
#  'Pearl & Steven': ['wha'],
#  'Mr. Smiley & Steven': ['chuckles',
#   'round',
#   'smiley',
#   'mr',
#   'world',
#   'make',
#   'they',
#   'hey',
#   'go',
#   'the'],
#  'Garnet & Pearl': ['stevonnie', 'connie', 'steven'],
#  'Yellowtail': ['mmhhmm', 'huhuhhuh', 'hah', 'huh'],
#  'Steven 2': ['models',
#   'productive',
#   'shushes',
#   'jobs',
#   'beachapalooza',
#   'band',
#   'join',
#   'sing',
#   'lead',
#   'singing'],
#  'Steven & Steven 2': ['minute', 'wait', 'steven', 'a'],
#  'Steven 3': ['drummer',
#   'prone',
#   'attractive',
#   'fourth',
#   'equally',
#   'agrees',
#   'attitude',
#   'extremely',
#   'hilarious',
#   'mmm'],
#  'Steven 4': ['okiedokie',
#   'artichokey',
#   'angsty',
#   'handsome',
#   'wrote',
#   'original',
#   'leader',
#   'song',
#   'rest',
#   'looking'],
#  'All Stevens': ['longest',
#   'idea',
#   'alright',
#   'thats',
#   'around',
#   'good',
#   'been',
#   'yeah',
#   'one',
#   'a'],
#  'Steven 2 & Steven 3': ['okay'],
#  'All other Stevens': ['fifth',
#   'haha',
#   'gotta',
#   'things',
#   'stop',
#   'theres',
#   'we',
#   'time',
#   'steven',
#   'all'],
#  'Past Steven': ['ahgah',
#   'mailman',
#   'lots',
#   'onion',
#   'couldve',
#   'dad',
#   'sadie',
#   'humans',
#   'lars',
#   'wish'],
#  'Gem Glow Steven': ['ahh',
#   'wha',
#   'gotta',
#   'guys',
#   'please',
#   'okay',
#   'im',
#   'just',
#   'steven',
#   'i'],
#  'Beginning Steven': ['hers',
#   'picked',
#   'names',
#   'gets',
#   'future',
#   'talking',
#   'bad',
#   'amethyst',
#   'keep',
#   'wait'],
#  'Handsome Steven': ['fat',
#   'haaaaa',
#   'fights',
#   'boats',
#   'beachapalooza',
#   'winner',
#   'fix',
#   'become',
#   'stevens',
#   'once'],
#  'Crystal Gems': ['augh',
#   'fear',
#   'bright',
#   'far',
#   'fight',
#   'future',
#   'woah',
#   'weve',
#   'believe',
#   'nothing'],
#  'Connie (o.s.)': ['she', 'didnt', 'say', 'really', 'that'],
#  'Lars & Sadie': ['falls', 'table', 'over', 'hey', 'steven', 'the'],
#  'Mirror': ['pbht',
#   'nooooo',
#   'ssssteven',
#   'er',
#   'repeatedly',
#   'mirror',
#   'laughs',
#   'funny',
#   'pretty',
#   'friend'],
#  'Lapis': ['battling',
#   'meepmorp',
#   'bluuuuuuuueso',
#   'devastation',
#   'shadowy',
#   'populated',
#   'ssorry',
#   'interrogated',
#   'bleak',
#   'tomb'],
#  'Beach City Citizens': ['incredible',
#   'did',
#   'whoa',
#   'where',
#   'wait',
#   'thats',
#   'go',
#   'how',
#   'do',
#   'what'],
#  'Mr. Pizza': ['pizza', 'my', 'and'],
#  'TV Narrator': ['episode',
#   'tuned',
#   'pining',
#   'camp',
#   'hearts',
#   'breakfast',
#   'crying',
#   'friends',
#   'last',
#   'another'],
#  'Steven & Greg': ['whaaaaats',
#   'mnhmnhmnh',
#   'admit',
#   'woah',
#   'must',
#   'garnet',
#   'great',
#   'uh',
#   'look',
#   'really'],
#  'Lady': ['midseason',
#   'prefinale',
#   'nurse',
#   'represent',
#   'satire',
#   'werewere',
#   'uhtheyre',
#   'reservations',
#   'radioactive',
#   'adults'],
#  'Doctor': ['nurse',
#   'prep',
#   'surgery',
#   'knife',
#   'patient',
#   'emergency',
#   'under',
#   'gonna',
#   'go',
#   'were'],
#  'Nurse': ['brain',
#   'doctor',
#   'legs',
#   'his',
#   'yes',
#   'into',
#   'did',
#   'get',
#   'how'],
#  'Dr. Maheswaran': ['mehow',
#   'masterful',
#   'caregivers',
#   'flu',
#   'doctorpatient',
#   'confidentiality',
#   'whove',
#   'abacus',
#   'budgets',
#   'strombergs'],
#  'Mr. Maheswaran': ['swerve',
#   'unlimited',
#   'pullout',
#   'mere',
#   'sweatshirt',
#   'universes',
#   'breadsticks',
#   'parked',
#   'couch',
#   'picks'],
#  'Alexandrite': ['hiiiiii',
#   'doctors',
#   'steveeeenn',
#   'outnumbered',
#   'breadsticks',
#   'bleh',
#   'malachite',
#   'bus',
#   'dear',
#   'instant'],
#  'Alexandrite (Pearl)': ['doing',
#   'think',
#   'dont',
#   'so',
#   'are',
#   'what',
#   'i',
#   'you'],
#  'Alexandrite (Amethyst)': ['hungry', 'im'],
#  'Alexandrite (Garnet)': ['cut', 'two', 'out', 'it', 'you'],
#  'Hopper': ['hoppin',
#   'hoppy',
#   'oohh',
#   'amulet',
#   'enchanted',
#   'ion',
#   'spontaneously',
#   'reforms',
#   'hoptastrophic',
#   'power'],
#  'Hoppy': ['wounds',
#   'hopper',
#   'higher',
#   'hop',
#   'chew',
#   'train',
#   'training',
#   'ring',
#   'nearly',
#   'jump'],
#  'Ringo': ['ringo',
#   'sacred',
#   'shrine',
#   'foxman',
#   'wuahah',
#   'caretaker',
#   'atop',
#   'yonder',
#   'obliged',
#   'doublecrossed'],
#  'Hoppy & Hopper': ['weighted', 'gauntlets', 'hop', 'five'],
#  'Foxman': ['ringo',
#   'huuurrrr',
#   'protector',
#   'sneaks',
#   'retrieves',
#   'hisses',
#   'foxman',
#   'shrine',
#   'curse',
#   'beating'],
#  'Hoppy, Hopper & Ringo': ['whoa', 'cool', 'so'],
#  'Hopper & Hoppy': ['wwwweighted',
#   'hip',
#   'hurray',
#   'hop',
#   'monster',
#   'hair',
#   'garnet',
#   'you'],
#  'Unknown Narrator': ['ringo',
#   'foxman',
#   'mountains',
#   'valuable',
#   'greater',
#   'stayed',
#   'garnets',
#   'zone',
#   'original',
#   'lesson'],
#  'Pearl, Garnet, & Amethyst': ['what'],
#  'Dogcopter': ['labels',
#   'conforming',
#   'standard',
#   'statement',
#   'breath',
#   'talent',
#   'conversation',
#   'meow',
#   'art',
#   'honesty'],
#  'Rose': ['sheer',
#   'colorful',
#   'washes',
#   'manyou',
#   'funi',
#   'youquite',
#   'entertainingi',
#   'songi',
#   'wayhuman',
#   'playi'],
#  'Peridot': ['domisoti',
#   'technician',
#   'praise',
#   'connectors',
#   'domisodo',
#   'madness',
#   'expiration',
#   'cruddy',
#   'waaaah',
#   'louder'],
#  'Stevonnie': ['poofed',
#   'sandal',
#   'grgreat',
#   'sweating',
#   'uggghhh',
#   'stevonnies',
#   'aaaheeee',
#   'targeting',
#   'downer',
#   'aanyone'],
#  'Stevonnie (Connie)': ['diet',
#   'protein',
#   'bars',
#   'healthy',
#   'dancing',
#   'energy',
#   'dance',
#   'happening',
#   'fun',
#   'understand'],
#  'Stevonnie (Steven)': ['fruits',
#   'fruit',
#   'kevin',
#   'deserves',
#   'iim',
#   'dreams',
#   'choice',
#   'bismuth',
#   'ii',
#   'shouldnt'],
#  'Unknown Man': ['yeesh'],
#  'Kevin': ['derrick',
#   'angels',
#   'himitsu',
#   'x',
#   'downhill',
#   'cooldown',
#   'brats',
#   'trench',
#   'views',
#   'clingy'],
#  'Stereo': ['exercise',
#   'tw',
#   'providence',
#   'schools',
#   'hangout',
#   'boogle',
#   'meltdown',
#   'mmmmmm',
#   'superduper',
#   'chat'],
#  'Cartoon Steven': ['considered',
#   'cookie',
#   'evil',
#   'cat',
#   'real',
#   'ugh',
#   'ah',
#   'guys',
#   'never',
#   'would'],
#  'Wasp 1': ['magic', 'made', 'were', 'of'],
#  'Wasp 2': ['magic', 'yeah'],
#  'Movie Hermit Man': ['eating', 'leg', 'youre', 'my'],
#  'Steven & Ronaldo': ['hey'],
#  'Spirit': ['laaarrrrsssss', 'laaaaarrrsss'],
#  'Steven, Ronaldo & Lars': ['sadie'],
#  'Young Ronaldo': ['clubhouse',
#   'nononononono',
#   'paranormal',
#   'station',
#   'discovery',
#   'explorer',
#   'possessed',
#   'smokes',
#   'lars',
#   'riot'],
#  'Young Lars': ['ronnie',
#   'carving',
#   'bbbutbut',
#   'clubhouse',
#   'zip',
#   'tearing',
#   'metal',
#   'secret',
#   'names',
#   'um'],
#  'Greg & Amethyst': ['money',
#   'woah',
#   'people',
#   'much',
#   'huh',
#   'too',
#   'have',
#   'you'],
#  "Li'l Butler": ['money',
#   'people',
#   'always',
#   'much',
#   'too',
#   'well',
#   'have',
#   'i',
#   'you'],
#  'Man on TV': ['baby',
#   'order',
#   'any',
#   'never',
#   'did',
#   'well',
#   'of',
#   'a',
#   'i',
#   'you'],
#  'Teenage girl on TV': ['pony',
#   'school',
#   'fool',
#   'show',
#   'ill',
#   'look',
#   'up',
#   'if',
#   'one',
#   'like'],
#  'TV': ['hawaii', 'after', 'where', 'going', 'are', 'you'],
#  'Amethyst (background)': ['clockwise',
#   'lift',
#   'backwards',
#   'pull',
#   'turn',
#   'yeah',
#   'other',
#   'sure',
#   'it',
#   'no'],
#  'Garnet (background)': ['pull', 'mean', 'you'],
#  'Holo-Rose': ['killed',
#   'win',
#   'lose',
#   'fight',
#   'please',
#   'understand',
#   'pearl',
#   'planet',
#   'home',
#   'stay'],
#  'Pearl (unheard)': ['charged',
#   'seemed',
#   'nowhere',
#   'impossible',
#   'side',
#   'rose',
#   'by',
#   'her',
#   'when',
#   'with'],
#  'Cloud Connie': ['rrrr',
#   'truth',
#   'told',
#   'her',
#   'tell',
#   'wanna',
#   'wanted',
#   'better',
#   'feel',
#   'want'],
#  'Mayor Dewey (Slow motion)': ['favors',
#   'political',
#   'few',
#   'wasnt',
#   'home',
#   'he',
#   'no',
#   'and'],
#  'Bodyguard #1 (Slow motion)': ['look', 'out'],
#  'Bodyguard #2 (Slow motion)': ['aaaah'],
#  'Marty': ['growling',
#   'pepes',
#   'guacola',
#   'cost',
#   'sc',
#   'saps',
#   'fame',
#   'jammed',
#   'pennies',
#   'schlock'],
#  'Vidalia': ['mushedup',
#   'carrots',
#   'livin',
#   'tarp',
#   'spitting',
#   'mischief',
#   'troublemaker',
#   'dish',
#   'noodles',
#   'hahah'],
#  'Purple Owl': ['hoo',
#   'hoahahaha',
#   'longhaired',
#   'pal',
#   'fence',
#   'kill',
#   'asking',
#   'he',
#   'human',
#   'talking'],
#  'Others': ['wha'],
#  'Mayor Dewey (voiceover)': ['sun',
#   'goes',
#   'does',
#   'down',
#   'when',
#   'so',
#   'the'],
#  'Greg & Pearl': ['uuhh', 'she', 'wanted', 'always', 'did', 'what'],
#  'Answering Machine, voice of Dr.Maheswaran': ['disappointment',
#   'residence',
#   'moans',
#   'reached',
#   'beep',
#   'maheswaran',
#   'short',
#   'message',
#   'after',
#   'leave'],
#  'Jasper': ['overcooked',
#   'shameless',
#   'symbol',
#   'barrage',
#   'widespread',
#   'priming',
#   'respected',
#   'tactics',
#   'tactic',
#   'auh'],
#  'Ruby': ['badge',
#   'comics',
#   'papow',
#   'thinkin',
#   'receiving',
#   'allllllways',
#   'notaboutthis',
#   'muffled',
#   'awwwhawhaw',
#   'laughy'],
#  'Sapphire': ['multiplied',
#   'probability',
#   'choosing',
#   'engulfed',
#   'stretches',
#   'horizon',
#   'wipes',
#   'duties',
#   'sophie',
#   'accompanying'],
#  'Steven, Amethyst, & Pearl': ['aww', 'garnet'],
#  'Malachite': ['measly',
#   'outnumbered',
#   'emergence',
#   'tremors',
#   'fullscale',
#   'disobey',
#   'anarchist',
#   'eurgh',
#   'mask',
#   'watermelon'],
#  'Malachite (Jasper)': ['held',
#   'argh',
#   'impressed',
#   'pathetic',
#   'theyre',
#   'doing',
#   'give',
#   'huh',
#   'really',
#   'up'],
#  'Malachite (Lapis)': ['prisoner',
#   'everyones',
#   'miserable',
#   'letting',
#   'planet',
#   'done',
#   'together',
#   'ugh',
#   'stay',
#   'being'],
#  'Cool Kids': ['ms',
#   'miller',
#   'bye',
#   'whoo',
#   'nooo',
#   'guys',
#   'ya',
#   'aah',
#   'hi',
#   'yeah'],
#  'Uncle Grandpa': ['beezooka',
#   'gus',
#   'dolphin',
#   'canon',
#   'bellys',
#   'hmmmwell',
#   'looksee',
#   'polished',
#   'mega',
#   'launcher'],
#  'Belly Bag': ['grandpa',
#   'uncle',
#   'thaaats',
#   'oooooooooooo',
#   'pops',
#   'worlds',
#   'comes',
#   'town',
#   'hes',
#   'head'],
#  'Pizza Steve': ['steve',
#   'tastiest',
#   'gusi',
#   'erased',
#   'drawing',
#   'guss',
#   'gemsona',
#   'steeven',
#   'g',
#   'vans'],
#  'Mr. Gus': ['denizens',
#   'multiverse',
#   'pan',
#   'maternal',
#   'vandalizes',
#   'layer',
#   'comprehensive',
#   'gemsona',
#   'frying',
#   'guss'],
#  'Giant Belly Bag': ['buurrrpppp'],
#  'Jamie (Narrating)': ['nymph',
#   'artery',
#   'cardiac',
#   'surgeon',
#   'transplant',
#   'poised',
#   'hesitating',
#   'implore',
#   'crab',
#   'shack'],
#  'Barbara': ['scuse',
#   'spurned',
#   'bin',
#   'intentions',
#   'planing',
#   'ballet',
#   'competitive',
#   'cheat',
#   'thems',
#   'prom'],
#  'Pearl & Connie': ['draw',
#   'sword',
#   'youd',
#   'fight',
#   'her',
#   'can',
#   'but',
#   'know',
#   'do',
#   'your'],
#  'Ronaldo (Narrator)': ['mysteriously',
#   'sweeps',
#   'slips',
#   'plea',
#   'skillfully',
#   'negotiated',
#   'diplomacy',
#   'seaside',
#   'cracks',
#   'facade'],
#  'Ronaldo (Footage)': ['invasion',
#   'unbelievable',
#   'missed',
#   'thing',
#   'an',
#   'look',
#   'its',
#   'there',
#   'at',
#   'right'],
#  'Mr. Fryman ("Footage")': ['let', 'go', 'it'],
#  'Peedee ("Footage")': ['dad', 'please', 'no'],
#  'Mr. Fryman (Footage)': ['blazes', 'blue', 'was', 'in', 'what', 'that'],
#  'Peedee (Footage)': ['explosion', 'an', 'think', 'was', 'it', 'i'],
#  'Ronaldo (Re-Enactment)': ['ouch',
#   'whoooaahwooophhhhwoah',
#   'ahhhh',
#   'hand',
#   'ah',
#   'my'],
#  'Peridot (Off-screen)': ['log', 'date'],
#  'Garnet (Ruby)': ['forgiving',
#   'punishment',
#   'theyve',
#   'rebellion',
#   'thinks',
#   'fusion',
#   'homeworld',
#   'ones',
#   'listen',
#   'couldnt'],
#  'Garnet (Sapphire)': ['known',
#   'calm',
#   'couldnt',
#   'fault',
#   'understand',
#   'rose',
#   'must',
#   'down',
#   'would',
#   'our'],
#  'RoseGreg': ['youwhat',
#   'dowhat',
#   'else',
#   'can',
#   'do',
#   'for',
#   'one',
#   'no',
#   'i',
#   'what'],
#  'Narrator': ['filmed',
#   'studio',
#   'audience',
#   'live',
#   'universe',
#   'before',
#   'was',
#   'steven',
#   'a'],
#  'Amethyst (off-screen)': ['fussing',
#   'baby',
#   'over',
#   'stop',
#   'like',
#   'steven',
#   'a'],
#  'Pearl (Dream)': ['spending',
#   'travel',
#   'galaxy',
#   'wonderful',
#   'rose',
#   'having',
#   'forget',
#   'greg',
#   'fun',
#   'much'],
#  'Rose (Dream)': ['fixing',
#   'van',
#   'thank',
#   'much',
#   'pearl',
#   'my',
#   'for',
#   'so',
#   'you'],
#  'Fusion Gem': ['gooooood',
#   'soontobeformer',
#   'checked',
#   'double',
#   'sardonyx',
#   'doin',
#   'evening',
#   'hub',
#   'communication',
#   'lovely'],
#  'Sardonyx': ['segment',
#   'smoky',
#   'sardonyxs',
#   'charmer',
#   'scowls',
#   'faultless',
#   'listing',
#   'qualities',
#   'surgical',
#   'aaandd'],
#  'Sad Spoon': ['pear',
#   'lie',
#   'forgive',
#   'course',
#   'why',
#   'did',
#   'me',
#   'of',
#   'you',
#   'to'],
#  'Crying Pear': ['tohoohoohoohoohoo',
#   'forgive',
#   'mean',
#   'please',
#   'didnt',
#   'me',
#   'i'],
#  'Ruby & Sapphire': ['entirely',
#   'uhhhh',
#   'quite',
#   'wasnt',
#   'new',
#   'someone',
#   'did',
#   'made',
#   'them',
#   'think'],
#  'Amethyst (Background)': ['fishtail',
#   'complain',
#   'docks',
#   'ol',
#   'ha',
#   'smell',
#   'expect',
#   'haha',
#   'wheres',
#   'dude'],
#  'Vidalia (Background)': ['trashed',
#   'spends',
#   'boats',
#   'mayors',
#   'snuck',
#   'yellowtail',
#   'boat',
#   'fancy',
#   'gross',
#   'sea'],
#  'Onion': ['mama'],
#  'Vidalia (VHS Tape)': ['ohhh',
#   'yellowtail',
#   'ready',
#   'comes',
#   'happening',
#   'he',
#   'okay',
#   'im',
#   'think',
#   'oh'],
#  'Jamie & Steven': ['acting'],
#  'Jamie (Narrator)': ['ruggedly',
#   'beats',
#   'deck',
#   'handsome',
#   'speaks',
#   'crew',
#   'tall',
#   'sea',
#   'sun',
#   'standing'],
#  'Jamie (William Dewey)': ['supernatural',
#   'crew',
#   'distinguished',
#   'heroic',
#   'journey',
#   'mate',
#   'laughs',
#   'woohoo',
#   'ability',
#   'search'],
#  'Jamie (First Mate Buddy)': ['captain',
#   'voyage',
#   'squall',
#   'sailing',
#   'rugged',
#   'yon',
#   'drifted',
#   'portside',
#   'approaching',
#   'lever'],
#  'Steven (Narrator)': ['fiftyfoot',
#   'carries',
#   'safely',
#   'elected',
#   'shore',
#   'grows',
#   'boat',
#   'william',
#   'crew',
#   'thinks'],
#  'Steven & Jamie': ['boom', 'acting', 'ah'],
#  'Steven (William Dewey)': ['dunce',
#   'journeying',
#   'drizzle',
#   'stale',
#   'noogie',
#   'legends',
#   'noogies',
#   'whata',
#   'makesa',
#   'greeeata'],
#  'Jamie (Pearl)': ['east',
#   'messenger',
#   'park',
#   'headed',
#   'species',
#   'greetings',
#   'brilliant',
#   'land',
#   'walk',
#   'ship'],
#  'Jamie (Garnet)': ['lest',
#   'swimmers',
#   'sea',
#   'fall',
#   'humans',
#   'turn',
#   'arent',
#   'very',
#   'around',
#   'should'],
#  'Jamie (Amethyst)': ['aint', 'they'],
#  'Jamie (Giant Woman)': ['interfere',
#   'woman',
#   'promise',
#   'land',
#   'dangerous',
#   'may',
#   'giant',
#   'stay',
#   'wont',
#   'very'],
#  'Hospital Staff Member #1': ['dr', 'west', 'aint', 'gonna', 'like', 'it'],
#  'Hospital Staff Member #2': ['dr', 'west', 'isnt', 'well', 'here'],
#  'DR. Maheswaran': ['circumstances',
#   'swords',
#   'rule',
#   'under',
#   'any',
#   'made',
#   'doing',
#   'even',
#   'did',
#   'how'],
#  'Steven & Barbara': ['thank', 'you'],
#  'Cloud Peridot': ['knows', 'only', 'who', 'one', 'about', 'im', 'the'],
#  'Steven & Peridot': ['aaaaaahhhhhh',
#   'pining',
#   'camp',
#   'hearts',
#   'peace',
#   'return',
#   'war',
#   'planet',
#   'done',
#   'whoa'],
#  'Pearl & Peridot': ['hmm', 'no'],
#  'Steven, Garnet, & Amethyst': ['shrug',
#   'each',
#   'woah',
#   'amethyst',
#   'other',
#   'pearl',
#   'look',
#   'at',
#   'and',
#   'steven'],
#  'Steven (Cluster Puppet)': ['stop', 'think', 'can', 'me', 'you'],
#  'Tape Recorder (Peridot)': ['exhibited',
#   'aptitude',
#   'engineering',
#   'begrudgingly',
#   'muddy',
#   'concluded',
#   'intent',
#   'replace',
#   'traits',
#   'capabilities'],
#  'Garnet (Narrator)': ['thwarted',
#   'aristocratic',
#   'casualty',
#   'faze',
#   'impulsive',
#   'renegade',
#   'sapphire',
#   'persistent',
#   'scenario',
#   'described'],
#  'Ruby Guard 1': ['sayin',
#   'bodies',
#   'rebels',
#   'punch',
#   'mmm',
#   'itll',
#   'over',
#   'three',
#   'their',
#   'those'],
#  'Ruby Guard 2': ['rebels',
#   'punch',
#   'faces',
#   'haha',
#   'their',
#   'those',
#   'them',
#   'yes',
#   'gonna',
#   'yeah'],
#  'Rose & Pearl': ['crystal', 'gems', 'are', 'the'],
#  'Past Garnet': ['whatwhat',
#   'ccan',
#   'willing',
#   'wwhy',
#   'unfuse',
#   'alter',
#   'ouch',
#   'fate',
#   'rather',
#   'scared'],
#  'Various Gems (Garnet)': ['unheard',
#   'disgusting',
#   'unbelievable',
#   'is',
#   'this',
#   'of'],
#  'Greg, Connie & the Gems': ['surpri'],
#  'Yellow Pearl': ['extraction',
#   'forbidden',
#   'members',
#   'authorized',
#   'lasagna',
#   'referring',
#   'elevated',
#   'indicate',
#   'liquids',
#   'reject'],
#  'Yellow Diamond': ['inform',
#   'incompetence',
#   'smirks',
#   'disrespected',
#   'redeem',
#   'immense',
#   'erasing',
#   'debacle',
#   'employ',
#   'terrifies'],
#  'Paulette': ['percy',
#   'team',
#   'yellow',
#   'care',
#   'work',
#   'make',
#   'if',
#   'can',
#   'youre',
#   'dont'],
#  'Percy': ['paulette',
#   'color',
#   'war',
#   'does',
#   'anything',
#   'mean',
#   'its',
#   'that',
#   'to',
#   'you'],
#  'Percy & Peridot': ['paulette',
#   'color',
#   'war',
#   'doesnt',
#   'anything',
#   'mean',
#   'its',
#   'that',
#   'to',
#   'the'],
#  'Peridot & Amethyst': ['significant',
#   'compared',
#   'output',
#   'energy',
#   'use',
#   'steven',
#   'of',
#   'to',
#   'the'],
#  'Tape Recorder (Garnet)': ['logs',
#   'recorder',
#   'gasps',
#   'caring',
#   'fourteen',
#   'peridots',
#   'curiosity',
#   'listened',
#   'log',
#   'date'],
#  'Gem Shards': ['form', 'must', 'want', 'need', 'to', 'have'],
#  'Gem Shard #1': ['toneed', 'want', 'have', 'to'],
#  'The Cluster': ['form',
#   'hi',
#   'must',
#   'whole',
#   'help',
#   'stay',
#   'stop',
#   'want',
#   'need',
#   'going'],
#  'Gem Shard #2': ['have', 'to'],
#  'Gem Shard #3': ['want', 'to'],
#  'Random Bystander': ['mooks', 'flyin', 'quit', 'sky', 'our', 'in', 'you'],
#  'Lapis (Narrator)': ['stopping',
#   'tool',
#   'panic',
#   'fled',
#   'picked',
#   'escaping',
#   'stayed',
#   'sight',
#   'theyd',
#   'ages'],
#  '"Army"': ['hiya',
#   'swung',
#   'razzlefrazzle',
#   'oughta',
#   'germs',
#   'yeahh',
#   'raah',
#   'tricked',
#   'tear',
#   'limb'],
#  '"Navy"': ['babyee',
#   'lovelysounding',
#   'correctly',
#   'devotion',
#   'clever',
#   'understandable',
#   'groovy',
#   'forgetful',
#   'passed',
#   'navy'],
#  '"Leggy"': ['purple',
#   'wwhat',
#   'walk',
#   'jasper',
#   'wheres',
#   'anyway',
#   'ruby',
#   'thinking',
#   'stand',
#   'human'],
#  '"Doc"': ['neptune',
#   'doublecheck',
#   'consisting',
#   'newbie',
#   'stuuupid',
#   'arriving',
#   'solar',
#   'disguises',
#   'settles',
#   'strike'],
#  'Homeworld Rubies': ['hup',
#   'moon',
#   'ruby',
#   'understand',
#   'mean',
#   'yes',
#   'huh',
#   'whats',
#   'then',
#   'yeah'],
#  'Peridot, Amethyst, Pearl, & Sapphire': ['baseball'],
#  '"Eyeball"': ['nd',
#   'dissipated',
#   'talks',
#   'tragedy',
#   'smoothly',
#   'minerals',
#   'geeems',
#   'platoon',
#   'airlock',
#   'closure'],
#  'Giant Ruby': ['correct',
#   'jasper',
#   'assigned',
#   'failed',
#   'peridot',
#   'mission',
#   'where',
#   'earth',
#   'well',
#   'didnt'],
#  'Air Hostess on Dhawar Airlines': ['belt',
#   'boys',
#   'turned',
#   'ahead',
#   'captain',
#   'seat',
#   'sign',
#   'sky',
#   'looks',
#   'has'],
#  "Donut (Steven's Imagination in Sadie's voice)": ['fresh'],
#  "Sadie (Steven's imagination)": ['alas',
#   'poor',
#   'knew',
#   'him',
#   'well',
#   'steven',
#   'i'],
#  'Random Citizen': ['guy', 'some', 'its'],
#  'DJ Sour Cream': ['kick', 'lets', 'it'],
#  'Greg & Steven': ['ayyyyyyy',
#   'blinding',
#   'streets',
#   'towering',
#   'subways',
#   'brooklyn',
#   'bowery',
#   'buildings',
#   'sights',
#   'lights'],
#  'Ricky': ['le',
#   'dough',
#   'bill',
#   'gee',
#   'bucks',
#   'hundred',
#   'shake',
#   'leg',
#   'spend',
#   'town'],
#  'Hotel Employees': ['deluxe',
#   'bucks',
#   'shake',
#   'leg',
#   'greg',
#   'mr',
#   'hes',
#   'its',
#   'hey',
#   'got'],
#  'Hotel Employee': ['boo', 'ruined', 'song', 'the', 'you'],
#  'Tablet Ad': ['roommates', 'area', 'cute', 'find', 'your', 'in'],
#  'Lars (Steven)': ['oohhohohoho',
#   'naked',
#   'ffffffbdf',
#   'laaaaarrrs',
#   'koalas',
#   'panther',
#   'psyched',
#   'terrors',
#   'critter',
#   'crematorium'],
#  'Martha': ['dante',
#   'attic',
#   'grades',
#   'burglar',
#   'plugs',
#   'laramie',
#   'average',
#   'lars',
#   'corner',
#   'below'],
#  'Dante': ['touchy',
#   'devil',
#   'martha',
#   'subject',
#   'laramie',
#   'swear',
#   'speak',
#   'school',
#   'scene',
#   'girl'],
#  'Dante & Martha': ['effort', 'little', 'a'],
#  'Male Werewolf (TV)': ['love', 'even', 'like', 'me', 'this', 'and', 'you'],
#  'Female Werewolf (TV)': ['dooooooooo', 'i'],
#  'The Cool Kids & A Bystander': ['oh'],
#  'Kofi & Mr. Fryman': ['waaaaaaar', 'restaurant', 'anything', 'what'],
#  'Fallen Person': ['carbs', 'many', 'too'],
#  'Tearful Girl': ['dvds',
#   'koala',
#   'princess',
#   'ronaldo',
#   'girl',
#   'return',
#   'another',
#   'find',
#   'only',
#   'way'],
#  'Jenny & Peedee': ['whaaaaat'],
#  'Jane': ['blog',
#   'single',
#   'save',
#   'beach',
#   'city',
#   'keep',
#   'your',
#   'for',
#   'it'],
#  'Peedee, Kiki, & Jenny': ['yeah'],
#  'Kiki and Steven': ['oh'],
#  'Kiki & Steven': ['jenny'],
#  'Pizza Jenny': ['kiki',
#   'delivering',
#   'rave',
#   'cave',
#   'pizzas',
#   'cheese',
#   'pizza',
#   'cover',
#   'tonight',
#   'ask'],
#  'Steven & Nephrite': ['chips',
#   'chaaaaps',
#   'love',
#   'from',
#   'we',
#   'and',
#   'i',
#   'you'],
#  'Steven & Lapis': ['ahh', 'jasper'],
#  'Steven& Greg': ['ayyyyyyyyyyyy'],
#  'TV Announcer': ['doorbell',
#   'butler',
#   'attitude',
#   'rings',
#   'tv',
#   'fall',
#   'coming',
#   'big',
#   'hes',
#   'little'],
#  'Holo-Pearls': ['defeatdefeatdefeatdefeatacceptedacceptedacceptedaccepted',
#   'initiating',
#   'dance',
#   'fusion'],
#  'Game Narrator': ['versus',
#   'blade',
#   'outgoing',
#   'lonely',
#   'ko',
#   'round',
#   'fist',
#   'fight'],
#  'Outgoing Fist (In-Game)': ['flyin'],
#  'Lonely Blade (In-Game)': ['boomerang',
#   'blade',
#   'blades',
#   'dodges',
#   'lonely',
#   'land',
#   'attack',
#   'blue',
#   'best',
#   'all'],
#  'Out Going Fist (In-Game)': ['fists', 'dead', 'even', 'my', 'are'],
#  'Blue Lonely Blade (In-Game)': ['bmrng', 'boomerang', 'blade'],
#  'Blue Lonely Blade (T.V)': ['loneliest',
#   'blades',
#   'hiyah',
#   'mirror',
#   'blade',
#   'thousand',
#   'after',
#   'one',
#   'all',
#   'my'],
#  "Game's Narrator": ['ko'],
#  'Bismuth': ['elites',
#   'hehehehe',
#   'pshh',
#   'recruits',
#   'meatball',
#   'everythins',
#   'buildin',
#   'uppercrusts',
#   'battalion',
#   'brighter'],
#  'Lonely Blade (TV)': ['demon',
#   'muramasa',
#   'poweeeeer',
#   'legendary',
#   'powerful',
#   'blade',
#   'fighter',
#   'possessed',
#   'infinite',
#   'most'],
#  'Percy (TV)': ['kayak',
#   'paulette',
#   'trapped',
#   'race',
#   'become',
#   'feel',
#   'problem',
#   'yourself',
#   'let',
#   'need'],
#  'Peridot & Steven': ['yeah'],
#  'Jasper & Amethyst': ['huh'],
#  'Smoky Quartz': ['smoky',
#   'woahoh',
#   'rreeeeeeeow',
#   'kapow',
#   'dink',
#   'corruption',
#   'plenty',
#   'tricks',
#   'sink',
#   'fans'],
#  'Amethyst (Jasper)': ['prisoners',
#   'tan',
#   'trusting',
#   'germs',
#   'worn',
#   'ease',
#   'rolls',
#   'warm',
#   'curse',
#   'heheh'],
#  '"Eyeball")': ['minute',
#   'different',
#   'than',
#   'thought',
#   'wait',
#   'would',
#   'look',
#   'a',
#   'you',
#   'i'],
#  'Ruby ("Doc")': ['liking', 'hope', 'its', 'your', 'to', 'i'],
#  'Other Rubies': ['respect', 'rude', 'unbelievable', 'no', 'way'],
#  '"Giant" Ruby': ['trick',
#   'rid',
#   'oof',
#   'easy',
#   'us',
#   'wont',
#   'let',
#   'again',
#   'yeah',
#   'cant'],
#  'Smoky': ['heya',
#   'dogwalking',
#   'bwooop',
#   'lick',
#   'string',
#   'thisaways',
#   'realbowzo',
#   'sardonyxi',
#   'sards',
#   'equals'],
#  'Sugilite (Voiceover)': ['ha',
#   'aint',
#   'try',
#   'man',
#   'nice',
#   'nothing',
#   'little',
#   'got',
#   'like',
#   'that'],
#  'Buddy (Jamie)': ['adventurer',
#   'narrowly',
#   'cemented',
#   'bronzed',
#   'wondered',
#   'shant',
#   'lowly',
#   'schwill',
#   'greatness',
#   'unexplored'],
#  'Stranger': ['buddy', 'hey'],
#  'Garnet & Stevonnie': ['remind',
#   'fear',
#   'fall',
#   'watch',
#   'apart',
#   'okay',
#   'lose',
#   'moment',
#   'yourself',
#   'thought'],
#  'Zoltron Robot': ['fortune',
#   'teller',
#   'w',
#   'zoltron',
#   'robot',
#   'numbers',
#   'future',
#   'lucky',
#   'am',
#   'today'],
#  'Zoltron (Steven)': ['zoltron',
#   'fetch',
#   'zoltrons',
#   'fills',
#   'predicts',
#   'stain',
#   'zzoltron',
#   'depressing',
#   'debt',
#   'repaid'],
#  'Mr. Frowney': ['fortunetelling',
#   'lifes',
#   'rained',
#   'difference',
#   'coins',
#   'disappointment',
#   'curtain',
#   'punchline',
#   'lightning',
#   'frowney'],
#  'Masked Kid': ['garbanzo'],
#  'Garbanzo': ['garbanzo',
#   'ggargarbanzo',
#   'gar',
#   'banzooo',
#   'ggarbanzo',
#   'gaaarbaaanzoooo'],
#  'Pilot': ['hippies',
#   'ahwhat',
#   'hobos',
#   'hobettes',
#   'hobo',
#   'constructions',
#   'jewels',
#   'socializin',
#   'whaaah',
#   'american'],
#  'Andy': ['hippie',
#   'demayos',
#   'tradition',
#   'leftovers',
#   'freeloaders',
#   'usin',
#   'turd',
#   'nephews',
#   'condolences',
#   'oints'],
#  'Andy (off-screen)': ['inlaws',
#   'technically',
#   'married',
#   'werent',
#   'mean',
#   'get',
#   'right',
#   'do',
#   'what',
#   'it'],
#  'Greg (off-screen)': ['andy', 'look'],
#  'Everyone (Except Andy)': ['cheers'],
#  'Everyone else': ['hear'],
#  'Blue Diamond': ['punished',
#   'blasted',
#   'centi',
#   'selves',
#   'curious',
#   'humanitys',
#   'perish',
#   'grieve',
#   'accused',
#   'restrain'],
#  'Blue Pearl': ['native',
#   'arrival',
#   'appointment',
#   'proceedings',
#   'overpowering',
#   'elegance',
#   'lustrous',
#   'awaiting',
#   'requested',
#   'emotionally'],
#  'Guard 1': ['believed',
#   'state',
#   'shut',
#   'zoo',
#   'news',
#   'throw',
#   'purpose',
#   'means',
#   'heh',
#   'which'],
#  'Elite Gem': ['doing', 'are', 'what', 'you'],
#  'Guards': ['forgive',
#   'clarity',
#   'agate',
#   'holly',
#   'blue',
#   'us',
#   'nothing',
#   'your'],
#  'Holly Blue': ['miscreants',
#   'backtoback',
#   'incessant',
#   'thrashing',
#   'chatty',
#   'staffs',
#   'maintaining',
#   'dawn',
#   'structure',
#   'devoted'],
#  'Guard 2': ['holly',
#   'talk',
#   'nothing',
#   'down',
#   'lets',
#   'come',
#   'about',
#   'just',
#   'it'],
#  'Guard 3': ['spunky',
#   'iiits',
#   'newer',
#   'agate',
#   'holly',
#   'news',
#   'blue',
#   'heh',
#   'humans',
#   'important'],
#  'Guard 4': ['agate',
#   'holly',
#   'uhh',
#   'blue',
#   'sorry',
#   'oh',
#   'no',
#   'im',
#   'dont',
#   'its'],
#  'Zooman 1': ['gareg', 'who', 'with', 'that', 'is', 'you'],
#  'Zooman 2': ['gareg', 'friend', 'new', 'is', 'this', 'a'],
#  'Zooman 3': ['greetings'],
#  'Zooman 4': ['gareg', 'wow'],
#  'Zoomans': ['cannonball', 'bits', 'yes', 'hi', 'oh', 'are', 'we', 'the'],
#  'Wy-Six': ['stevan',
#   'gareg',
#   'discs',
#   'wheeled',
#   'conveyance',
#   'caruise',
#   'laze',
#   'delinquents',
#   'choosen',
#   'cannonball'],
#  'Zooman 5': ['say', 'come', 'on', 'it'],
#  '???': ['daily',
#   'letmesee',
#   'afar',
#   'period',
#   'designated',
#   'meal',
#   'routine',
#   'greetings',
#   'quickly',
#   'enjoy'],
#  'Jay-Ten': ['gareg',
#   'stevan',
#   'splash',
#   'choosening',
#   'choosen',
#   'voices',
#   'guide',
#   'circle',
#   'wall',
#   'opening'],
#  'Little Voice': ['circle',
#   'refreshing',
#   'choosening',
#   'gather',
#   'bath',
#   'choosened',
#   'jayten',
#   'pool',
#   'u',
#   'center'],
#  'Together': ['do', 'you'],
#  'Amethyst(s)': ['trouble', 'big', 'two', 'are', 'in', 'you'],
#  'Amethyst 1': ['haa',
#   'cutxm',
#   'xh',
#   'j',
#   'cliquey',
#   'skinnys',
#   'shortest',
#   'unreal',
#   'stations',
#   'betas'],
#  'Amethyst 2': ['priceless',
#   'unit',
#   'emerged',
#   'comes',
#   'yet',
#   'them',
#   'havent',
#   'amethyst',
#   'two',
#   'were'],
#  '8XL': ['popped',
#   'pfft',
#   'waiting',
#   'under',
#   'amethyst',
#   'nothing',
#   'never',
#   'yeah',
#   'were',
#   'out'],
#  '8XJ': ['j', 'arent', 'all', 'im', 'we'],
#  'Skinny': ['prime',
#   'cliquey',
#   'celebrating',
#   'amethysts',
#   'so',
#   'are',
#   'you'],
#  'Carnelian': ['shortest', 'anymore', 'not', 'im', 'the'],
#  'Pearls': ['haa',
#   'haaaaa',
#   'aah',
#   'rid',
#   'ha',
#   'all',
#   'with',
#   'here',
#   'it',
#   'of'],
#  'Yellow Diamond & Pearls': ['drowning',
#   'regret',
#   'feeling',
#   'use',
#   'rather',
#   'forward',
#   'looking',
#   'ohh',
#   'plan',
#   'attack'],
#  'Connie (Narrating)': ['rocky',
#   'challenge',
#   'seemed',
#   'realized',
#   'wash',
#   'felt',
#   'person',
#   'crystal',
#   'alone',
#   'house'],
#  'Steven (On phone)': ['dads',
#   'trouble',
#   'space',
#   'him',
#   'into',
#   'need',
#   'back',
#   'get',
#   'go',
#   'in'],
#  'Lapis (imitating Garnet)': ['amethyst',
#   'garnet',
#   'only',
#   'there',
#   'no',
#   'is'],
#  'Connie, Lapis & Peridot (with Pumpkin)': ['temps', 'crystal', 'go'],
#  'Priyanka Maheswaran (voicemail)': ['patients',
#   'reached',
#   'maheswaran',
#   'number',
#   'doctor',
#   'message',
#   'shouldnt',
#   'leave',
#   'youve',
#   'please'],
#  'Ronaldo (Video)': ['followers',
#   'truths',
#   'thankless',
#   'outsider',
#   'joining',
#   'mixed',
#   'pride',
#   'loyal',
#   'bringing',
#   'ended'],
#  "Steven's Phone": ['quiet',
#   'rabbit',
#   'forest',
#   'trees',
#   'ahhh',
#   'sing',
#   'begins',
#   'sky',
#   'small',
#   'are'],
#  'Billy Bank Assets': ['huff',
#   'stocks',
#   'financially',
#   'puff',
#   'stable',
#   'blow',
#   'actually',
#   'pretty',
#   'well',
#   'guess'],
#  'Lapis & Peridot': ['steven'],
#  'Rose (TV)': ['nora',
#   'intro',
#   'rambling',
#   'asia',
#   'bitty',
#   'ittaisiaby',
#   'rearrange',
#   'hairball',
#   'unlocks',
#   'pleeeeease'],
#  'Greg (TV)': ['edit',
#   'following',
#   'part',
#   'woah',
#   'hes',
#   'now',
#   'can',
#   'do',
#   'me',
#   'we'],
#  'Doug': ['loitering',
#   'trespassing',
#   'trusty',
#   'swashbuckling',
#   'swashbuckler',
#   'stakeout',
#   'hopping',
#   'shoplifting',
#   'equip',
#   'punk'],
#  'Lars, Steven & Sadie': ['hmm'],
#  'Steven & Sadie': ['amazing'],
#  'Lars (Voicemail)': ['message', 'lars', 'leave', 'is', 'this', 'a'],
#  'Teens of Rage Announcer': ['challengers',
#   'validate',
#   'awaiting',
#   'new',
#   'me',
#   'to'],
#  'Teardrop Gem': ['topaz',
#   'organics',
#   'squirming',
#   'dad',
#   'aquamarine',
#   'wasted',
#   'bother',
#   'listening',
#   'connie',
#   'couldve'],
#  'The Gems': ['whoo', 'vacation', 'what'],
#  'Aquamarine': ['shatterings',
#   'rosie',
#   'screwed',
#   'takeoff',
#   'revolt',
#   'rewarded',
#   'handsomely',
#   'handed',
#   'boulder',
#   'separated'],
#  'Topaz': ['clutches',
#   'heartfelt',
#   'topaz',
#   'doom',
#   'aquamarine',
#   'missions',
#   'coordinates',
#   'pod',
#   'pretending',
#   'sending'],
#  'Zircon (Defense)': ['unluckiest',
#   'zircon',
#   'loyal',
#   'service',
#   'ridiculous',
#   'court',
#   'galaxy',
#   'years',
#   'quartz',
#   'rose'],
#  'Zircon (D)': ['brief',
#   'guilty',
#   'thoughtout',
#   'ininnocent',
#   'tumble',
#   'shallow',
#   'stratagem',
#   'attachment',
#   'indisputable',
#   'overseeing'],
#  'Zircon (Prosecutor)': ['defending', 'treason', 'rebel', 'isnt', 'that', 'a'],
#  'Zircon (P)': ['opulent',
#   'glimmering',
#   'committed',
#   'crime',
#   'exhibit',
#   'passion',
#   'diabolical',
#   'eyewitness',
#   'whatsoever',
#   'specimen'],
#  'Eyeball': ['villainous',
#   'sigh',
#   'wallpaper',
#   'som',
#   'cases',
#   'clumsy',
#   'emoji',
#   'buttdialed',
#   'mamay',
#   'paraphernalia'],
#  'Steven & Lars': ['aghh', 'aah'],
#  'Twin Gems': ['bizarre',
#   'belong',
#   'rhodonite',
#   'forgotten',
#   'relax',
#   'certainly',
#   'brought',
#   'somewhere',
#   'seen',
#   'come'],
#  'Rhodonite': ['quads',
#   'unforgivable',
#   'morganite',
#   'storys',
#   'exposed',
#   'decimated',
#   'undetected',
#   'battleship',
#   'pointed',
#   'llowering'],
#  '"Sapphire" Gem': ['prediction',
#   'wondrous',
#   'strangers',
#   'current',
#   'rutile',
#   'twins',
#   'hiding',
#   'bring',
#   'everyone',
#   'place'],
#  'Rutile Twins': ['scanned',
#   'rutiles',
#   'incredulous',
#   'wich',
#   'behalf',
#   'destroyers',
#   'offline',
#   'hyperdefective',
#   'malformed',
#   'haywire'],
#  'Giant Fusion Gem': ['theydontlooklikegems',
#   'gemslikeusarentneeded',
#   'padparadschacanonlypredictthingsthatjusthappened'],
#  'Fluorite': ['thatswhyyoulooksounusual',
#   'maybemore',
#   'ifwemeettherightgem',
#   'theyseemto',
#   'haveoverlooked',
#   'usforthe',
#   'timebeing',
#   'butif',
#   'theyllfind',
#   'usforsure'],
#  'Padparadscha': ['gemless',
#   'reflective',
#   'hue',
#   'winning',
#   'emerald',
#   'marvelous',
#   'pressing',
#   'predict',
#   'launch',
#   'fluorite'],
#  'Male Citizen': ['sick', 'mayor', 'hes', 'were', 'of', 'it', 'the'],
#  'All, except Steven': ['no'],
#  'Female Citizen': ['involved', 'maybe', 'should', 'he', 'yeah', 'be'],
#  'Bill Dewey': ['mo',
#   'traditional',
#   'debate',
#   'oww',
#   'tennis',
#   'drag',
#   'middle',
#   'mayor',
#   'room',
#   'talking'],
#  'Ronaldo (Voiceover)': ['koala',
#   'princess',
#   'steveeen',
#   'lent',
#   'entangled',
#   'immersive',
#   'lore',
#   'kangaroofus',
#   'wombats',
#   'naught'],
#  'Steven a& Peridot': ['aah'],
#  'Steven, Buck & Jenny': ['what'],
#  'Zombie (TV)': ['brains'],
#  'Steven, Buck, Jenny & Sour Cream': ['whoa'],
#  'Steven & Jenny': ['sadie'],
#  'Derrick': ['kev',
#   'yearold',
#   'invited',
#   'bro',
#   'yo',
#   'dude',
#   'aah',
#   'who',
#   'come',
#   'no'],
#  'Steven & Kevin': ['no', 'what'],
#  'Party-Goers': ['yeah'],
#  'Green Gem': ['colors',
#   'miserable',
#   'over',
#   'off',
#   'ive',
#   'got',
#   'now',
#   'its',
#   'you'],
#  'Emerald': ['nova',
#   'inconvenience',
#   'shuttle',
#   'upsilon',
#   'impersonated',
#   'officers',
#   'cosmic',
#   'jubilee',
#   'citrines',
#   'guarding'],
#  'Lars, Rhodonite, Rutile Twins & Fluorite': ['aww'],
#  'Stevens': ['twins'],
#  'Rhononite & Rutile Twins': ['quartz', 'rose'],
#  'Pink Diamond': ['insolence',
#   'creating',
#   'expense',
#   'absurd',
#   'post',
#   'convincing',
#   'hehe',
#   'nno',
#   'lifeforms',
#   'prime'],
#  'Off Colors': ['yes', 'okay', 'yeah'],
#  'Sadie & Cool Kids': ['suspects', 'killer', 'sadie', 'yeah', 'and', 'the'],
#  'Sadie & Jenny': ['venue', 'the'],
#  'Sadie (Pre-recorded)': ['calling',
#   'side',
#   'other',
#   'from',
#   'im',
#   'the',
#   'you'],
#  'Sunshine': ['venue',
#   'gimmick',
#   'anytime',
#   'reminds',
#   'whered',
#   'suspects',
#   'kids',
#   'killer',
#   'crowd',
#   'ahead'],
#  'Passerby': ['thanks', 'hey'],
#  'Steven (voiceover)': ['soooo',
#   'misses',
#   'letter',
#   'dear',
#   'fill',
#   'answer',
#   'hows',
#   'lars',
#   'since',
#   'space'],
#  'Steven (v.o.)': ['marmalade',
#   'gearing',
#   'street',
#   'tagteam',
#   'wasp',
#   'reopening',
#   'spirits',
#   'completes',
#   'election',
#   'platform'],
#  'Bill': ['oogity',
#   'boogity',
#   'ooohooohooo',
#   'waiter',
#   'worms',
#   'outgrown',
#   'cue',
#   'potato',
#   'restaurant',
#   'mobile'],
#  'Mr. Dewey': ['freshly',
#   'fried',
#   'dewey',
#   'roll',
#   'classic',
#   'ha',
#   'line',
#   'cute',
#   'house',
#   'next'],
#  'Pearl #1': ['paraphernalia',
#   'alphabetical',
#   'compartmentalizing',
#   'alphabetized',
#   'spears',
#   'items',
#   'st',
#   'pho',
#   'cellular',
#   'c'],
#  'Pearl #2': ['cellphone',
#   'disappears',
#   'lost',
#   'baby',
#   'lose',
#   'thinking',
#   'probably',
#   'she',
#   'else',
#   'said'],
#  'Pearl #3': ['won',
#   'bright',
#   'wed',
#   'light',
#   'leaving',
#   'ones',
#   'homeworld',
#   'left',
#   'everyone',
#   'thought'],
#  'Pearl #4': ['nods',
#   'excitedly',
#   'status',
#   'none',
#   'purpose',
#   'crazy',
#   'matter',
#   'rose',
#   'anymore',
#   'change'],
#  'Amethyst 3': ['nicest',
#   'anyone',
#   'said',
#   'first',
#   'ever',
#   'has',
#   'thing',
#   'me',
#   'that',
#   'is'],
#  'Amethyst 4': ['emerged',
#   'orders',
#   'catch',
#   'later',
#   'soon',
#   'move',
#   'as',
#   'go',
#   'she',
#   'whats'],
#  'Amethyst 5': ['xm', 'emerged', 'hasnt', 'yet', 'but'],
#  'Pearl (voiceover)': ['preserve',
#   'handful',
#   'created',
#   'ignore',
#   'threw',
#   'she',
#   'zoo',
#   'status',
#   'finish',
#   'decided'],
#  'Amethyst & Steven': ['ruby'],
#  'Ruby (voiceover)': ['ridin',
#   'sturdy',
#   'solitary',
#   'rider',
#   'ol',
#   'stone',
#   'ruby',
#   'alone',
#   'shes',
#   'is'],
#  'Ruby (v.o.)': ['rider',
#   'dust',
#   'ol',
#   'dirt',
#   'danger',
#   'ruby',
#   'fusion',
#   'home',
#   'new',
#   'more'],
#  'All': ['aauuh', 'wooow', 'pearl'],
#  'Pearl & Ruby': ['biiismuth'],
#  'Everyone Else': ['day',
#   'only',
#   'lets',
#   'think',
#   'one',
#   'about',
#   'just',
#   'right'],
#  'Steven & Garnet': ['needed',
#   'future',
#   'thanks',
#   'everything',
#   'here',
#   'for',
#   'are',
#   'in',
#   'we',
#   'this'],
#  'Mayor Nanefua': ['shelters',
#   'stragglers',
#   'designated',
#   'repeat',
#   'drill',
#   'attention',
#   'yourselves',
#   'citizens',
#   'missing',
#   'head'],
#  'Pearl, Amethyst & Garnet': ['right'],
#  'Connie (Mind)': ['supposed',
#   'remember',
#   'together',
#   'were',
#   'be',
#   'in',
#   'this',
#   'to'],
#  'Garnet (Mind)': ['surprises',
#   'hold',
#   'together',
#   'full',
#   'ive',
#   'everyone',
#   'got',
#   'always',
#   'huh',
#   'it'],
#  'Amethyst (Mind)': ['shattered',
#   'get',
#   'can',
#   'dont',
#   'do',
#   'this',
#   'steven',
#   'i'],
#  'Pearl (Mind)': ['wont',
#   'him',
#   'everything',
#   'give',
#   'do',
#   'her',
#   'for',
#   'up',
#   'it',
#   'i'],
#  'Bismuth (Mind)': ['em',
#   'lose',
#   'yet',
#   'thinking',
#   'lost',
#   'friends',
#   'havent',
#   'again',
#   'am',
#   'gonna'],
#  'Yellow Diamond (Mind)': ['fate',
#   'blame',
#   'miserable',
#   'handle',
#   'gave',
#   'colony',
#   'knew',
#   'couldnt',
#   'own',
#   'her'],
#  'Blue Diamond (Mind)': ['suffer',
#   'more',
#   'pink',
#   'long',
#   'any',
#   'gems',
#   'these',
#   'again',
#   'will',
#   'good'],
#  'Steven (Mind)': ['enemies',
#   'family',
#   'fighting',
#   'please',
#   'listen',
#   'arent',
#   'has',
#   'stop',
#   'am',
#   'who'],
#  'Nephrite': ['cabochon',
#   'heed',
#   'avenged',
#   'hessonites',
#   'evacuation',
#   'nephrite',
#   'facet',
#   'failure',
#   'mustve',
#   'team'],
#  'Amethyst & Connie': ['yeah'],
#  'White Pearl': ['attendance',
#   'therefore',
#   'required',
#   'attend',
#   'observe',
#   'era',
#   'presence',
#   'necessary',
#   'ball',
#   'white'],
#  'Connie & Pearl': ['steven'],
#  'White Diamond': ['ruled',
#   'littlest',
#   'comforts',
#   'bequeath',
#   'despair',
#   'championed',
#   'furthest',
#   'announce',
#   'soooooo',
#   'waaaait'],
#  'Brainy': ['thank', 'you'],
#  'Patch': ['is', 'it'],
#  'Nosey': ['nosey',
#   'begins',
#   'laugh',
#   'funny',
#   'pink',
#   'very',
#   'her',
#   'is',
#   'it',
#   'to'],
#  'Chesto': ['different', 'does', 'she', 'look', 'why'],
#  'Gem #5': ['shes', 'back'],
#  'Noggin': ['pinkie', 'pink', 'shes', 'diamond', 'our', 'back', 'time'],
#  'Fisto': ['pebbles',
#   'pretending',
#   'games',
#   'playing',
#   'doesnt',
#   'always',
#   'she',
#   'us',
#   'her',
#   'know'],
#  'Comby': ['aloney',
#   'combing',
#   'as',
#   'youll',
#   'long',
#   'never',
#   'be',
#   'are',
#   'you'],
#  'Pebble': ['pinks', 'moving', 'again'],
#  'Yellow & Blue Pearl': ['command',
#   'pink',
#   'diamond',
#   'whatever',
#   'at',
#   'your',
#   'are',
#   'we',
#   'you'],
#  'Pair of Gems #1': ['sparkly',
#   'radiant',
#   'wonderful',
#   'presence',
#   'pink',
#   'wow',
#   'diamond',
#   'be',
#   'its',
#   'your'],
#  'Pair of Gems #2': ['exquisite',
#   'radiant',
#   'pink',
#   'wow',
#   'diamond',
#   'so',
#   'and'],
#  'Lemon Jade': ['aahhh',
#   'knew',
#   'couldnt',
#   'only',
#   'one',
#   'be',
#   'i',
#   'me',
#   'it',
#   'and'],
#  'Pink Diamond (Steven)': ['sorry', 'know', 'im', 'i'],
#  'Pink Pearl (White Diamond)': ['grave',
#   'conduct',
#   'addressed',
#   'however',
#   'issues',
#   'rooms',
#   'certain',
#   'mistake',
#   'anywhere',
#   'forward'],
#  'Connie & Peridot': ['steven'],
#  'Smoky (Amethyst)': ['smoky',
#   'genius',
#   'smokes',
#   'coaster',
#   'pulled',
#   'roller',
#   'holy',
#   'save',
#   'mmm',
#   'uhh'],
#  'Rainbow Quartz 2.0': ['rainbow',
#   'stones',
#   'activate',
#   'bird',
#   'powers',
#   'mess',
#   'quartz',
#   'fine',
#   'ah',
#   'wont'],
#  'Sunstone': ['bully',
#   'awwwwwwwwwww',
#   'chillax',
#   'alleyoop',
#   'owwwwwww',
#   'sunstones',
#   'foul',
#   'electrical',
#   'respecting',
#   'crosswalk'],
#  'Amethyst (White Diamond)': ['generous',
#   'excellent',
#   'white',
#   'thank',
#   'feel',
#   'diamond',
#   'oh',
#   'now',
#   'how',
#   'of'],
#  'Garnet (White Diamond)': ['white',
#   'thank',
#   'better',
#   'feel',
#   'diamond',
#   'much',
#   'now',
#   'so',
#   'we',
#   'you'],
#  'Pearl (White Diamond)': ['excellent', 'feel', 'i'],
#  'Gem Steven': ['gooonnne', 'shes', 'gone'],
#  'Pink Pearl': ['nickname',
#   'blip',
#   'serves',
#   'boutique',
#   'refurbishment',
#   'trivial',
#   'volleyball',
#   'luxury',
#   'whwhat',
#   'ribbon'],
#  'Steven (Voiceover)': ['world',
#   'people',
#   'believe',
#   'amethyst',
#   'garnet',
#   'find',
#   'always',
#   'pearl',
#   'way',
#   'think'],
#  'Blue & Yellow Diamond': ['believes',
#   'tale',
#   'heard',
#   'everyone',
#   'have',
#   'in',
#   'of',
#   'the',
#   'you'],
#  'The Diamonds': ['adore',
#   'revelation',
#   'revolution',
#   'palace',
#   'compassionate',
#   'hers',
#   'grows',
#   'remind',
#   'loves',
#   'imagine'],
#  'Steven & Pearl': ['future', 'here', 'are', 'in', 'we', 'the'],
#  'Spinel': ['driiift',
#   'loop',
#   'nobodies',
#   'singsongy',
#   'wrooong',
#   'reeled',
#   'flooding',
#   'smiled',
#   'driiiiiiift',
#   'presto'],
#  'Shell': ['identify',
#   'preferred',
#   'customization',
#   'selected',
#   'illuminated',
#   'offerings',
#   'accessories',
#   'scanning',
#   'impactful',
#   'manifest'],
#  'Bismuth & Peridot': ['find', 'way', 'well', 'a'],
#  'Bismuth & Lapis': ['save', 'day', 'to', 'the'],
#  'Steven, Bismuth, Peridot & Lapis': ['save',
#   'day',
#   'find',
#   'who',
#   'way',
#   'thats',
#   'well',
#   'are',
#   'we',
#   'a'],
#  'Sadie & Amethyst': ['disobedient',
#   'deranged',
#   'summers',
#   'wasted',
#   'awake',
#   'spent',
#   'shoot',
#   'wondering',
#   'went',
#   'wanna'],
#  'Steg': ['independent',
#   'gettin',
#   'crushed',
#   'push',
#   'weight',
#   'master',
#   'lift',
#   'endless',
#   'remind',
#   'nothings'],
#  'Steg & Opal': ['independent',
#   'together',
#   'fly',
#   'can',
#   'and',
#   'we',
#   'i',
#   'you'],
#  'Spinel (Pink)': ['garden',
#   'game',
#   'stand',
#   'play',
#   'done',
#   'show',
#   'still',
#   'very',
#   'ill',
#   'lets'],
#  'Steven & Spinel': ['youme',
#   'someday',
#   'youllill',
#   'youreim',
#   'youi',
#   'somehow',
#   'treats',
#   'someone',
#   'somewhere',
#   'wants'],
#  'Garnet (v.o.)': ['true', 'kinda', 'love', 'its', 'the'],
#  'Garnet, Amethyst, Pearl & Greg': ['steven'],
#  'The Diamonds (overlapping)': ['adore',
#   'palace',
#   'white',
#   'room',
#   'together',
#   'yellow',
#   'waiting',
#   'come',
#   'live',
#   'blue'],
#  'Spinel & the Diamonds': ['wellill',
#   'weveive',
#   'found',
#   'already',
#   'someone',
#   'love',
#   'again'],
#  'Crystal Gems & Greg': ['future', 'here', 'are', 'we', 'in', 'and', 'the'],
#  'Peridot & Lapis': ['future', 'here', 'are', 'in', 'we', 'the'],
#  'Lars, Sadie, & Mayor Nanefua': ['future', 'here', 'are', 'in', 'we', 'the'],
#  'Garnet, Amethyst, & Pearl': ['future', 'here', 'are', 'in', 'we', 'the'],
#  'Everyone': ['future', 'here', 'are', 'in', 'we', 'who', 'the'],
#  'Garnet, Amethyst, Pearl & Connie': ['bright',
#   'far',
#   'change',
#   'its',
#   'come',
#   'make',
#   'and',
#   'here',
#   'so',
#   'can'],
#  'Cherry Quartz': ['morp',
#   'class',
#   'whose',
#   'schedule',
#   'sign',
#   'missed',
#   'idea',
#   'who',
#   'talking',
#   'happened'],
#  'Steven (Narrating)': ['pastry',
#   'promoting',
#   'applying',
#   'fundamental',
#   'equally',
#   'intergalactic',
#   'album',
#   'prep',
#   'gimmick',
#   'touring'],
#  'Ruby 1': ['classified',
#   'nursecitizen',
#   'kissing',
#   'mmhmm',
#   'information',
#   'complete',
#   'geez',
#   'mission',
#   'mayor',
#   'clear'],
#  'Ruby 2': ['clear', 'thanks', 'amethyst', 'all'],
#  'Snowflake Obsidian': ['trenches',
#   'filling',
#   'ice',
#   'dug',
#   'armies',
#   'snow',
#   'uhh',
#   'their',
#   'yes',
#   'about'],
#  'Larimar': ['screams',
#   'sculptures',
#   'delights',
#   'amusement',
#   'stuffed',
#   'larimar',
#   'operation',
#   'handing',
#   'screaming',
#   'actor'],
#  'Zebra Jasper': ['gaahh', 'order', 'up'],
#  'Ocean Jasper': ['delivery',
#   'sunstone',
#   'wowzers',
#   'g',
#   'slip',
#   'stairs',
#   'dangerous',
#   'watch',
#   'looks',
#   'better'],
#  'Smoky (Steven)': ['saving',
#   'second',
#   'took',
#   'ugh',
#   'universe',
#   'any',
#   'give',
#   'time',
#   'dont',
#   'know'],
#  'An Amethyst': ['chill', 'holly', 'blue', 'want', 'out', 'know', 'you', 'to'],
#  'The Famethyst': ['missed', 'aw', 'amethyst', 'yeah', 'we', 'you'],
#  '"Superfan" Rose': ['carrot',
#   'siblings',
#   'athletic',
#   'cutting',
#   'unbubbled',
#   'breathing',
#   'beans',
#   'heroes',
#   'dying',
#   'imagined'],
#  '"Hippie" Rose': ['smelled',
#   'massage',
#   'slumber',
#   'related',
#   'bummer',
#   'bubbled',
#   'butter',
#   'tense',
#   'relaxing',
#   'chill'],
#  '"Shy" Rose': ['hint',
#   'bothering',
#   'swore',
#   'quartzes',
#   'pretending',
#   'created',
#   'bubbled',
#   'wear',
#   'expect',
#   'excuse'],
#  'Rose Quartz (TV)': ['exist',
#   'become',
#   'half',
#   'both',
#   'going',
#   'cant',
#   'im',
#   'steven',
#   'we',
#   'to'],
#  'Angel Aura Quartz': ['waahhh', 'fast', 'think'],
#  'Pink Steven': ['gasp',
#   'horrible',
#   'pearls',
#   'fix',
#   'deal',
#   'hear',
#   'want',
#   'stop',
#   'she',
#   'even'],
#  'Mega Pearl': ['mothers',
#   'expected',
#   'mother',
#   'picture',
#   'pearls',
#   'change',
#   'understand',
#   'each',
#   'trying',
#   'knew'],
#  'Short Fusion Gem': ['savior',
#   'himself',
#   'aint',
#   'old',
#   'well',
#   'universe',
#   'gem',
#   'if',
#   'steven',
#   'it'],
#  'Bluebird': ['die',
#   'azurite',
#   'clams',
#   'appen',
#   'waterworks',
#   'celebrated',
#   'duped',
#   'rue',
#   'en',
#   'garde'],
#  '"Eyeball" and Aquamarine': ['yes', 'too', 'know', 'me', 'i'],
#  'Character 1': ['bandit',
#   'blackbird',
#   'unintelligible',
#   'parasol',
#   'animated',
#   'nesta',
#   'stressedstick',
#   'nestand',
#   'blackbirds',
#   'restthe'],
#  '"Explorer Gal"': ['unintelligible', 'speech'],
#  'Rainbow 2.0': ['blackbird',
#   'parasol',
#   'animated',
#   'nesta',
#   'stressedstick',
#   'nestand',
#   'blackbirds',
#   'restthe',
#   'aroundthe',
#   'aroundand'],
#  'Ocean JasperNephrite': ['aaah'],
#  'Steven and Pearl': ['nope'],
#  'Cat Steven': ['meow'],
#  '"Nice" Lapis': ['exemplary',
#   'presume',
#   'halfdiamond',
#   'halflisten',
#   'teaching',
#   'mentioned',
#   'misunderstanding',
#   'taught',
#   'minute',
#   'school'],
#  '"Mean" Lapis': ['uhuhuhuhuh',
#   'terraforming',
#   'prefer',
#   'chains',
#   'colors',
#   'mud',
#   'pitiful',
#   'smaller',
#   'easier',
#   'dull'],
#  'Shep': ['critique',
#   'magics',
#   'suffocate',
#   'drifting',
#   'cd',
#   'dome',
#   'shep',
#   'awww',
#   'cake',
#   'grow'],
#  'Cactus': ['woof'],
#  'Cactus Steven': ['steeeven',
#   'lithen',
#   'tryna',
#   'thsorry',
#   'togetherr',
#   'whyy',
#   'steevennn',
#   'woow',
#   'sprouted',
#   'hay'],
#  'Cookie Cat': ['needs',
#   'still',
#   'help',
#   'why',
#   'one',
#   'no',
#   'here',
#   'your',
#   'steven',
#   'so'],
#  'Rodrigo': ['stefan',
#   'jasmine',
#   'wwhat',
#   'arms',
#   'fly',
#   'thanks',
#   'happening',
#   'guy',
#   'best',
#   'wish'],
#  'Stefan': ['jasmine',
#   'downstream',
#   'birds',
#   'rodrigo',
#   'toward',
#   'birdy',
#   'island',
#   'headed',
#   'specimens',
#   'full'],
#  'Jasmine': ['stefan',
#   'rodrigo',
#   'lie',
#   'person',
#   'hear',
#   'best',
#   'bad',
#   'thanks',
#   'guess',
#   'being'],
#  'Sour Cream (on radio)': ['emily',
#   'rink',
#   'featuring',
#   'king',
#   'starlight',
#   'request',
#   'dj',
#   'songs',
#   'roller',
#   'sour'],
#  'Man': ['shady',
#   'mechanics',
#   'cams',
#   'bleeding',
#   'dry',
#   'tired',
#   'bring',
#   'are',
#   'of',
#   'it'],
#  'Jaime': ['moves',
#   'woo',
#   'yo',
#   'bismuth',
#   'alright',
#   'gotta',
#   'cool',
#   'show',
#   'those',
#   'pearl'],
#  'Khadijah': ['architect',
#   'marvellous',
#   'skate',
#   'bismuth',
#   'known',
#   'also',
#   'long',
#   'guys',
#   'wow',
#   'pearl'],
#  'A girl': ['connie', 'whoa', 'that', 'is'],
#  'Daniel': ['okayy',
#   'ap',
#   'stressed',
#   'classes',
#   'moms',
#   'sec',
#   'forgot',
#   'heck',
#   'family',
#   'kinda'],
#  'Patricia': ['daniel',
#   'tore',
#   'grade',
#   'shoulda',
#   'bent',
#   'scores',
#   'earlier',
#   'test',
#   'shape',
#   'heck'],
#  'Brandish': ['flow', 'love', 'your', 'i'],
#  'Drew': ['dc',
#   'decoy',
#   'tours',
#   'skeleton',
#   'trauma',
#   'recovered',
#   'cortisol',
#   'harmful',
#   'extended',
#   'voicemail'],
#  'Announcer': ['pronounce',
#   'bark',
#   'woof',
#   'dogcopter',
#   'till',
#   'death',
#   'man',
#   'now',
#   'do',
#   'we'],
#  'Greg(on phone)': ['tours',
#   'extended',
#   'touring',
#   'tunnel',
#   'delmarva',
#   'shep',
#   'parties',
#   'routine',
#   'manager',
#   'throwing'],
#  'Connie(on phone)': ['medical',
#   'aare',
#   'hospital',
#   'professional',
#   'glowing',
#   'doctor',
#   'happening',
#   'worried',
#   'mom',
#   'uhh'],
#  'Priyanka': ['skeleton',
#   'trauma',
#   'recovered',
#   'cortisol',
#   'harmful',
#   'childhood',
#   'cancellation',
#   'booked',
#   'determine',
#   'nongem'],
#  'Kerry Moonbeam': ['comin',
#   'looking',
#   'lookin',
#   'universe',
#   'place',
#   'through',
#   'for',
#   'in',
#   'too',
#   'your'],
#  'Greg and Kerry Moonbeam': ['splinters',
#   'winters',
#   'chaples',
#   'teardrops',
#   'castles',
#   'temples',
#   'apples',
#   'seconds',
#   'flowers',
#   'cats'],
#  'A Jasper': ['zircon',
#   'stooge',
#   'vote',
#   'homeworlds',
#   'half',
#   'trust',
#   'face',
#   'believe',
#   'diamond',
#   'gonna'],
#  'Aubergine Pearl': ['storied',
#   'throughout',
#   'halls',
#   'gift',
#   'center',
#   'empire',
#   'truly',
#   'era',
#   'shop',
#   'power'],
#  'Chert': ['welcome', 'okay', 'hey', 'back', 'its'],
#  'Flint': ['hey'],
#  'White Diamond and Spinel': ['instead',
#   'control',
#   'channel',
#   'thoughts',
#   'body',
#   'taking',
#   'watch',
#   'her',
#   'guess',
#   'other'],
#  'Steven and White Diamond': ['thisthis',
#   'needed',
#   'weird',
#   'woah',
#   'last',
#   'anything',
#   'diamond',
#   'wont',
#   'away',
#   'want'],
#  'Steven (TV)': ['universe', 'im', 'is', 'a'],
#  'Plant Stevens': ['stevens', 'help', 'here', 'to'],
#  'Plant Steven': ['helping', 'were'],
#  'Bismuth, Peridot, and Lapis': ['what'],
#  'Peridot, Lapis, and Bismuth': ['love', 'too', 'steven', 'we', 'you'],
#  'Connie and Greg': ['bye']}

# %%
# See how tokens change over episodes and seasons
# Create a document for each speaker, where the corpus is a episode

merged_df = transcripts_df.merge(episodes_df, left_on='episode', right_on='title')
merged_df.head()
# Out:
#     episode speaker                                            actions  \
# 0  Gem Glow     NaN                                                 []
# 1  Gem Glow     NaN                                                 []
# 2  Gem Glow  Steven                                                 []
# 3  Gem Glow     NaN                                                 []
# 4  Gem Glow  Steven  ['looking at an empty freezer', 'grabs Lars ar...
#
#                                                quote  \
# 0                                                NaN
# 1                                                NaN
# 2                                   NOOOOOOOOOOOOO!!
# 3                                                NaN
# 4  This can't be happening! This has to be a drea...
#
#                       location description     title season num_series  \
# 0  Open Overview of Beach City         NaN  Gem Glow      1          1
# 1        Trans. Ext. Big Donut         NaN  Gem Glow      1          1
# 2                          NaN         NaN  Gem Glow      1          1
# 3        Trans. Int. Big Donut         NaN  Gem Glow      1          1
# 4                          NaN         NaN  Gem Glow      1          1
#
#   num_season  airdate                                            summary  \
# 0          1      NaN  Steven thinks his favorite ice cream sandwiche...
# 1          1      NaN  Steven thinks his favorite ice cream sandwiche...
# 2          1      NaN  Steven thinks his favorite ice cream sandwiche...
# 3          1      NaN  Steven thinks his favorite ice cream sandwiche...
# 4          1      NaN  Steven thinks his favorite ice cream sandwiche...
#
#                                       list_of_tokens
# 0  [steven, thinks, his, favorite, ice, cream, sa...
# 1  [steven, thinks, his, favorite, ice, cream, sa...
# 2  [steven, thinks, his, favorite, ice, cream, sa...
# 3  [steven, thinks, his, favorite, ice, cream, sa...
# 4  [steven, thinks, his, favorite, ice, cream, sa...

# %%
season = "1"
filtered = merged_df.loc[merged_df['season']==season, :]
filtered.head()
# Out:
#     episode speaker                                            actions  \
# 0  Gem Glow     NaN                                                 []
# 1  Gem Glow     NaN                                                 []
# 2  Gem Glow  Steven                                                 []
# 3  Gem Glow     NaN                                                 []
# 4  Gem Glow  Steven  ['looking at an empty freezer', 'grabs Lars ar...
#
#                                                quote  \
# 0                                                NaN
# 1                                                NaN
# 2                                   NOOOOOOOOOOOOO!!
# 3                                                NaN
# 4  This can't be happening! This has to be a drea...
#
#                       location description     title season num_series  \
# 0  Open Overview of Beach City         NaN  Gem Glow      1          1
# 1        Trans. Ext. Big Donut         NaN  Gem Glow      1          1
# 2                          NaN         NaN  Gem Glow      1          1
# 3        Trans. Int. Big Donut         NaN  Gem Glow      1          1
# 4                          NaN         NaN  Gem Glow      1          1
#
#   num_season  airdate                                            summary  \
# 0          1      NaN  Steven thinks his favorite ice cream sandwiche...
# 1          1      NaN  Steven thinks his favorite ice cream sandwiche...
# 2          1      NaN  Steven thinks his favorite ice cream sandwiche...
# 3          1      NaN  Steven thinks his favorite ice cream sandwiche...
# 4          1      NaN  Steven thinks his favorite ice cream sandwiche...
#
#                                       list_of_tokens
# 0  [steven, thinks, his, favorite, ice, cream, sa...
# 1  [steven, thinks, his, favorite, ice, cream, sa...
# 2  [steven, thinks, his, favorite, ice, cream, sa...
# 3  [steven, thinks, his, favorite, ice, cream, sa...
# 4  [steven, thinks, his, favorite, ice, cream, sa...

# %%
all_speakers = transcripts_df.speaker.unique()

# %%
test_speaker = all_speakers[7]

# %%
test_speaker
# Out:
# 'Garnet, Pearl & Amethyst'

# %%
set([speaker.strip() for speaker in re.split(', |& ', test_speaker)])
# Out:
# ['Garnet', 'Pearl', 'Amethyst']

# %%
test_speaker = test_speaker.strip()

# %%
test_speaker
# Out:
# 'Garnet, Pearl & Amethyst'

# %%
clean_speaker_list = test_speaker.lower().strip().split()

# %%
speaker_set = set(clean_speaker_list)
speaker_set
# Out:
# {'amethyst', 'garnet', 'pearl'}

# %%
all_speakers
# Out:
# array([nan, 'Steven', 'Lars', 'Sadie', 'Amethyst', 'Pearl', 'Garnet',
#        'Garnet, Pearl & Amethyst', 'Mr. Fryman', 'Steven & Amethyst',
#        'Greg', 'Pearl, Amethyst, and Garnet', 'Jamie', 'Mr. Queasy',
#        'Garnet, Amethyst & Pearl', 'Pearl & Amethyst',
#        'Amethyst & Garnet', 'Dumb Police', 'Gems', 'Peedee', 'Mr. Smiley',
#        'The Frymans', 'Mayor Dewey', 'Steven and Greg', 'Cat Finger',
#        'Sadie and Lars', 'Cat Fingers', 'Peedee and Mr. Fryman',
#        'Ronaldo', 'Connie', 'Chunk Truck', 'Random Man', 'Kiki',
#        'Road Killer', 'Teens of Rage', 'Punch Buddy', 'Meat Beat Mania',
#        'Opal', 'Whacker Man', 'Amethyst & Pearl', 'Jenny', 'Buck',
#        'Sour Cream', 'Jenny, Sour Cream & Buck', 'Jenny & Buck',
#        'G.U.Y.S. Machine', 'Lonely Blade', 'Samurai President',
#        'Holo-Pearl', 'Garnet & Amethyst', "Lonely Blade's Brother",
#        'Movie Narrator', 'Steven & Connie', 'Ticket Booth Lady', 'Kofi',
#        'Nanefua', 'Jenny & Kiki', 'Amethyst & Jenny', 'Ace',
#        'Pearl, Amethyst, & Garnet', "Ace's Father", 'Sadie & Lars',
#        'Tiny Floating Whale', 'Sugilite', 'Greg & Lars', 'Pearl & Steven',
#        'Steven & Greg', 'Mr. Smiley & Steven', 'Garnet & Pearl',
#        'Yellowtail', 'Steven 2', 'Steven & Steven 2', 'Steven 3',
#        'Steven 4', 'All Stevens', 'Steven 2 & Steven 3',
#        'All other Stevens', 'Past Steven', 'Gem Glow Steven',
#        'Beginning Steven', 'Handsome Steven', 'Crystal Gems',
#        'Connie (o.s.)', 'Lars & Sadie', 'Mirror', 'Lapis',
#        'Beach City Citizens', 'Mr. Pizza', 'TV Narrator', 'Lady',
#        'Doctor', 'Nurse', 'Mr. Maheswaran', 'Dr. Maheswaran',
#        'Alexandrite', 'Alexandrite (Pearl)', 'Alexandrite (Amethyst)',
#        'Alexandrite (Garnet)', 'Hopper', 'Hoppy', 'Ringo',
#        'Hoppy & Hopper', 'Foxman', 'Hoppy, Hopper & Ringo',
#        'Hopper & Hoppy', 'Unknown Narrator', 'Pearl, Garnet, & Amethyst',
#        'Dogcopter', 'Rose', 'Peridot', 'Stevonnie', 'Stevonnie (Connie)',
#        'Stevonnie (Steven)', 'Unknown Man', 'Kevin', 'Stereo',
#        'Cartoon Steven', 'Wasp 1', 'Wasp 2', 'Movie Hermit Man',
#        'Steven & Ronaldo', 'Spirit', 'Steven, Ronaldo & Lars',
#        'Young Ronaldo', 'Young Lars', 'Greg & Amethyst', "Li'l Butler",
#        'Man on TV', 'Teenage girl on TV', 'TV', 'Amethyst (background)',
#        'Garnet (background)', 'Holo-Rose', 'Pearl (unheard)',
#        'Cloud Connie', 'Mayor Dewey (Slow motion)',
#        'Bodyguard #1 (Slow motion)', 'Bodyguard #2 (Slow motion)',
#        'Marty', 'Vidalia', 'Purple Owl', 'Others',
#        'Mayor Dewey (voiceover)', 'Greg & Pearl',
#        'Answering Machine, voice of Dr.Maheswaran', 'Jasper', 'Ruby',
#        'Sapphire', 'Steven, Amethyst, & Pearl', 'Malachite',
#        'Malachite (Jasper)', 'Malachite (Lapis)', 'Cool Kids',
#        'Uncle Grandpa', 'Belly Bag', 'Pizza Steve', 'Mr. Gus',
#        'Giant Belly Bag', 'Jamie (Narrating)', 'Barbara',
#        'Pearl & Connie', 'Ronaldo (Narrator)', 'Ronaldo (Footage)',
#        'Mr. Fryman ("Footage")', 'Peedee ("Footage")',
#        'Mr. Fryman (Footage)', 'Peedee (Footage)',
#        'Ronaldo (Re-Enactment)', 'Peridot (Off-screen)', 'Garnet (Ruby)',
#        'Garnet (Sapphire)', 'RoseGreg', 'Narrator',
#        'Amethyst (off-screen)', 'Pearl (Dream)', 'Rose (Dream)',
#        'Fusion Gem', 'Sardonyx', 'Sad Spoon', 'Crying Pear',
#        'Ruby & Sapphire', 'Amethyst (Background)', 'Vidalia (Background)',
#        'Onion', 'Vidalia (VHS Tape)', 'Jamie & Steven',
#        'Jamie (Narrator)', 'Jamie (William Dewey)',
#        'Jamie (First Mate Buddy)', 'Steven (Narrator)', 'Steven & Jamie',
#        'Steven (William Dewey)', 'Jamie (Pearl)', 'Jamie (Garnet)',
#        'Jamie (Amethyst)', 'Jamie (Giant Woman)',
#        'Hospital Staff Member #1', 'Hospital Staff Member #2',
#        'DR. Maheswaran', 'Steven & Barbara', 'Cloud Peridot',
#        'Steven & Peridot', 'Pearl & Peridot',
#        'Steven, Garnet, & Amethyst', 'Steven (Cluster Puppet)',
#        'Tape Recorder (Peridot)', 'Garnet (Narrator)', 'Ruby Guard 1',
#        'Ruby Guard 2', 'Rose & Pearl', 'Past Garnet',
#        'Various Gems (Garnet)', 'Greg, Connie & the Gems', 'Yellow Pearl',
#        'Yellow Diamond', 'Paulette', 'Percy', 'Percy & Peridot',
#        'Peridot & Amethyst', 'Tape Recorder (Garnet)', 'Gem Shards',
#        'Gem Shard #1', 'The Cluster', 'Gem Shard #2', 'Gem Shard #3',
#        'Random Bystander', 'Lapis (Narrator)', '"Army"', '"Navy"',
#        '"Leggy"', '"Doc"', 'Homeworld Rubies',
#        'Peridot, Amethyst, Pearl, & Sapphire', '"Eyeball"', 'Giant Ruby',
#        'Air Hostess on Dhawar Airlines',
#        "Donut (Steven's Imagination in Sadie's voice)",
#        "Sadie (Steven's imagination)", 'Random Citizen', 'DJ Sour Cream',
#        'Greg & Steven', 'Ricky', 'Hotel Employees', 'Hotel Employee',
#        'Tablet Ad', 'Lars (Steven)', 'Martha', 'Dante', 'Dante & Martha',
#        'Male Werewolf (TV)', 'Female Werewolf (TV)',
#        'The Cool Kids & A Bystander', 'Kofi & Mr. Fryman',
#        'Fallen Person', 'Tearful Girl', 'Jenny & Peedee', 'Jane',
#        'Peedee, Kiki, & Jenny', 'Kiki and Steven', 'Kiki & Steven',
#        'Pizza Jenny', 'Steven & Nephrite', 'Steven & Lapis',
#        'Steven& Greg', 'TV Announcer', 'Holo-Pearls', 'Game Narrator',
#        'Outgoing Fist (In-Game)', 'Lonely Blade (In-Game)',
#        'Out Going Fist (In-Game)', 'Blue Lonely Blade (In-Game)',
#        'Blue Lonely Blade (T.V)', "Game's Narrator", 'Bismuth',
#        'Lonely Blade (TV)', 'Percy (TV)', 'Peridot & Steven',
#        'Jasper & Amethyst', 'Smoky Quartz', 'Amethyst (Jasper)',
#        '"Eyeball")', 'Ruby ("Doc")', 'Other Rubies', '"Giant" Ruby',
#        'Smoky', 'Sugilite (Voiceover)', 'Buddy (Jamie)', 'Stranger',
#        'Garnet & Stevonnie', 'Zoltron Robot', 'Zoltron (Steven)',
#        'Mr. Frowney', 'Masked Kid', 'Garbanzo', 'Pilot', 'Andy',
#        'Andy (off-screen)', 'Greg (off-screen)', 'Everyone (Except Andy)',
#        'Everyone else', 'Blue Diamond', 'Blue Pearl', 'Guard 1',
#        'Elite Gem', 'Guards', 'Holly Blue', 'Guard 2', 'Guard 3',
#        'Guard 4', 'Zooman 1', 'Zooman 2', 'Zooman 3', 'Zooman 4',
#        'Zoomans', 'Wy-Six', 'Zooman 5', '???', 'Jay-Ten', 'Little Voice',
#        'Together', 'Amethyst(s)', 'Amethyst 1', 'Amethyst 2', '8XL',
#        '8XJ', 'Skinny', 'Carnelian', 'Pearls', 'Yellow Diamond & Pearls',
#        'Connie (Narrating)', 'Steven (On phone)',
#        'Lapis (imitating Garnet)',
#        'Connie, Lapis & Peridot (with Pumpkin)',
#        'Priyanka Maheswaran (voicemail)', 'Ronaldo (Video)',
#        "Steven's Phone", 'Billy Bank Assets', 'Lapis & Peridot',
#        'Rose (TV)', 'Greg (TV)', 'Doug', 'Lars, Steven & Sadie',
#        'Steven & Sadie', 'Lars (Voicemail)', 'Teens of Rage Announcer',
#        'Teardrop Gem', 'The Gems', 'Aquamarine', 'Topaz',
#        'Zircon (Defense)', 'Zircon (D)', 'Zircon (Prosecutor)',
#        'Zircon (P)', 'Eyeball', 'Steven & Lars', 'Twin Gems', 'Rhodonite',
#        '"Sapphire" Gem', 'Rutile Twins', 'Giant Fusion Gem', 'Fluorite',
#        'Padparadscha', 'Male Citizen', 'All, except Steven',
#        'Female Citizen', 'Bill Dewey', 'Ronaldo (Voiceover)',
#        'Steven a& Peridot', 'Steven, Buck & Jenny', 'Zombie (TV)',
#        'Steven, Buck, Jenny & Sour Cream', 'Steven & Jenny', 'Derrick',
#        'Steven & Kevin', 'Party-Goers', 'Green Gem', 'Emerald',
#        'Lars, Rhodonite, Rutile Twins & Fluorite', 'Stevens',
#        'Rhononite & Rutile Twins', 'Pink Diamond', 'Off Colors',
#        'Sadie & Cool Kids', 'Sadie & Jenny', 'Sadie (Pre-recorded)',
#        'Sunshine', 'Passerby', 'Steven (voiceover)', 'Steven (v.o.)',
#        'Bill', 'Mr. Dewey', 'Pearl #1', 'Pearl #2', 'Pearl #3',
#        'Pearl #4', 'Amethyst 3', 'Amethyst 4', 'Amethyst 5',
#        'Pearl (voiceover)', 'Amethyst & Steven', 'Ruby (voiceover)',
#        'Ruby (v.o.)', 'All', 'Pearl & Ruby', 'Everyone Else',
#        'Steven & Garnet', 'Mayor Nanefua', 'Pearl, Amethyst & Garnet',
#        'Connie (Mind)', 'Garnet (Mind)', 'Amethyst (Mind)',
#        'Pearl (Mind)', 'Bismuth (Mind)', 'Yellow Diamond (Mind)',
#        'Blue Diamond (Mind)', 'Steven (Mind)', 'Nephrite',
#        'Amethyst & Connie', 'White Pearl', 'Connie & Pearl',
#        'White Diamond', 'Brainy', 'Patch', 'Nosey', 'Chesto', 'Gem #5',
#        'Noggin', 'Fisto', 'Comby', 'Pebble', 'Yellow & Blue Pearl',
#        'Pair of Gems #1', 'Pair of Gems #2', 'Lemon Jade',
#        'Pink Diamond (Steven)', 'Pink Pearl (White Diamond)',
#        'Connie & Peridot', 'Smoky (Amethyst)', 'Rainbow Quartz 2.0',
#        'Sunstone', 'Amethyst (White Diamond)', 'Garnet (White Diamond)',
#        'Pearl (White Diamond)', 'Gem Steven', 'Pink Pearl',
#        'Steven (Voiceover)', 'Blue & Yellow Diamond', 'The Diamonds',
#        'Steven & Pearl', 'Spinel', 'Shell', 'Bismuth & Peridot',
#        'Bismuth & Lapis', 'Steven, Bismuth, Peridot & Lapis',
#        'Sadie & Amethyst', 'Steg', 'Steg & Opal', 'Spinel (Pink)',
#        'Steven & Spinel', 'Garnet (v.o.)',
#        'Garnet, Amethyst, Pearl & Greg', 'The Diamonds (overlapping)',
#        'Spinel & the Diamonds', 'Crystal Gems & Greg', 'Peridot & Lapis',
#        'Lars, Sadie, & Mayor Nanefua', 'Garnet, Amethyst, & Pearl',
#        'Everyone', 'Garnet, Amethyst, Pearl & Connie', 'Cherry Quartz',
#        'Steven (Narrating)', 'Ruby 1', 'Ruby 2', 'Snowflake Obsidian',
#        'Larimar', 'Zebra Jasper', 'Ocean Jasper', 'Smoky (Steven)',
#        'An Amethyst', 'The Famethyst', '"Superfan" Rose', '"Hippie" Rose',
#        '"Shy" Rose', 'Rose Quartz (TV)', 'Angel Aura Quartz',
#        'Pink Steven', 'Mega Pearl', 'Short Fusion Gem', 'Bluebird',
#        '"Eyeball" and Aquamarine', 'Character 1', '"Explorer Gal"',
#        'Rainbow 2.0', 'Ocean JasperNephrite', 'Steven and Pearl',
#        'Cat Steven', '"Nice" Lapis', '"Mean" Lapis', 'Shep', 'Cactus',
#        'Cactus Steven', 'Cookie Cat', 'Rodrigo', 'Stefan', 'Jasmine',
#        'Sour Cream (on radio)', 'Man', 'Jaime', 'Khadijah', 'A girl',
#        'Daniel', 'Patricia', 'Brandish', 'Drew', 'Announcer',
#        'Greg(on phone)', 'Connie(on phone)', 'Priyanka', 'Kerry Moonbeam',
#        'Greg and Kerry Moonbeam', 'A Jasper', 'Aubergine Pearl', 'Chert',
#        'Flint', 'White Diamond and Spinel', 'Steven and White Diamond',
#        'Steven (TV)', 'Plant Stevens', 'Plant Steven',
#        'Bismuth, Peridot, and Lapis', 'Peridot, Lapis, and Bismuth',
#        'Connie and Greg'], dtype=object)

# %%
cleaned_speakers = []
for speaker in all_speakers:
    if isinstance(speaker, str):
        speaker_set = set([speaker.strip() for speaker in re.split(', |& |and ', speaker) if speaker != ''])
        if speaker_set not in cleaned_speakers:
            cleaned_speakers.append(speaker_set)
        
cleaned_speakers
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-060b4b562879> in <module>
#       1 cleaned_speakers = []
# ----> 2 for speaker in all_speakers:
#       3     if isinstance(speaker, str):
#       4         speaker_set = set([speaker.strip() for speaker in re.split(', |& |and ', speaker) if speaker != ''])
#       5         if speaker_set not in cleaned_speakers:
#
# NameError: name 'all_speakers' is not defined
